# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_excel(r"C:\Users\SWARNASASH\OneDrive\Desktop\New folder (3)\FOLD1.xlsx")
df1
# Out:
#        Source.Name  match_id   season start_date                venue  \
# 0        64814.csv     64814  2002/03 2002-12-29  McLean Park, Napier
# 1        64814.csv     64814  2002/03 2002-12-29  McLean Park, Napier
# 2        64814.csv     64814  2002/03 2002-12-29  McLean Park, Napier
# 3        64814.csv     64814  2002/03 2002-12-29  McLean Park, Napier
# 4        64814.csv     64814  2002/03 2002-12-29  McLean Park, Napier
# ...            ...       ...      ...        ...                  ...
# 812384  936167.csv    936167  2016/17 2017-02-10      SuperSport Park
# 812385  936167.csv    936167  2016/17 2017-02-10      SuperSport Park
# 812386  936167.csv    936167  2016/17 2017-02-10      SuperSport Park
# 812387  936167.csv    936167  2016/17 2017-02-10      SuperSport Park
# 812388  936167.csv    936167  2016/17 2017-02-10      SuperSport Park
#
#         innings  ball batting_team  bowling_team        striker  ... extras  \
# ...

# %%
df2=pd.read_excel(r"C:\Users\SWARNASASH\OneDrive\Desktop\New folder (3)\FOLD2.xlsx")
df2
# Out:
#       Source.Name  match_id   season start_date  \
# 0      953335.csv    953335  2015/16 2015-12-25
# 1      953335.csv    953335  2015/16 2015-12-25
# 2      953335.csv    953335  2015/16 2015-12-25
# 3      953335.csv    953335  2015/16 2015-12-25
# 4      953335.csv    953335  2015/16 2015-12-25
# ...           ...       ...      ...        ...
# 8867  1000887.csv   1000887  2016/17 2017-01-13
# 8868  1000887.csv   1000887  2016/17 2017-01-13
# 8869  1000887.csv   1000887  2016/17 2017-01-13
# 8870  1000887.csv   1000887  2016/17 2017-01-13
# 8871  1000887.csv   1000887  2016/17 2017-01-13
#
#                                        venue  innings  ball batting_team  \
# 0                    Sharjah Cricket Stadium        1   0.1  Afghanistan
# 1                    Sharjah Cricket Stadium        1   0.2  Afghanistan
# 2                    Sharjah Cricket Stadium        1   0.3  Afghanistan
# 3                    Sharjah Cricket Stadium        1   0.4  Afghanistan
# ...

# %%
df3=pd.read_excel(r"C:\Users\SWARNASASH\OneDrive\Desktop\New folder (3)\FOLD3.xlsx")
df3
# Out:
#         Source.Name  match_id   season start_date  \
# 0       1000889.csv   1000889  2016/17 2017-01-15
# 1       1000889.csv   1000889  2016/17 2017-01-15
# 2       1000889.csv   1000889  2016/17 2017-01-15
# 3       1000889.csv   1000889  2016/17 2017-01-15
# 4       1000889.csv   1000889  2016/17 2017-01-15
# ...             ...       ...      ...        ...
# 453321  1395702.csv   1395702     2023 2023-09-26
# 453322  1395702.csv   1395702     2023 2023-09-26
# 453323  1395702.csv   1395702     2023 2023-09-26
# 453324  1395702.csv   1395702     2023 2023-09-26
# 453325  1395702.csv   1395702     2023 2023-09-26
#
#                                         venue  innings  ball batting_team  \
# 0                    Melbourne Cricket Ground        1   0.1    Australia
# 1                    Melbourne Cricket Ground        1   0.2    Australia
# 2                    Melbourne Cricket Ground        1   0.3    Australia
# ...

# %%
ODI=pd.concat([df1,df2,df3])
ODI
# Out:
#         Source.Name  match_id   season start_date  \
# 0         64814.csv     64814  2002/03 2002-12-29
# 1         64814.csv     64814  2002/03 2002-12-29
# 2         64814.csv     64814  2002/03 2002-12-29
# 3         64814.csv     64814  2002/03 2002-12-29
# 4         64814.csv     64814  2002/03 2002-12-29
# ...             ...       ...      ...        ...
# 453321  1395702.csv   1395702     2023 2023-09-26
# 453322  1395702.csv   1395702     2023 2023-09-26
# 453323  1395702.csv   1395702     2023 2023-09-26
# 453324  1395702.csv   1395702     2023 2023-09-26
# 453325  1395702.csv   1395702     2023 2023-09-26
#
#                                         venue  innings  ball batting_team  \
# 0                         McLean Park, Napier        1   0.1  New Zealand
# 1                         McLean Park, Napier        1   0.2  New Zealand
# 2                         McLean Park, Napier        1   0.3  New Zealand
# ...

# %%
ODI.dtypes
# Out:
# Source.Name                       object
# match_id                           int64
# season                            object
# start_date                datetime64[ns]
# venue                             object
# innings                            int64
# ball                             float64
# batting_team                      object
# bowling_team                      object
# striker                           object
# non_striker                       object
# bowler                            object
# runs_off_bat                       int64
# extras                             int64
# wides                            float64
# noballs                          float64
# byes                             float64
# legbyes                          float64
# penalty                          float64
# wicket_type                       object
# player_dismissed                  object
# other_wicket_type                float64
# other_player_dismissed           float64
# ...

# %%
ODI.start_date=pd.to_datetime(ODI.start_date)
ODI['Year']=ODI.start_date.dt.year
ODI['Overs']=np.ceil(ODI.ball)
ODI.head(20)
# Out:
#    Source.Name  match_id   season start_date                venue  innings  \
# 0    64814.csv     64814  2002/03 2002-12-29  McLean Park, Napier        1
# 1    64814.csv     64814  2002/03 2002-12-29  McLean Park, Napier        1
# 2    64814.csv     64814  2002/03 2002-12-29  McLean Park, Napier        1
# 3    64814.csv     64814  2002/03 2002-12-29  McLean Park, Napier        1
# 4    64814.csv     64814  2002/03 2002-12-29  McLean Park, Napier        1
# 5    64814.csv     64814  2002/03 2002-12-29  McLean Park, Napier        1
# 6    64814.csv     64814  2002/03 2002-12-29  McLean Park, Napier        1
# 7    64814.csv     64814  2002/03 2002-12-29  McLean Park, Napier        1
# 8    64814.csv     64814  2002/03 2002-12-29  McLean Park, Napier        1
# 9    64814.csv     64814  2002/03 2002-12-29  McLean Park, Napier        1
# 10   64814.csv     64814  2002/03 2002-12-29  McLean Park, Napier        1
# ...

# %% [markdown]
# To find the **Predicted playing 11 (for team India) in ODI World Cup 2023** ODI dataset is considered in two diffrent time frame;
# **2019** (the previous world Cup was conducted in 2019.To evalute player's Performance within current years; the performance since 2019 will be considered) & **2023** (Current year's Performance)

# %%
ODI_19=ODI[ODI.Year>=2019]#data from 2019
ODI_19
# Out:
#         Source.Name  match_id   season start_date  \
# 126310  1144156.csv   1144156  2018/19 2019-01-19
# 126311  1144156.csv   1144156  2018/19 2019-01-19
# 126312  1144156.csv   1144156  2018/19 2019-01-19
# 126313  1144156.csv   1144156  2018/19 2019-01-19
# 126314  1144156.csv   1144156  2018/19 2019-01-19
# ...             ...       ...      ...        ...
# 453321  1395702.csv   1395702     2023 2023-09-26
# 453322  1395702.csv   1395702     2023 2023-09-26
# 453323  1395702.csv   1395702     2023 2023-09-26
# 453324  1395702.csv   1395702     2023 2023-09-26
# 453325  1395702.csv   1395702     2023 2023-09-26
#
#                                         venue  innings  ball  batting_team  \
# 126310                       St George's Park        1   0.1  South Africa
# 126311                       St George's Park        1   0.2  South Africa
# 126312                       St George's Park        1   0.3  South Africa
# ...

# %%
ODI_23=ODI[ODI.Year==2023]#data in 2023
ODI_23
# Out:
#         Source.Name  match_id   season start_date  \
# 354622  1322359.csv   1322359  2022/23 2023-03-25
# 354623  1322359.csv   1322359  2022/23 2023-03-25
# 354624  1322359.csv   1322359  2022/23 2023-03-25
# 354625  1322359.csv   1322359  2022/23 2023-03-25
# 354626  1322359.csv   1322359  2022/23 2023-03-25
# ...             ...       ...      ...        ...
# 453321  1395702.csv   1395702     2023 2023-09-26
# 453322  1395702.csv   1395702     2023 2023-09-26
# 453323  1395702.csv   1395702     2023 2023-09-26
# 453324  1395702.csv   1395702     2023 2023-09-26
# 453325  1395702.csv   1395702     2023 2023-09-26
#
#                                         venue  innings  ball batting_team  \
# 354622                    Eden Park, Auckland        1   0.1  New Zealand
# 354623                    Eden Park, Auckland        1   0.2  New Zealand
# 354624                    Eden Park, Auckland        1   0.3  New Zealand
# ...

# %% [markdown]
# ### Batting Stats (Team India)

# %%
ODI_19_IND_bt=ODI_19[ODI_19.batting_team=='India']
ODI_19_IND_bt
# Out:
#         Source.Name  match_id   season start_date  \
# 134822  1144490.csv   1144490     2019 2019-06-05
# 134823  1144490.csv   1144490     2019 2019-06-05
# 134824  1144490.csv   1144490     2019 2019-06-05
# 134825  1144490.csv   1144490     2019 2019-06-05
# 134826  1144490.csv   1144490     2019 2019-06-05
# ...             ...       ...      ...        ...
# 450322  1389389.csv   1389389  2023/24 2023-09-24
# 450323  1389389.csv   1389389  2023/24 2023-09-24
# 450324  1389389.csv   1389389  2023/24 2023-09-24
# 450325  1389389.csv   1389389  2023/24 2023-09-24
# 450326  1389389.csv   1389389  2023/24 2023-09-24
#
#                                  venue  innings  ball batting_team  \
# 134822                   The Rose Bowl        2   0.1        India
# 134823                   The Rose Bowl        2   0.2        India
# 134824                   The Rose Bowl        2   0.3        India
# 134825                   The Rose Bowl        2   0.4        India
# ...

# %%
ODI_23_IND_bt=ODI_23[ODI_23.batting_team=='India']
ODI_23_IND_bt
# Out:
#         Source.Name  match_id   season start_date  \
# 387003  1348643.csv   1348643  2022/23 2023-01-10
# 387004  1348643.csv   1348643  2022/23 2023-01-10
# 387005  1348643.csv   1348643  2022/23 2023-01-10
# 387006  1348643.csv   1348643  2022/23 2023-01-10
# 387007  1348643.csv   1348643  2022/23 2023-01-10
# ...             ...       ...      ...        ...
# 450322  1389389.csv   1389389  2023/24 2023-09-24
# 450323  1389389.csv   1389389  2023/24 2023-09-24
# 450324  1389389.csv   1389389  2023/24 2023-09-24
# 450325  1389389.csv   1389389  2023/24 2023-09-24
# 450326  1389389.csv   1389389  2023/24 2023-09-24
#
#                                       venue  innings  ball batting_team  \
# 387003  Barsapara Cricket Stadium, Guwahati        1   0.1        India
# 387004  Barsapara Cricket Stadium, Guwahati        1   0.2        India
# 387005  Barsapara Cricket Stadium, Guwahati        1   0.3        India
# ...

# %%
ODI_19_IND_BAT=pd.pivot_table(ODI_19_IND_bt,index=["match_id","striker"],
                              values=["runs_off_bat","ball","player_dismissed"],
               aggfunc={"runs_off_bat":"sum","ball":"count","player_dismissed":"count"})
ODI_19_IND_BAT.rename(columns={"runs_off_bat":"Runs Scored","ball":"Balls Faced","player_dismissed":"Dismissals"},
                 inplace=True)
ODI_19_IND_BAT_P=pd.pivot_table(ODI_19_IND_BAT,index=['striker'],values=["Runs Scored","Balls Faced","Dismissals"],aggfunc="sum")
ODI_19_IND_BAT_P["Strike Rate"]=round(ODI_19_IND_BAT_P["Runs Scored"]/ODI_19_IND_BAT_P["Balls Faced"]*100,2)
ODI_19_IND_BAT_P["Batting Average"]=round(ODI_19_IND_BAT_P["Runs Scored"]/ODI_19_IND_BAT_P["Dismissals"],2)
ODI_19_IND_BAT_P
# Out:
#                    Balls Faced  Dismissals  Runs Scored  Strike Rate  \
# striker
# AR Patel                   299          10          300       100.33
# AT Rayudu                  335           8          247        73.73
# Arshdeep Singh               9           1            9       100.00
# Avesh Khan                  19           2           13        68.42
# B Kumar                    152           9          112        73.68
# C Sakariya                   1           0            0         0.00
# DJ Hooda                   194           6          153        78.87
# DL Chahar                  204           5          191        93.63
# HH Pandya                 1038          28         1088       104.82
# Ishan Kishan               889          20          886        99.66
# J Yadav                      6           1            2        33.33
# JJ Bumrah                   88           5           57        64.77
# ...

# %%
ODI_19_IND_BAT=pd.pivot_table(ODI_19_IND_bt,index=["match_id","striker"],
                              values=["runs_off_bat","ball","player_dismissed"],
               aggfunc={"runs_off_bat":"sum","ball":"count","player_dismissed":"count"})
ODI_19_IND_BAT.rename(columns={"runs_off_bat":"Runs Scored","ball":"Balls Faced","player_dismissed":"Dismissals"},
                 inplace=True)
ODI_19_IND_BAT
# Out:
#                        Balls Faced  Dismissals  Runs Scored
# match_id striker
# 1144490  HH Pandya               8           0           15
#          KL Rahul               42           1           26
#          MS Dhoni               47           1           34
#          RG Sharma             146           0          122
#          S Dhawan               12           1            8
# ...                            ...         ...          ...
# 1389389  RA Jadeja               9           0           13
#          RD Gaikwad             13           1            8
#          SA Yadav               39           0           72
#          SS Iyer                92           1          105
#          Shubman Gill           97           1          104
#
# [691 rows x 3 columns]

# %%
ODI_23_IND_BAT=pd.pivot_table(ODI_23_IND_bt,index=["match_id","striker"],
                              values=["runs_off_bat","ball","player_dismissed"],
               aggfunc={"runs_off_bat":"sum","ball":"count","player_dismissed":"count"})
ODI_23_IND_BAT.rename(columns={"runs_off_bat":"Runs Scored","ball":"Balls Faced","player_dismissed":"Dismissals"},
                 inplace=True)
ODI_23_IND_BAT_P=pd.pivot_table(ODI_23_IND_BAT,index=['striker'],values=["Runs Scored","Balls Faced","Dismissals"],aggfunc="sum")
ODI_23_IND_BAT_P["Strike Rate"]=round(ODI_23_IND_BAT_P["Runs Scored"]/ODI_23_IND_BAT_P["Balls Faced"]*100,2)
ODI_23_IND_BAT_P["Batting Average"]=round(ODI_23_IND_BAT_P["Runs Scored"]/ODI_23_IND_BAT_P["Dismissals"],2)
ODI_23_IND_BAT_P
# Out:
#                    Balls Faced  Dismissals  Runs Scored  Strike Rate  \
# striker
# AR Patel                   154           6          132        85.71
# HH Pandya                  406          10          372        91.63
# Ishan Kishan               449          12          409        91.09
# JJ Bumrah                   26           2           21        80.77
# KL Rahul                   593           7          505        85.16
# Kuldeep Yadav               94           5           40        42.55
# M Prasidh Krishna            2           0            0         0.00
# Mohammed Shami              23           3           26       113.04
# Mohammed Siraj              37           1           16        43.24
# Mukesh Kumar                 7           1            6        85.71
# RA Jadeja                  272           6          154        56.62
# RD Gaikwad                 104           3           87        83.65
# ...

# %%
ODI_23_IND_BAT=pd.pivot_table(ODI_23_IND_bt,index=["match_id","striker"],
                              values=["runs_off_bat","ball","player_dismissed"],
               aggfunc={"runs_off_bat":"sum","ball":"count","player_dismissed":"count"})
ODI_23_IND_BAT.rename(columns={"runs_off_bat":"Runs Scored","ball":"Balls Faced","player_dismissed":"Dismissals"},
                 inplace=True)
ODI_23_IND_BAT
# Out:
#                          Balls Faced  Dismissals  Runs Scored
# match_id striker
# 1348643  AR Patel                 10           1            9
#          HH Pandya                13           1           14
#          KL Rahul                 29           1           39
#          Mohammed Shami            4           0            4
#          Mohammed Siraj            8           0            7
# ...                              ...         ...          ...
# 1389389  RA Jadeja                 9           0           13
#          RD Gaikwad               13           1            8
#          SA Yadav                 39           0           72
#          SS Iyer                  92           1          105
#          Shubman Gill             97           1          104
#
# [157 rows x 3 columns]

# %%
ODI_19_IND_BAT_P_runs=ODI_19_IND_BAT_P.sort_values(by='Runs Scored',ascending=False).head(5)
ODI_19_IND_BAT_P_runs
# Out:
#               Balls Faced  Dismissals  Runs Scored  Strike Rate  \
# striker
# V Kohli              2924          57         2795        95.59
# RG Sharma            2769          49         2577        93.07
# KL Rahul             2234          37         1948        87.20
# Shubman Gill         1917          31         1917       100.00
# S Dhawan             2264          47         1858        82.07
#
#               Batting Average
# striker
# V Kohli                 49.04
# RG Sharma               52.59
# KL Rahul                52.65
# Shubman Gill            61.84
# S Dhawan                39.53

# %%
ODI_23_IND_BAT_P_runs=ODI_23_IND_BAT_P.sort_values(by='Runs Scored',ascending=False).head(5)
ODI_23_IND_BAT_P_runs
# Out:
#               Balls Faced  Dismissals  Runs Scored  Strike Rate  \
# striker
# Shubman Gill         1202          18         1230       102.33
# RG Sharma             563          12          577       102.49
# V Kohli               491          10          556       113.24
# KL Rahul              593           7          505        85.16
# Ishan Kishan          449          12          409        91.09
#
#               Batting Average
# striker
# Shubman Gill            68.33
# RG Sharma               48.08
# V Kohli                 55.60
# KL Rahul                72.14
# Ishan Kishan            34.08

# %%
ODI_19_IND_BAT_P_avg=ODI_19_IND_BAT_P[ODI_19_IND_BAT_P["Balls Faced"]>=750].sort_values(by='Batting Average',ascending=False).head(5)
ODI_19_IND_BAT_P_avg
# Out:
#               Balls Faced  Dismissals  Runs Scored  Strike Rate  \
# striker
# Shubman Gill         1917          31         1917       100.00
# MS Dhoni              753          10          600        79.68
# KL Rahul             2234          37         1948        87.20
# RG Sharma            2769          49         2577        93.07
# V Kohli              2924          57         2795        95.59
#
#               Batting Average
# striker
# Shubman Gill            61.84
# MS Dhoni                60.00
# KL Rahul                52.65
# RG Sharma               52.59
# V Kohli                 49.04

# %%
ODI_23_IND_BAT_P_avg=ODI_23_IND_BAT_P[ODI_23_IND_BAT_P["Balls Faced"]>=400].sort_values(by='Batting Average',ascending=False).head(5)
ODI_23_IND_BAT_P_avg
# Out:
#               Balls Faced  Dismissals  Runs Scored  Strike Rate  \
# striker
# KL Rahul              593           7          505        85.16
# Shubman Gill         1202          18         1230       102.33
# V Kohli               491          10          556       113.24
# RG Sharma             563          12          577       102.49
# HH Pandya             406          10          372        91.63
#
#               Batting Average
# striker
# KL Rahul                72.14
# Shubman Gill            68.33
# V Kohli                 55.60
# RG Sharma               48.08
# HH Pandya               37.20

# %%
ODI_19_IND_BAT_P_SR=ODI_19_IND_BAT_P[ODI_19_IND_BAT_P["Balls Faced"]>=750].sort_values(by='Strike Rate',ascending=False).head(5)
ODI_19_IND_BAT_P_SR
# Out:
#               Balls Faced  Dismissals  Runs Scored  Strike Rate  \
# striker
# HH Pandya            1038          28         1088       104.82
# RR Pant               804          22          824       102.49
# Shubman Gill         1917          31         1917       100.00
# Ishan Kishan          889          20          886        99.66
# V Kohli              2924          57         2795        95.59
#
#               Batting Average
# striker
# HH Pandya               38.86
# RR Pant                 37.45
# Shubman Gill            61.84
# Ishan Kishan            44.30
# V Kohli                 49.04

# %%
ODI_23_IND_BAT_P_SR=ODI_23_IND_BAT_P[ODI_23_IND_BAT_P["Balls Faced"]>=400].sort_values(by='Strike Rate',ascending=False).head(5)
ODI_23_IND_BAT_P_SR
# Out:
#               Balls Faced  Dismissals  Runs Scored  Strike Rate  \
# striker
# V Kohli               491          10          556       113.24
# RG Sharma             563          12          577       102.49
# Shubman Gill         1202          18         1230       102.33
# HH Pandya             406          10          372        91.63
# Ishan Kishan          449          12          409        91.09
#
#               Batting Average
# striker
# V Kohli                 55.60
# RG Sharma               48.08
# Shubman Gill            68.33
# HH Pandya               37.20
# Ishan Kishan            34.08

# %%
ODI_19_IND_BAT_P_50=pd.pivot_table(ODI_19_IND_BAT[(ODI_19_IND_BAT['Runs Scored']>=50)|(ODI_19_IND_BAT['Runs Scored']<100)],
                                   index=['striker'],values=['Runs Scored'],aggfunc={'Runs Scored':'count'})
ODI_19_IND_BAT_P_50.rename(columns={'Runs Scored':'Half Centuries'},inplace=True)
ODI_19_IND_BAT_P_50=ODI_19_IND_BAT_P_50.sort_values(by='Half Centuries',ascending=False).head(5)
ODI_19_IND_BAT_P_50
# Out:
#            Half Centuries
# striker
# V Kohli                60
# RG Sharma              55
# S Dhawan               50
# KL Rahul               45
# SS Iyer                36

# %%
ODI_23_IND_BAT_P_50=pd.pivot_table(ODI_23_IND_BAT[(ODI_23_IND_BAT['Runs Scored']>=50)|(ODI_23_IND_BAT['Runs Scored']<100)],
                                   index=['striker'],values=['Runs Scored'],aggfunc={'Runs Scored':'count'})
ODI_23_IND_BAT_P_50.rename(columns={'Runs Scored':'Half Centuries'},inplace=True)
ODI_23_IND_BAT_P_50=ODI_23_IND_BAT_P_50.sort_values(by='Half Centuries',ascending=False).head(5)
ODI_23_IND_BAT_P_50
# Out:
#               Half Centuries
# striker
# Shubman Gill              20
# RG Sharma                 14
# Ishan Kishan              13
# V Kohli                   12
# HH Pandya                 12

# %%
ODI_19_IND_BAT_P_100=pd.pivot_table(ODI_19_IND_BAT[ODI_19_IND_BAT['Runs Scored']>=100],index=['striker'],values=['Runs Scored']
               ,aggfunc={'Runs Scored':'count'})
ODI_19_IND_BAT_P_100.rename(columns={'Runs Scored':'Centuries'},inplace=True)
ODI_19_IND_BAT_P_100=ODI_19_IND_BAT_P_100.sort_values(by='Centuries',ascending=False).head(5)
ODI_19_IND_BAT_P_100
# Out:
#               Centuries
# striker
# RG Sharma             9
# V Kohli               9
# Shubman Gill          6
# KL Rahul              5
# SS Iyer               3

# %%
ODI_23_IND_BAT_P_100=pd.pivot_table(ODI_23_IND_BAT[ODI_23_IND_BAT['Runs Scored']>=100],index=['striker'],values=['Runs Scored']
               ,aggfunc={'Runs Scored':'count'})
ODI_23_IND_BAT_P_100.rename(columns={'Runs Scored':'Centuries'},inplace=True)
ODI_23_IND_BAT_P_100=ODI_23_IND_BAT_P_100.sort_values(by='Centuries',ascending=False).head(5)
ODI_23_IND_BAT_P_100
# Out:
#               Centuries
# striker
# Shubman Gill          5
# V Kohli               3
# KL Rahul              1
# RG Sharma             1
# SS Iyer               1

# %%
ODI_19_IND_bt_4=pd.pivot_table(ODI_19_IND_bt[ODI_19_IND_bt['runs_off_bat']==4],index='striker',values='runs_off_bat',aggfunc={'runs_off_bat':'count'})
ODI_19_IND_bt_4.rename(columns={'runs_off_bat':'Boundaries'},inplace=True)
ODI_19_IND_bt_4['Boundaries per Ball']=round(ODI_19_IND_bt_4['Boundaries']/ODI_19_IND_BAT_P['Balls Faced'],3)
ODI_19_IND_bt_4=ODI_19_IND_bt_4[ODI_19_IND_bt_4['Boundaries']>=100].sort_values(by='Boundaries per Ball',ascending=False).head(5)
ODI_19_IND_bt_4
# Out:
#               Boundaries  Boundaries per Ball
# striker
# Shubman Gill         214                0.112
# S Dhawan             228                0.101
# RG Sharma            268                0.097
# SS Iyer              153                0.094
# V Kohli              259                0.089

# %%
ODI_23_IND_bt_4=pd.pivot_table(ODI_23_IND_bt[ODI_23_IND_bt['runs_off_bat']==4],index='striker',values='runs_off_bat',aggfunc={'runs_off_bat':'count'})
ODI_23_IND_bt_4.rename(columns={'runs_off_bat':'Boundaries'},inplace=True)
ODI_23_IND_bt_4['Boundaries per Ball']=round(ODI_23_IND_bt_4['Boundaries']/ODI_23_IND_BAT_P['Balls Faced'],3)
ODI_23_IND_bt_4=ODI_23_IND_bt_4[ODI_23_IND_bt_4['Boundaries']>=40].sort_values(by='Boundaries',ascending=False).head(5)
ODI_23_IND_bt_4
# Out:
#               Boundaries  Boundaries per Ball
# striker
# Shubman Gill         140                0.116
# RG Sharma             60                0.107
# V Kohli               49                0.100
# KL Rahul              44                0.074
# Ishan Kishan          41                0.091

# %%
ODI_19_IND_bt_6=pd.pivot_table(ODI_19_IND_bt[ODI_19_IND_bt['runs_off_bat']==6],index='striker',values='runs_off_bat',aggfunc={'runs_off_bat':'count'})
ODI_19_IND_bt_6.rename(columns={'runs_off_bat':'Over Boundaries'},inplace=True)
ODI_19_IND_bt_6['Over Boundaries per Ball']=round(ODI_19_IND_bt_6['Over Boundaries']/ODI_19_IND_BAT_P['Balls Faced'],3)
ODI_19_IND_bt_6=ODI_19_IND_bt_6[ODI_19_IND_bt_6['Over Boundaries']>=20].sort_values(by='Over Boundaries per Ball',
                                                                                     ascending=False).head(5)
ODI_19_IND_bt_6
# Out:
#               Over Boundaries  Over Boundaries per Ball
# striker
# Ishan Kishan               31                     0.035
# HH Pandya                  35                     0.034
# RR Pant                    25                     0.031
# RG Sharma                  84                     0.030
# KL Rahul                   47                     0.021

# %%
ODI_23_IND_bt_6=pd.pivot_table(ODI_23_IND_bt[ODI_23_IND_bt['runs_off_bat']==6],index='striker',values='runs_off_bat',
                               aggfunc={'runs_off_bat':'count'})
ODI_23_IND_bt_6.rename(columns={'runs_off_bat':'Over Boundaries'},inplace=True)
ODI_23_IND_bt_6['Over Boundaries per Ball']=round(ODI_23_IND_bt_6['Over Boundaries']/ODI_23_IND_BAT_P['Balls Faced'],3)
ODI_23_IND_bt_6=ODI_23_IND_bt_6[ODI_23_IND_bt_6['Over Boundaries']>=10].sort_values(by='Over Boundaries per Ball',
                                                                                    ascending=False).head(5)        
ODI_23_IND_bt_6
# Out:
#               Over Boundaries  Over Boundaries per Ball
# striker
# RG Sharma                  30                     0.053
# SA Yadav                   12                     0.049
# HH Pandya                  12                     0.030
# V Kohli                    14                     0.029
# Ishan Kishan               11                     0.024

# %%
plt.subplot(7,2,1)
ODI_19_IND_BAT_P_runs['Runs Scored'].plot(kind='bar',figsize=(12,5),color='coral')
for i in range(len(list(ODI_19_IND_BAT_P_runs.index))):
    plt.text(i,ODI_19_IND_BAT_P_runs['Runs Scored'][i],ODI_19_IND_BAT_P_runs['Runs Scored'][i],ha='center')
plt.title('Top Runs Scorers of India(Since 2019)')
plt.xlabel('Batter')
plt.xticks(rotation=0)
plt.ylabel('Runs Scored')
plt.subplot(7,2,2)
ODI_23_IND_BAT_P_runs['Runs Scored'].plot(kind='bar',figsize=(12,5),color='coral')
for i in range(len(list(ODI_23_IND_BAT_P_runs.index))):
    plt.text(i,ODI_23_IND_BAT_P_runs['Runs Scored'][i],ODI_23_IND_BAT_P_runs['Runs Scored'][i],ha='center')
plt.title('Top Runs Scorers of India(In 2023)')
plt.xlabel('Batter')
plt.xticks(rotation=0)
plt.ylabel('Runs Scored')
plt.subplot(7,2,3)
ODI_19_IND_BAT_P_avg['Batting Average'].plot(kind='bar',figsize=(12,5),color='blue')
for i in range(len(list(ODI_19_IND_BAT_P_avg.index))):
    plt.text(i,ODI_19_IND_BAT_P_avg['Batting Average'][i],ODI_19_IND_BAT_P_avg['Batting Average'][i],ha='center')
plt.title('Top Batting Average (played atleast 750 balls) of India(Since 2019)')
plt.xlabel('Batter')
plt.xticks(rotation=0)
plt.subplot(7,2,4)
plt.ylabel('Batting Average')
ODI_23_IND_BAT_P_avg['Batting Average'].plot(kind='bar',figsize=(12,5),color='blue')
for i in range(len(list(ODI_23_IND_BAT_P_avg.index))):
    plt.text(i,ODI_23_IND_BAT_P_avg['Batting Average'][i],ODI_23_IND_BAT_P_avg['Batting Average'][i],ha='center')
plt.title('Top Batting Average (played atleast 400 balls) of India(In 2023)')
plt.xlabel('Batter')
plt.xticks(rotation=0)
plt.ylabel('Batting Average')
plt.subplot(7,2,5)
ODI_19_IND_BAT_P_SR['Strike Rate'].plot(kind='bar',figsize=(12,5),color='violet')
for i in range(len(list(ODI_19_IND_BAT_P_SR.index))):
    plt.text(i,ODI_19_IND_BAT_P_SR['Strike Rate'][i],ODI_19_IND_BAT_P_SR['Strike Rate'][i],ha='center')
plt.title('Top Strike Rate (played atleast 750 balls) of India(Since 2019)')
plt.xlabel('Batter')
plt.xticks(rotation=0)
plt.ylabel('Strike Rate')
plt.subplot(7,2,6)
ODI_23_IND_BAT_P_SR['Strike Rate'].plot(kind='bar',figsize=(12,5),color='violet')
for i in range(len(list(ODI_23_IND_BAT_P_SR.index))):
    plt.text(i,ODI_23_IND_BAT_P_SR['Strike Rate'][i],ODI_23_IND_BAT_P_SR['Strike Rate'][i],ha='center')
plt.title('Top Strike Rate (played atleast 400 balls) of India(In 2023)')
plt.xlabel('Batter')
plt.xticks(rotation=0)
plt.ylabel('Strike Rate')
plt.subplot(7,2,7)
ODI_19_IND_bt_4['Boundaries per Ball'].plot(kind='bar',figsize=(12,5),color='green')
for i in range(len(list(ODI_19_IND_bt_4.index))):
    plt.text(i,ODI_19_IND_bt_4['Boundaries per Ball'][i],ODI_19_IND_bt_4['Boundaries per Ball'][i],ha='center')
plt.title('Top Boundaries per Ball hitters (atleast hit 100 boundaries) of India(Since 2019)')
plt.xlabel('Batter')
plt.xticks(rotation=0)
plt.ylabel('Boundaries per Ball')
plt.subplot(7,2,8)
ODI_23_IND_bt_4['Boundaries per Ball'].plot(kind='bar',figsize=(12,5),color='green')
for i in range(len(list(ODI_23_IND_bt_4.index))):
    plt.text(i,ODI_23_IND_bt_4['Boundaries per Ball'][i],ODI_23_IND_bt_4['Boundaries per Ball'][i],ha='center')
plt.title('Top Boundaries per Ball hitters (atleast hit 40 boundaries) of India(In 2023)')
plt.xlabel('Batter')
plt.xticks(rotation=0)
plt.ylabel('Boundaries per Ball')
plt.subplot(7,2,9)
ODI_19_IND_bt_6['Over Boundaries per Ball'].plot(kind='bar',figsize=(12,5),color='red')
for i in range(len(list(ODI_19_IND_bt_6.index))):
    plt.text(i,ODI_19_IND_bt_6['Over Boundaries per Ball'][i],ODI_19_IND_bt_6['Over Boundaries per Ball'][i],ha='center')
plt.title('Top Over Boundaries per Ball hitters (atleast hit 20 Over boundaries) of India(Since 2019)')
plt.xlabel('Batter')
plt.xticks(rotation=0)
plt.ylabel('Over Boundaries per Ball')
plt.subplot(7,2,10)
ODI_23_IND_bt_6['Over Boundaries per Ball'].plot(kind='bar',figsize=(12,5),color='red')
for i in range(len(list(ODI_23_IND_bt_6.index))):
    plt.text(i,ODI_23_IND_bt_6['Over Boundaries per Ball'][i],ODI_23_IND_bt_6['Over Boundaries per Ball'][i],ha='center')
plt.title('Top Over Boundaries per Ball hitters (atleast hit 10 Over boundaries) of India(In 2023)')
plt.xlabel('Batter')
plt.xticks(rotation=0)
plt.ylabel('Over Boundaries per Ball')
plt.subplot(7,2,11)
ODI_19_IND_BAT_P_50['Half Centuries'].plot(kind='bar',figsize=(12,5),color='yellow')
for i in range(len(list(ODI_19_IND_BAT_P_50.index))):
    plt.text(i,ODI_19_IND_BAT_P_50['Half Centuries'][i],ODI_19_IND_BAT_P_50['Half Centuries'][i],ha='center')
plt.title('Top Half Centuries of India(Since 2019)')
plt.xlabel('Batter')
plt.xticks(rotation=0)
plt.ylabel('Half Centuries')
plt.subplot(7,2,12)
ODI_23_IND_BAT_P_50['Half Centuries'].plot(kind='bar',figsize=(12,5),color='yellow')
for i in range(len(list(ODI_23_IND_BAT_P_50.index))):
    plt.text(i,ODI_23_IND_BAT_P_50['Half Centuries'][i],ODI_23_IND_BAT_P_50['Half Centuries'][i],ha='center')
plt.title('Top Half Centuries of India(In 2023)')
plt.xlabel('Batter')
plt.xticks(rotation=0)
plt.ylabel('Half Centuries')
plt.subplot(7,2,13)
ODI_19_IND_BAT_P_100['Centuries'].plot(kind='bar',figsize=(12,5),color='brown')
for i in range(len(list(ODI_19_IND_BAT_P_100.index))):
    plt.text(i,ODI_19_IND_BAT_P_100['Centuries'][i],ODI_19_IND_BAT_P_100['Centuries'][i],ha='center')
plt.title('Top Centuries of India(Since 2019)')
plt.xlabel('Batter')
plt.xticks(rotation=0)
plt.ylabel('Centuries')
plt.subplot(7,2,14)
ODI_23_IND_BAT_P_100['Centuries'].plot(kind='bar',figsize=(12,5),color='brown')
for i in range(len(list(ODI_23_IND_BAT_P_100.index))):
    plt.text(i,ODI_23_IND_BAT_P_100['Centuries'][i],ODI_23_IND_BAT_P_100['Centuries'][i],ha='center')
plt.title('Top Centuries of India(In 2023)')
plt.xlabel('Batter')
plt.xticks(rotation=0)
plt.ylabel('Centuries')
plt.subplots_adjust(left=0.1,bottom=0.01, right=1.5, top=4.5, wspace=0.4, hspace=0.8)
plt.show()

# %% [markdown]
# **Caution:**
#
#      1. Mahendra Singh Dhoni has retired from ODI cricket after 2019 World Cup.
#      2. In 2023 Shikhar Dhawan doesn't get much chance in ODI India team in 2023. He may in the shceme of BCCI for 2023             ODI Corld Cup.
#      3. Rishabh Pant met an Car Accident in 2023. So he will not able to play for India in 2023 World Cup .
#      4. Subhman proved himself a star batter fotr India within a year.
#      5. KL Rahul and Shreyas Iyer has come back after a couple of months breaks due to injury.
#      6. Rohit Sharma has scored 5 centuries in 2019 World Cup (This performance is also included in this dataset).

# %% [markdown]
# **Batting Stats(Info):**
#
#      1. Virat Kohli (2795 Runs,60 Half centuries, 9 centuries) and Rohit sharma(2577 Runs,55 half centuries, 9 centuries)          is the highest run getters (Since 2019 world cup) with most centuries and half centuries.
#      2. Subhman Gill is the Star Performer for India in 2023 (Highest Run getters :1250 Runs,Highest half Centuries:20,
#         Runs, Highest Centuries : 5,Batting average : 68.33(2nd Highest), Strike rate: 102.33)
#      3. Subhman Gill has highest Batting average (61.84) since 2019.
#      4. Hardik Pandya has highest Strike Rate(104.82) Since 2019.
#      5. Virat kohli has highest Strike Rate(113.24) in 2023 for India.

# %% [markdown]
# ### Bowling Stats (Team India)

# %%
ODI_19_IND_bl=ODI_19[ODI_19.bowling_team=='India']
ODI_19_IND_bl
# Out:
#         Source.Name  match_id   season start_date  \
# 134516  1144490.csv   1144490     2019 2019-06-05
# 134517  1144490.csv   1144490     2019 2019-06-05
# 134518  1144490.csv   1144490     2019 2019-06-05
# 134519  1144490.csv   1144490     2019 2019-06-05
# 134520  1144490.csv   1144490     2019 2019-06-05
# ...             ...       ...      ...        ...
# 450495  1389389.csv   1389389  2023/24 2023-09-24
# 450496  1389389.csv   1389389  2023/24 2023-09-24
# 450497  1389389.csv   1389389  2023/24 2023-09-24
# 450498  1389389.csv   1389389  2023/24 2023-09-24
# 450499  1389389.csv   1389389  2023/24 2023-09-24
#
#                                  venue  innings  ball  batting_team  \
# 134516                   The Rose Bowl        1   0.1  South Africa
# 134517                   The Rose Bowl        1   0.2  South Africa
# 134518                   The Rose Bowl        1   0.3  South Africa
# 134519                   The Rose Bowl        1   0.4  South Africa
# ...

# %%
ODI_23_IND_bl=ODI_23[ODI_23.bowling_team=='India']
ODI_23_IND_bl
# Out:
#         Source.Name  match_id   season start_date  \
# 387308  1348643.csv   1348643  2022/23 2023-01-10
# 387309  1348643.csv   1348643  2022/23 2023-01-10
# 387310  1348643.csv   1348643  2022/23 2023-01-10
# 387311  1348643.csv   1348643  2022/23 2023-01-10
# 387312  1348643.csv   1348643  2022/23 2023-01-10
# ...             ...       ...      ...        ...
# 450495  1389389.csv   1389389  2023/24 2023-09-24
# 450496  1389389.csv   1389389  2023/24 2023-09-24
# 450497  1389389.csv   1389389  2023/24 2023-09-24
# 450498  1389389.csv   1389389  2023/24 2023-09-24
# 450499  1389389.csv   1389389  2023/24 2023-09-24
#
#                                       venue  innings  ball batting_team  \
# 387308  Barsapara Cricket Stadium, Guwahati        2   0.1    Sri Lanka
# 387309  Barsapara Cricket Stadium, Guwahati        2   0.2    Sri Lanka
# 387310  Barsapara Cricket Stadium, Guwahati        2   0.3    Sri Lanka
# ...

# %%
ODI_19_IND_BALL=pd.pivot_table(ODI_19_IND_bl,index=["match_id","bowler"],
                              values=["runs_off_bat","ball","player_dismissed"],
               aggfunc={"runs_off_bat":"sum","ball":"count","player_dismissed":"count"})
ODI_19_IND_BALL.rename(columns={"runs_off_bat":"Runs Conceeded","ball":"Balls Delivered","player_dismissed":"Dismissals"},
                 inplace=True)
ODI_19_IND_BALL_P=pd.pivot_table(ODI_19_IND_BALL,index=['bowler'],
                                 values=["Runs Conceeded","Balls Delivered","Dismissals"],aggfunc="sum")
ODI_19_IND_BALL_P["Economy"]=round(ODI_19_IND_BALL_P["Runs Conceeded"]/ODI_19_IND_BALL_P["Balls Delivered"]*6,2)
ODI_19_IND_BALL_P["Bowling Average"]=round(ODI_19_IND_BALL_P["Runs Conceeded"]/ODI_19_IND_BALL_P["Dismissals"],2)
ODI_19_IND_BALL_P["Bowling Strike Rate"]=round(ODI_19_IND_BALL_P["Balls Delivered"]/ODI_19_IND_BALL_P["Dismissals"],2)
ODI_19_IND_BALL_P
# Out:
#                    Balls Delivered  Dismissals  Runs Conceeded  Economy  \
# bowler
# AR Patel                       606          15             486     4.81
# AT Rayudu                       12           0              13     6.50
# Arshdeep Singh                  82           0              86     6.29
# Avesh Khan                     221           3             206     5.59
# B Kumar                       1336          46            1121     5.03
# C Sakariya                      51           2              31     3.65
# DJ Hooda                       154           3             113     4.40
# DL Chahar                      506          16             432     5.12
# HH Pandya                     1382          40            1143     4.96
# J Yadav                         62           0              47     4.55
# JD Unadkat                      30           1              16     3.20
# JJ Bumrah                     1802          51            1350     4.50
# ...

# %%
ODI_19_IND_BALL=pd.pivot_table(ODI_19_IND_bl,index=["match_id","bowler"],
                              values=["runs_off_bat","ball","player_dismissed"],
               aggfunc={"runs_off_bat":"sum","ball":"count","player_dismissed":"count"})
ODI_19_IND_BALL.rename(columns={"runs_off_bat":"Runs Conceeded","ball":"Balls Delivered","player_dismissed":"Dismissals"},
                 inplace=True)
ODI_19_IND_BALL
# Out:
#                             Balls Delivered  Dismissals  Runs Conceeded
# match_id bowler
# 1144490  B Kumar                         62           2              42
#          HH Pandya                       36           0              31
#          JJ Bumrah                       60           2              35
#          KM Jadhav                       24           0              16
#          Kuldeep Yadav                   61           1              45
# ...                                     ...         ...             ...
# 1389389  M Prasidh Krishna               38           2              54
#          Mohammed Shami                  36           1              39
#          R Ashwin                        42           3              41
#          RA Jadeja                       32           3              42
#          SN Thakur                       25           1              34
#
# [478 rows x 3 columns]

# %%
ODI_23_IND_BALL=pd.pivot_table(ODI_23_IND_bl,index=["match_id","bowler"],
                              values=["runs_off_bat","ball","player_dismissed"],
               aggfunc={"runs_off_bat":"sum","ball":"count","player_dismissed":"count"})
ODI_23_IND_BALL.rename(columns={"runs_off_bat":"Runs Conceeded","ball":"Balls Delivered","player_dismissed":"Dismissals"},
                 inplace=True)
ODI_23_IND_BALL_P=pd.pivot_table(ODI_23_IND_BALL,index=['bowler'],
                                 values=["Runs Conceeded","Balls Delivered","Dismissals"],aggfunc="sum")
ODI_23_IND_BALL_P["Economy"]=round(ODI_23_IND_BALL_P["Runs Conceeded"]/ODI_23_IND_BALL_P["Balls Delivered"]*6,2)
ODI_23_IND_BALL_P["Bowling Average"]=round(ODI_23_IND_BALL_P["Runs Conceeded"]/ODI_23_IND_BALL_P["Dismissals"],2)
ODI_23_IND_BALL_P["Bowling Strike Rate"]=round(ODI_23_IND_BALL_P["Balls Delivered"]/ODI_23_IND_BALL_P["Dismissals"],2)
ODI_23_IND_BALL_P
# Out:
#                    Balls Delivered  Dismissals  Runs Conceeded  Economy  \
# bowler
# AR Patel                       254           5             230     5.43
# HH Pandya                      484          16             388     4.81
# JD Unadkat                      30           1              16     3.20
# JJ Bumrah                      167           5             105     3.77
# Kuldeep Yadav                  640          31             471     4.42
# M Prasidh Krishna               94           3              95     6.06
# Mohammed Shami                 520          21             430     4.96
# Mohammed Siraj                 498          30             359     4.33
# Mukesh Kumar                    98           4              61     3.73
# R Ashwin                       102           4              88     5.18
# RA Jadeja                      525          15             407     4.65
# SN Thakur                      443          21             430     5.82
# ...

# %%
ODI_23_IND_BALL=pd.pivot_table(ODI_23_IND_bl,index=["match_id","bowler"],
                              values=["runs_off_bat","ball","player_dismissed"],
               aggfunc={"runs_off_bat":"sum","ball":"count","player_dismissed":"count"})
ODI_23_IND_BALL.rename(columns={"runs_off_bat":"Runs Conceeded","ball":"Balls Delivered","player_dismissed":"Dismissals"},
                 inplace=True)
ODI_23_IND_BALL
# Out:
#                             Balls Delivered  Dismissals  Runs Conceeded
# match_id bowler
# 1348643  AR Patel                        60           0              58
#          HH Pandya                       38           1              31
#          Mohammed Shami                  56           1              64
#          Mohammed Siraj                  42           2              30
#          Umran Malik                     52           3              53
# ...                                     ...         ...             ...
# 1389389  M Prasidh Krishna               38           2              54
#          Mohammed Shami                  36           1              39
#          R Ashwin                        42           3              41
#          RA Jadeja                       32           3              42
#          SN Thakur                       25           1              34
#
# [108 rows x 3 columns]

# %%
ODI_19_IND_BALL_P_wicket=ODI_19_IND_BALL_P.sort_values(by='Dismissals',ascending=False).head(5)
ODI_19_IND_BALL_P_wicket
# Out:
#                 Balls Delivered  Dismissals  Runs Conceeded  Economy  \
# bowler
# Kuldeep Yadav              2845          87            2461     5.19
# Mohammed Shami             2110          82            1843     5.24
# YS Chahal                  1969          66            1810     5.52
# SN Thakur                  1694          59            1619     5.73
# Mohammed Siraj             1327          54             945     4.27
#
#                 Bowling Average  Bowling Strike Rate
# bowler
# Kuldeep Yadav             28.29                32.70
# Mohammed Shami            22.48                25.73
# YS Chahal                 27.42                29.83
# SN Thakur                 27.44                28.71
# Mohammed Siraj            17.50                24.57

# %%
ODI_23_IND_BALL_P_wicket=ODI_23_IND_BALL_P.sort_values(by='Dismissals',ascending=False).head(5)
ODI_23_IND_BALL_P_wicket
# Out:
#                 Balls Delivered  Dismissals  Runs Conceeded  Economy  \
# bowler
# Kuldeep Yadav               640          31             471     4.42
# Mohammed Siraj              498          30             359     4.33
# SN Thakur                   443          21             430     5.82
# Mohammed Shami              520          21             430     4.96
# HH Pandya                   484          16             388     4.81
#
#                 Bowling Average  Bowling Strike Rate
# bowler
# Kuldeep Yadav             15.19                20.65
# Mohammed Siraj            11.97                16.60
# SN Thakur                 20.48                21.10
# Mohammed Shami            20.48                24.76
# HH Pandya                 24.25                30.25

# %%
ODI_19_IND_BALL_P_eco=ODI_19_IND_BALL_P[ODI_19_IND_BALL_P["Balls Delivered"]>=750].sort_values(by='Economy',ascending=True).head(5)
ODI_19_IND_BALL_P_eco
# Out:
#                 Balls Delivered  Dismissals  Runs Conceeded  Economy  \
# bowler
# Mohammed Siraj             1327          54             945     4.27
# JJ Bumrah                  1802          51            1350     4.50
# RA Jadeja                  1897          39            1548     4.90
# HH Pandya                  1382          40            1143     4.96
# B Kumar                    1336          46            1121     5.03
#
#                 Bowling Average  Bowling Strike Rate
# bowler
# Mohammed Siraj            17.50                24.57
# JJ Bumrah                 26.47                35.33
# RA Jadeja                 39.69                48.64
# HH Pandya                 28.58                34.55
# B Kumar                   24.37                29.04

# %%
ODI_23_IND_BALL_P_eco=ODI_23_IND_BALL_P[ODI_23_IND_BALL_P["Balls Delivered"]>=150].sort_values(by='Economy',ascending=True).head(5)
ODI_23_IND_BALL_P_eco
# Out:
#                 Balls Delivered  Dismissals  Runs Conceeded  Economy  \
# bowler
# JJ Bumrah                   167           5             105     3.77
# Mohammed Siraj              498          30             359     4.33
# Kuldeep Yadav               640          31             471     4.42
# RA Jadeja                   525          15             407     4.65
# HH Pandya                   484          16             388     4.81
#
#                 Bowling Average  Bowling Strike Rate
# bowler
# JJ Bumrah                 21.00                33.40
# Mohammed Siraj            11.97                16.60
# Kuldeep Yadav             15.19                20.65
# RA Jadeja                 27.13                35.00
# HH Pandya                 24.25                30.25

# %%
ODI_19_IND_BALL_P_bavg=ODI_19_IND_BALL_P[ODI_19_IND_BALL_P["Balls Delivered"]>=750].sort_values(by='Bowling Average',ascending=True).head(5)
ODI_19_IND_BALL_P_bavg
# Out:
#                    Balls Delivered  Dismissals  Runs Conceeded  Economy  \
# bowler
# Mohammed Siraj                1327          54             945     4.27
# Mohammed Shami                2110          82            1843     5.24
# M Prasidh Krishna              787          29             670     5.11
# B Kumar                       1336          46            1121     5.03
# JJ Bumrah                     1802          51            1350     4.50
#
#                    Bowling Average  Bowling Strike Rate
# bowler
# Mohammed Siraj               17.50                24.57
# Mohammed Shami               22.48                25.73
# M Prasidh Krishna            23.10                27.14
# B Kumar                      24.37                29.04
# JJ Bumrah                    26.47                35.33

# %%
ODI_23_IND_BALL_P_bavg=ODI_23_IND_BALL_P[ODI_23_IND_BALL_P["Balls Delivered"]>=150].sort_values(by='Bowling Average',ascending=True).head(5)
ODI_23_IND_BALL_P_bavg
# Out:
#                 Balls Delivered  Dismissals  Runs Conceeded  Economy  \
# bowler
# Mohammed Siraj              498          30             359     4.33
# Kuldeep Yadav               640          31             471     4.42
# Mohammed Shami              520          21             430     4.96
# SN Thakur                   443          21             430     5.82
# JJ Bumrah                   167           5             105     3.77
#
#                 Bowling Average  Bowling Strike Rate
# bowler
# Mohammed Siraj            11.97                16.60
# Kuldeep Yadav             15.19                20.65
# Mohammed Shami            20.48                24.76
# SN Thakur                 20.48                21.10
# JJ Bumrah                 21.00                33.40

# %%
ODI_19_IND_BALL_P_bSR=ODI_19_IND_BALL_P[ODI_19_IND_BALL_P["Balls Delivered"]>=750].sort_values(by='Bowling Strike Rate',ascending=True).head(5)
ODI_19_IND_BALL_P_bSR
# Out:
#                    Balls Delivered  Dismissals  Runs Conceeded  Economy  \
# bowler
# Mohammed Siraj                1327          54             945     4.27
# Mohammed Shami                2110          82            1843     5.24
# M Prasidh Krishna              787          29             670     5.11
# SN Thakur                     1694          59            1619     5.73
# B Kumar                       1336          46            1121     5.03
#
#                    Bowling Average  Bowling Strike Rate
# bowler
# Mohammed Siraj               17.50                24.57
# Mohammed Shami               22.48                25.73
# M Prasidh Krishna            23.10                27.14
# SN Thakur                    27.44                28.71
# B Kumar                      24.37                29.04

# %%
ODI_23_IND_BALL_P_bSR=ODI_23_IND_BALL_P[ODI_23_IND_BALL_P["Balls Delivered"]>=150].sort_values(by='Bowling Strike Rate',ascending=True).head(5)
ODI_23_IND_BALL_P_bSR
# Out:
#                 Balls Delivered  Dismissals  Runs Conceeded  Economy  \
# bowler
# Mohammed Siraj              498          30             359     4.33
# Kuldeep Yadav               640          31             471     4.42
# SN Thakur                   443          21             430     5.82
# Mohammed Shami              520          21             430     4.96
# Umran Malik                 176           6             193     6.58
#
#                 Bowling Average  Bowling Strike Rate
# bowler
# Mohammed Siraj            11.97                16.60
# Kuldeep Yadav             15.19                20.65
# SN Thakur                 20.48                21.10
# Mohammed Shami            20.48                24.76
# Umran Malik               32.17                29.33

# %%
ODI_19_IND_BALL_3=pd.pivot_table(ODI_19_IND_BALL[ODI_19_IND_BALL['Dismissals']>=3],index=['bowler'],values=['Dismissals'],
               aggfunc={'Dismissals':'count'})
ODI_19_IND_BALL_3.rename(columns={'Dismissals':'Dismissals(atleast 3)'},inplace=True)
ODI_19_IND_BALL_3=ODI_19_IND_BALL_3.sort_values(by='Dismissals(atleast 3)',ascending=False).head(5)
ODI_19_IND_BALL_3
# Out:
#                 Dismissals(atleast 3)
# bowler
# Mohammed Shami                     14
# Kuldeep Yadav                      12
# SN Thakur                          10
# YS Chahal                          10
# Mohammed Siraj                      9

# %%
ODI_23_IND_BALL_3=pd.pivot_table(ODI_23_IND_BALL[ODI_23_IND_BALL['Dismissals']>=3],index=['bowler'],values=['Dismissals'],
               aggfunc={'Dismissals':'count'})
ODI_23_IND_BALL_3.rename(columns={'Dismissals':'Dismissals(atleast 3)'},inplace=True)
ODI_23_IND_BALL_3=ODI_23_IND_BALL_3.sort_values(by='Dismissals(atleast 3)',ascending=False).head(5)
ODI_23_IND_BALL_3
# Out:
#                 Dismissals(atleast 3)
# bowler
# Kuldeep Yadav                       6
# Mohammed Siraj                      6
# SN Thakur                           4
# Mohammed Shami                      3
# RA Jadeja                           3

# %%
plt.subplot(5,2,1)
ODI_19_IND_BALL_P_wicket['Dismissals'].plot(kind='bar',figsize=(12,5),color='orange')
for i in range(len(list(ODI_19_IND_BALL_P_wicket.index))):
    plt.text(i,ODI_19_IND_BALL_P_wicket['Dismissals'][i],ODI_19_IND_BALL_P_wicket['Dismissals'][i],ha='center')
plt.title('Top Wicket Takers of India(Since 2019)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Wickets Taken')
plt.subplot(5,2,2)
ODI_23_IND_BALL_P_wicket['Dismissals'].plot(kind='bar',figsize=(12,5),color='orange')
for i in range(len(list(ODI_23_IND_BALL_P_wicket.index))):
    plt.text(i,ODI_23_IND_BALL_P_wicket['Dismissals'][i],ODI_23_IND_BALL_P_wicket['Dismissals'][i],ha='center')
plt.title('Top Wicket Takers of India(In 2023)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Wickets Taken')
plt.subplot(5,2,3)
ODI_19_IND_BALL_P_eco['Economy'].plot(kind='bar',figsize=(12,5),color='green')
for i in range(len(list(ODI_19_IND_BALL_P_eco.index))):
    plt.text(i,ODI_19_IND_BALL_P_eco['Economy'][i],ODI_19_IND_BALL_P_eco['Economy'][i],ha='center')
plt.title('Least Economical bowlers(atleast 750 balls delivered) of India(Since 2019)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Economy')
plt.subplot(5,2,4)
ODI_23_IND_BALL_P_eco['Economy'].plot(kind='bar',figsize=(12,5),color='green')
for i in range(len(list(ODI_23_IND_BALL_P_eco.index))):
    plt.text(i,ODI_23_IND_BALL_P_eco['Economy'][i],ODI_23_IND_BALL_P_eco['Economy'][i],ha='center')
plt.title('Least Economical bowlers(atleast 150 balls delivered) of India(In 2023)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Economy')
plt.subplot(5,2,5)
ODI_19_IND_BALL_P_bavg['Bowling Average'].plot(kind='bar',figsize=(12,5),color='yellow')
for i in range(len(list(ODI_19_IND_BALL_P_bavg.index))):
    plt.text(i,ODI_19_IND_BALL_P_bavg['Bowling Average'][i],ODI_19_IND_BALL_P_bavg['Bowling Average'][i],ha='center')
plt.title('Least Bowling Average(atleast 750 balls delivered) of India(Since 2019)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Bowling Average')
plt.subplot(5,2,6)
ODI_23_IND_BALL_P_bavg['Bowling Average'].plot(kind='bar',figsize=(12,5),color='yellow')
for i in range(len(list(ODI_23_IND_BALL_P_bavg.index))):
    plt.text(i,ODI_23_IND_BALL_P_bavg['Bowling Average'][i],ODI_23_IND_BALL_P_bavg['Bowling Average'][i],ha='center')
plt.title('Least Bowling Average(atleast 750 balls delivered) of India(In 2023)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Bowling Average')
plt.subplot(5,2,7)
ODI_19_IND_BALL_P_bSR['Bowling Strike Rate'].plot(kind='bar',figsize=(12,5),color='brown')
for i in range(len(list(ODI_19_IND_BALL_P_bSR.index))):
    plt.text(i,ODI_19_IND_BALL_P_bSR['Bowling Strike Rate'][i],ODI_19_IND_BALL_P_bSR['Bowling Strike Rate'][i],ha='center')
plt.title('Least Bowling Strike Rate(atleast 750 balls delivered) of India(Since 2019)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Bowling Strike Rate')
plt.subplot(5,2,8)
ODI_23_IND_BALL_P_bSR['Bowling Strike Rate'].plot(kind='bar',figsize=(12,5),color='brown')
for i in range(len(list(ODI_23_IND_BALL_P_bSR.index))):
    plt.text(i,ODI_23_IND_BALL_P_bSR['Bowling Strike Rate'][i],ODI_23_IND_BALL_P_bSR['Bowling Strike Rate'][i],ha='center')
plt.title('Least Bowling Strike Rate(atleast 150 balls delivered) of India(In 2023)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Bowling Strike Rate')
plt.subplot(5,2,9)
ODI_19_IND_BALL_3['Dismissals(atleast 3)'].plot(kind='bar',figsize=(12,5),color='blue')
for i in range(len(list(ODI_19_IND_BALL_3.index))):
    plt.text(i,ODI_19_IND_BALL_3['Dismissals(atleast 3)'][i],ODI_19_IND_BALL_3['Dismissals(atleast 3)'][i],ha='center')
plt.title('Top Multiple Wicket Takers (atleast 3)of India(Since 2019)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Dismissals(atleast 3)')
plt.subplot(5,2,10)
ODI_23_IND_BALL_3['Dismissals(atleast 3)'].plot(kind='bar',figsize=(12,5),color='blue')
for i in range(len(list(ODI_23_IND_BALL_3.index))):
    plt.text(i,ODI_23_IND_BALL_3['Dismissals(atleast 3)'][i],ODI_23_IND_BALL_3['Dismissals(atleast 3)'][i],ha='center')
plt.title('Top Multiple Wicket Takers (atleast 3)of India(In 2023)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Dismissals(atleast 3)')
plt.subplots_adjust(left=0.1,bottom=0.01, right=1.5, top=4.5, wspace=0.4, hspace=0.8)
plt.show()

# %% [markdown]
# **Caution**
#
#     1. Yuzi Chahal, Bhubaneshwar Kumar, Umran Malik and Prasidh Krishna not get much chances to perform in 2023. They might        not be in the scheme of BCCI for 2033 world Cup.
#     2. Kuldeep Yadav was out of perform after 2019 ODI world Cup and make a great comeback in 2023.
#     3. Mohammad Siraj improved himself as a top performer within a year. He has bowled an exceptional spell against                SriLanka in 2023 ODI Asia Cup Final.
#     4. Jasprit Bumrah was out of ground for couple of months due to injury.

# %% [markdown]
# **Bowling Stats (Info)**
#
#     1. Kuldeep Yadav (87 wickets) and Mohammad Shami(82 wickets) is the top most wicket takers for India since 2019 world          Cup.
#     2. Mohammad Siraj (2nd Highest Wicket takers: 30, 2nd least economy: 4.33, Least bowling Average: 11.97, Least Bowling        Strike Rate: 16.6, 6 Three wicket's haul(Highest)) and Kuldeep Yadav (Highest Wicket takers: 31, economy: 4.42, 2nd        least bowling Average: 15.19, 2nd least Bowling Strike Rate: 20.65, 6 Three wicket's haul(Highest)) are Star                performers for India in 2023.
#     3. Mohammad Siraj has least econmy(4.27), bowling average(17.5) and bowling Strike rate(24.67) for India since 2019.
#     4. Jasprit Bumrah has least economy(3.77) in 2023 for India.
#     5. Mohammad Shami has taken most numbers of 3 wickets haul(14) since 2019.

# %% [markdown]
# **Playing 11 Structure:**
#
#     * Check all the following criteria in Indian Ground Also [As 2023 world cup is hosted by India]
#
#     1. Openers(Have good Strike rate and Batting Average in 1st powerplay(1-10 overs);
#                ability of hitting boundaries in 1st powerplay(0-10 overs))
#     2. Middle Orders(have good Strike Rate and Batting Average in 2nd powreplay(11-40 overs);
#                     ability of running between the wickets in 2nd powreplay(11-40 overs))
#     3. AllRounders (have high strike rate in 3rd powerplay (41-50 overs);
#                  ability of hitting sixes in 3rd powerplay (41-50 overs);
#                    ability of taking wickets with good bowling figures)
#     4. Wicket Taking Seamers in 1st powerplay (have good economy and wicket taking ability in (1-10) overs)
#     5. Wicket Taking Bowlers (Specially Spinners in Indian Conditions) in middle overs (have good bowling figures)
#     6. Gun Death Bowlers (have least economy and ability of wicket taking)

# %% [markdown]
# ### Openers

# %%
ODI_19_IND_bt_pp1=ODI_19_IND_bt[ODI_19_IND_bt['Overs']<=10]
ODI_19_IND_bt_pp1
# Out:
#         Source.Name  match_id   season start_date  \
# 134822  1144490.csv   1144490     2019 2019-06-05
# 134823  1144490.csv   1144490     2019 2019-06-05
# 134824  1144490.csv   1144490     2019 2019-06-05
# 134825  1144490.csv   1144490     2019 2019-06-05
# 134826  1144490.csv   1144490     2019 2019-06-05
# ...             ...       ...      ...        ...
# 450073  1389389.csv   1389389  2023/24 2023-09-24
# 450074  1389389.csv   1389389  2023/24 2023-09-24
# 450075  1389389.csv   1389389  2023/24 2023-09-24
# 450076  1389389.csv   1389389  2023/24 2023-09-24
# 450077  1389389.csv   1389389  2023/24 2023-09-24
#
#                                  venue  innings  ball batting_team  \
# 134822                   The Rose Bowl        2   0.1        India
# 134823                   The Rose Bowl        2   0.2        India
# 134824                   The Rose Bowl        2   0.3        India
# 134825                   The Rose Bowl        2   0.4        India
# ...

# %%
ODI_19_IND_BAT_pp1=pd.pivot_table(ODI_19_IND_bt_pp1,index=["match_id","striker"],
                              values=["runs_off_bat","ball","player_dismissed"],
               aggfunc={"runs_off_bat":"sum","ball":"count","player_dismissed":"count"})
ODI_19_IND_BAT_pp1.rename(columns={"runs_off_bat":"Runs Scored","ball":"Balls Faced","player_dismissed":"Dismissals"},
                 inplace=True)
ODI_19_IND_BAT_pp1
# Out:
#                        Balls Faced  Dismissals  Runs Scored
# match_id striker
# 1144490  RG Sharma              32           0           21
#          S Dhawan               12           1            8
#          V Kohli                17           0            4
# 1144496  RG Sharma              25           0           11
#          S Dhawan               36           0           27
# ...                            ...         ...          ...
# 1389388  RD Gaikwad             37           0           32
#          Shubman Gill           24           0           32
# 1389389  RD Gaikwad             13           1            8
#          SS Iyer                20           0           34
#          Shubman Gill           28           0           33
#
# [266 rows x 3 columns]

# %%
ODI_23_IND_bt_pp1=ODI_23_IND_bt[ODI_23_IND_bt['Overs']<=10]
ODI_23_IND_bt_pp1
# Out:
#         Source.Name  match_id   season start_date  \
# 387003  1348643.csv   1348643  2022/23 2023-01-10
# 387004  1348643.csv   1348643  2022/23 2023-01-10
# 387005  1348643.csv   1348643  2022/23 2023-01-10
# 387006  1348643.csv   1348643  2022/23 2023-01-10
# 387007  1348643.csv   1348643  2022/23 2023-01-10
# ...             ...       ...      ...        ...
# 450073  1389389.csv   1389389  2023/24 2023-09-24
# 450074  1389389.csv   1389389  2023/24 2023-09-24
# 450075  1389389.csv   1389389  2023/24 2023-09-24
# 450076  1389389.csv   1389389  2023/24 2023-09-24
# 450077  1389389.csv   1389389  2023/24 2023-09-24
#
#                                       venue  innings  ball batting_team  \
# 387003  Barsapara Cricket Stadium, Guwahati        1   0.1        India
# 387004  Barsapara Cricket Stadium, Guwahati        1   0.2        India
# 387005  Barsapara Cricket Stadium, Guwahati        1   0.3        India
# ...

# %%
ODI_23_IND_BAT_pp1=pd.pivot_table(ODI_23_IND_bt_pp1,index=["match_id","striker"],
                              values=["runs_off_bat","ball","player_dismissed"],
               aggfunc={"runs_off_bat":"sum","ball":"count","player_dismissed":"count"})
ODI_23_IND_BAT_pp1.rename(columns={"runs_off_bat":"Runs Scored","ball":"Balls Faced","player_dismissed":"Dismissals"},
                 inplace=True)
ODI_23_IND_BAT_pp1
# Out:
#                        Balls Faced  Dismissals  Runs Scored
# match_id striker
# 1348643  RG Sharma              33           0           44
#          Shubman Gill           27           0           31
# 1348644  KL Rahul                2           0            5
#          RG Sharma              22           1           17
#          SS Iyer                16           0           13
#          Shubman Gill           12           1           21
#          V Kohli                13           1            4
# 1348645  RG Sharma              32           0           36
#          Shubman Gill           28           0           35
# 1348646  RG Sharma              33           0           27
#          Shubman Gill           31           0           21
# 1348647  RG Sharma              40           0           38
#          Shubman Gill           20           0           14
# 1348648  RG Sharma              32           0           39
# ...

# %%
ODI_19_IND_BAT_pp1=pd.pivot_table(ODI_19_IND_bt_pp1,index=["match_id","striker"],
                              values=["runs_off_bat","ball","player_dismissed"],
               aggfunc={"runs_off_bat":"sum","ball":"count","player_dismissed":"count"})
ODI_19_IND_BAT_pp1.rename(columns={"runs_off_bat":"Runs Scored","ball":"Balls Faced","player_dismissed":"Dismissals"},
                 inplace=True)
ODI_19_IND_BAT_P_pp1=pd.pivot_table(ODI_19_IND_BAT_pp1,index=['striker'],values=["Runs Scored","Balls Faced","Dismissals"],aggfunc="sum")
ODI_19_IND_BAT_P_pp1["Strike Rate"]=round(ODI_19_IND_BAT_P_pp1["Runs Scored"]/ODI_19_IND_BAT_P_pp1["Balls Faced"]*100,2)
ODI_19_IND_BAT_P_pp1["Batting Average"]=round(ODI_19_IND_BAT_P_pp1["Runs Scored"]/ODI_19_IND_BAT_P_pp1["Dismissals"],2)
ODI_19_IND_BAT_P_pp1
# Out:
#                    Balls Faced  Dismissals  Runs Scored  Strike Rate  \
# striker
# AT Rayudu                   32           2            4        12.50
# HH Pandya                    3           1            1        33.33
# Ishan Kishan               255           2          203        79.61
# KD Karthik                  25           1            6        24.00
# KL Rahul                   439           7          286        65.15
# MA Agarwal                  91           5           86        94.51
# MK Pandey                   15           0           13        86.67
# MS Dhoni                    42           1           13        30.95
# PP Shaw                    151           4          167       110.60
# RA Jadeja                    4           0            2        50.00
# RD Gaikwad                  71           1           46        64.79
# RG Sharma                 1331          20         1072        80.54
# ...

# %%
ODI_23_IND_BAT_pp1=pd.pivot_table(ODI_23_IND_bt_pp1,index=["match_id","striker"],
                              values=["runs_off_bat","ball","player_dismissed"],
               aggfunc={"runs_off_bat":"sum","ball":"count","player_dismissed":"count"})
ODI_23_IND_BAT_pp1.rename(columns={"runs_off_bat":"Runs Scored","ball":"Balls Faced","player_dismissed":"Dismissals"},
                 inplace=True)
ODI_23_IND_BAT_P_pp1=pd.pivot_table(ODI_23_IND_BAT_pp1,index=['striker'],values=["Runs Scored","Balls Faced","Dismissals"],aggfunc="sum")
ODI_23_IND_BAT_P_pp1["Strike Rate"]=round(ODI_23_IND_BAT_P_pp1["Runs Scored"]/ODI_23_IND_BAT_P_pp1["Balls Faced"]*100,2)
ODI_23_IND_BAT_P_pp1["Batting Average"]=round(ODI_23_IND_BAT_P_pp1["Runs Scored"]/ODI_23_IND_BAT_P_pp1["Dismissals"],2)
ODI_23_IND_BAT_P_pp1
# Out:
#               Balls Faced  Dismissals  Runs Scored  Strike Rate  \
# striker
# HH Pandya               3           1            1        33.33
# Ishan Kishan          117           1          106        90.60
# KL Rahul               52           1           34        65.38
# RA Jadeja               4           0            2        50.00
# RD Gaikwad             50           1           40        80.00
# RG Sharma             355           5          342        96.34
# SA Yadav               22           2           15        68.18
# SS Iyer                46           1           61       132.61
# Shubman Gill          511           3          486        95.11
# Tilak Varma            10           1            5        50.00
# V Kohli                58           3           35        60.34
#
#               Batting Average
# striker
# HH Pandya                1.00
# Ishan Kishan           106.00
# KL Rahul                34.00
# RA Jadeja                 inf
# ...

# %%
ODI_19_IND_BAT_P_pp1_runs=ODI_19_IND_BAT_P_pp1.sort_values(by='Runs Scored',ascending=False).head(5)
ODI_19_IND_BAT_P_pp1_runs
# Out:
#               Balls Faced  Dismissals  Runs Scored  Strike Rate  \
# striker
# RG Sharma            1331          20         1072        80.54
# S Dhawan             1195          27          891        74.56
# Shubman Gill          847           7          773        91.26
# V Kohli               512          12          374        73.05
# KL Rahul              439           7          286        65.15
#
#               Batting Average
# striker
# RG Sharma               53.60
# S Dhawan                33.00
# Shubman Gill           110.43
# V Kohli                 31.17
# KL Rahul                40.86

# %%
ODI_23_IND_BAT_P_pp1_runs=ODI_23_IND_BAT_P_pp1.sort_values(by='Runs Scored',ascending=False).head(5)
ODI_23_IND_BAT_P_pp1_runs
# Out:
#               Balls Faced  Dismissals  Runs Scored  Strike Rate  \
# striker
# Shubman Gill          511           3          486        95.11
# RG Sharma             355           5          342        96.34
# Ishan Kishan          117           1          106        90.60
# SS Iyer                46           1           61       132.61
# RD Gaikwad             50           1           40        80.00
#
#               Batting Average
# striker
# Shubman Gill            162.0
# RG Sharma                68.4
# Ishan Kishan            106.0
# SS Iyer                  61.0
# RD Gaikwad               40.0

# %%
ODI_19_IND_BAT_P_pp1_avg=ODI_19_IND_BAT_P_pp1[ODI_19_IND_BAT_P_pp1["Balls Faced"]>=350].sort_values(by='Batting Average',ascending=False).head()
ODI_19_IND_BAT_P_pp1_avg
# Out:
#               Balls Faced  Dismissals  Runs Scored  Strike Rate  \
# striker
# Shubman Gill          847           7          773        91.26
# RG Sharma            1331          20         1072        80.54
# KL Rahul              439           7          286        65.15
# S Dhawan             1195          27          891        74.56
# V Kohli               512          12          374        73.05
#
#               Batting Average
# striker
# Shubman Gill           110.43
# RG Sharma               53.60
# KL Rahul                40.86
# S Dhawan                33.00
# V Kohli                 31.17

# %%
ODI_23_IND_BAT_P_pp1_avg=ODI_23_IND_BAT_P_pp1[ODI_23_IND_BAT_P_pp1["Balls Faced"]>=100].sort_values(by='Batting Average',ascending=False).head()
ODI_23_IND_BAT_P_pp1_avg
# Out:
#               Balls Faced  Dismissals  Runs Scored  Strike Rate  \
# striker
# Shubman Gill          511           3          486        95.11
# Ishan Kishan          117           1          106        90.60
# RG Sharma             355           5          342        96.34
#
#               Batting Average
# striker
# Shubman Gill            162.0
# Ishan Kishan            106.0
# RG Sharma                68.4

# %%
ODI_19_IND_BAT_P_pp1_SR=ODI_19_IND_BAT_P_pp1[ODI_19_IND_BAT_P_pp1["Balls Faced"]>=350].sort_values(by='Strike Rate',ascending=False).head(5)
ODI_19_IND_BAT_P_pp1_SR
# Out:
#               Balls Faced  Dismissals  Runs Scored  Strike Rate  \
# striker
# Shubman Gill          847           7          773        91.26
# RG Sharma            1331          20         1072        80.54
# S Dhawan             1195          27          891        74.56
# V Kohli               512          12          374        73.05
# KL Rahul              439           7          286        65.15
#
#               Batting Average
# striker
# Shubman Gill           110.43
# RG Sharma               53.60
# S Dhawan                33.00
# V Kohli                 31.17
# KL Rahul                40.86

# %%
ODI_23_IND_BAT_P_pp1_SR=ODI_23_IND_BAT_P_pp1[ODI_23_IND_BAT_P_pp1["Balls Faced"]>=100].sort_values(by='Strike Rate',ascending=False).head(5)
ODI_23_IND_BAT_P_pp1_SR
# Out:
#               Balls Faced  Dismissals  Runs Scored  Strike Rate  \
# striker
# RG Sharma             355           5          342        96.34
# Shubman Gill          511           3          486        95.11
# Ishan Kishan          117           1          106        90.60
#
#               Batting Average
# striker
# RG Sharma                68.4
# Shubman Gill            162.0
# Ishan Kishan            106.0

# %%
ODI_19_IND_BAT_pp1_4=pd.pivot_table(ODI_19_IND_bt_pp1[ODI_19_IND_bt_pp1['runs_off_bat']==4],index='striker',values='runs_off_bat',aggfunc={'runs_off_bat':'count'})
ODI_19_IND_BAT_pp1_4.rename(columns={'runs_off_bat':'Boundaries'},inplace=True)
ODI_19_IND_BAT_pp1_4['Boundaries per Ball']=round(ODI_19_IND_BAT_pp1_4['Boundaries']/ODI_19_IND_BAT_P_pp1['Balls Faced'],3)
ODI_19_IND_BAT_pp1_4=ODI_19_IND_BAT_pp1_4[ODI_19_IND_BAT_pp1_4['Boundaries']>=50].sort_values(by='Boundaries per Ball',ascending=False).head(5)
ODI_19_IND_BAT_pp1_4
# Out:
#               Boundaries  Boundaries per Ball
# striker
# Shubman Gill         116                0.137
# S Dhawan             132                0.110
# RG Sharma            145                0.109
# V Kohli               50                0.098

# %%
ODI_23_IND_BAT_pp1_4=pd.pivot_table(ODI_23_IND_bt_pp1[ODI_23_IND_bt_pp1['runs_off_bat']==4],index='striker',values='runs_off_bat',aggfunc={'runs_off_bat':'count'})
ODI_23_IND_BAT_pp1_4.rename(columns={'runs_off_bat':'Boundaries'},inplace=True)
ODI_23_IND_BAT_pp1_4['Boundaries per Ball']=round(ODI_23_IND_BAT_pp1_4['Boundaries']/ODI_23_IND_BAT_P_pp1['Balls Faced'],3)
ODI_23_IND_BAT_pp1_4=ODI_23_IND_BAT_pp1_4[ODI_23_IND_BAT_pp1_4['Boundaries']>=15].sort_values(by='Boundaries per Ball',ascending=False).head(5)
ODI_23_IND_BAT_pp1_4
# Out:
#               Boundaries  Boundaries per Ball
# striker
# Shubman Gill          81                0.159
# Ishan Kishan          15                0.128
# RG Sharma             40                0.113

# %%
plt.subplot(4,2,1)
ODI_19_IND_BAT_P_pp1_runs['Runs Scored'].plot(kind='bar',figsize=(12,5),color='pink')
for i in range(len(list(ODI_19_IND_BAT_P_pp1_runs.index))):
    plt.text(i,ODI_19_IND_BAT_P_pp1_runs['Runs Scored'][i],ODI_19_IND_BAT_P_pp1_runs['Runs Scored'][i],ha='center')
plt.title('Top Runs Scorers [1-10 overs] of India(Since 2019)')
plt.xlabel('Batter')
plt.xticks(rotation=0)
plt.ylabel('Runs Scored')
plt.subplot(4,2,2)
ODI_23_IND_BAT_P_pp1_runs['Runs Scored'].plot(kind='bar',figsize=(12,5),color='pink')
for i in range(len(list(ODI_23_IND_BAT_P_pp1_runs.index))):
    plt.text(i,ODI_23_IND_BAT_P_pp1_runs['Runs Scored'][i],ODI_23_IND_BAT_P_pp1_runs['Runs Scored'][i],ha='center')
plt.title('Top Runs Scorers [1-10 overs] of India(In 2023)')
plt.xlabel('Batter')
plt.xticks(rotation=0)
plt.ylabel('Runs Scored')
plt.subplot(4,2,3)
ODI_19_IND_BAT_P_pp1_avg['Batting Average'].plot(kind='bar',figsize=(12,5),color='blue')
for i in range(len(list(ODI_19_IND_BAT_P_pp1_avg.index))):
    plt.text(i,ODI_19_IND_BAT_P_pp1_avg['Batting Average'][i],ODI_19_IND_BAT_P_pp1_avg['Batting Average'][i],ha='center')
plt.title('Top Batting Average [1-10 overs](played atleast 350 balls) of India(Since 2019)')
plt.xlabel('Batter')
plt.xticks(rotation=0)
plt.ylabel('Batting Average')
plt.subplot(4,2,4)
ODI_23_IND_BAT_P_pp1_avg['Batting Average'].plot(kind='bar',figsize=(12,5),color='blue')
for i in range(len(list(ODI_23_IND_BAT_P_pp1_avg.index))):
    plt.text(i,ODI_23_IND_BAT_P_pp1_avg['Batting Average'][i],ODI_23_IND_BAT_P_pp1_avg['Batting Average'][i],ha='center')
plt.title('Top Batting Average [1-10 overs](played atleast 100 balls) of India(In 2023)')
plt.xlabel('Batter')
plt.xticks(rotation=0)
plt.ylabel('Batiing Average')
plt.subplot(4,2,5)
ODI_19_IND_BAT_P_pp1_SR['Strike Rate'].plot(kind='bar',figsize=(12,5),color='violet')
for i in range(len(list(ODI_19_IND_BAT_P_pp1_SR.index))):
    plt.text(i,ODI_19_IND_BAT_P_pp1_SR['Strike Rate'][i],ODI_19_IND_BAT_P_pp1_SR['Strike Rate'][i],ha='center')
plt.title('Top Strike Rate [1-10 overs](played atleast 350 balls) of India(Since 2019)')
plt.xlabel('Batter')
plt.xticks(rotation=0)
plt.ylabel('Strike Rate')
plt.subplot(4,2,6)
ODI_23_IND_BAT_P_pp1_SR['Strike Rate'].plot(kind='bar',figsize=(12,5),color='violet')
for i in range(len(list(ODI_23_IND_BAT_P_pp1_SR.index))):
    plt.text(i,ODI_23_IND_BAT_P_pp1_SR['Strike Rate'][i],ODI_23_IND_BAT_P_pp1_SR['Strike Rate'][i],ha='center')
plt.title('Top Strike Rate [1-10 overs](played atleast 100 balls) of India(In 2023)')
plt.xlabel('Batter')
plt.xticks(rotation=0)
plt.ylabel('Strike Rate')    
plt.subplots_adjust(left=0.1,bottom=0.01, right=1.1, top=2, wspace=0.4, hspace=0.6)
plt.subplot(4,2,7)
ODI_19_IND_BAT_pp1_4['Boundaries per Ball'].plot(kind='bar',figsize=(12,5),color='green')
for i in range(len(list(ODI_19_IND_BAT_pp1_4.index))):
    plt.text(i,ODI_19_IND_BAT_pp1_4['Boundaries per Ball'][i],ODI_19_IND_BAT_pp1_4['Boundaries per Ball'][i],ha='center')
plt.title('Boundaries per Ball [1-10 overs](atleast hit 40 boundaries) of India(Since 2019)')
plt.xlabel('Batter')
plt.xticks(rotation=0)
plt.ylabel('Boundaries per Ball')
plt.subplot(4,2,8)
ODI_23_IND_BAT_pp1_4['Boundaries per Ball'].plot(kind='bar',figsize=(12,5),color='green')
for i in range(len(list(ODI_23_IND_BAT_pp1_4.index))):
    plt.text(i,ODI_23_IND_BAT_pp1_4['Boundaries per Ball'][i],ODI_23_IND_BAT_pp1_4['Boundaries per Ball'][i],ha='center')
plt.title('Boundaries per Ball [1-10 overs](atleast hit 15 boundaries) of India(In 2023)')
plt.xlabel('Batter')
plt.xticks(rotation=0)
plt.ylabel('Boundaries per Ball')
plt.show()

# %% [markdown]
# **Caution:**
#
#     In 2023 Shikhar Dhawan hasn't get much chance to perform in ODI 2023. He is not in the scheme of BCCI for ODI world         Cup 2023(Though he is the 2nd highest run getters(891 Runs) in PP1 (Overs 1-10) since 2019).His age and recent             performance may reduce his chance of being included in the World cup 2023.

# %% [markdown]
# **Batting Stats(Info) in PP1 (Overs 1-10):**
#
#     1. Rohit Sharma has scored highest runs(1072 Runs) with batting average 53.6 in PP1 (Overs 1-10) for India since 2019.
#     2. Subhman Gill has highest Runs(486), Batting Averge(162.0), Boundaries per Balls hitting abilities(0.159) with a            strike Rate of 95.11 in PP1( Overs 1-10) 2023 for India.
#     3. Subhman Gill has best batting average(110.43) and boundaries per ball ratio(0.137) for India in PP1(Overs 1-10)            since 2019.
#     4. Rohit Sharma has best Strike Rate(96.34) for India in PP1(Overs 1-10)in 2019.

# %% [markdown]
# **Openers:**
#
#     1. Rohit Sharma  (He is the captain of Indian Cricket team; Moreover he a consistant experience batter for India)
#     2. Subhman Gill (Star Performer in 2023)
#     3. Ishan Kishan [Backup: left handed explosive wicket keeper batter; has double century in last against Bangladesh)]

# %% [markdown]
# ### Middle Orders

# %%
ODI_19_IND_bt_pp2=ODI_19_IND_bt[(ODI_19_IND_bt['Overs']>10) & (ODI_19_IND_bt['Overs']<=40)]
ODI_19_IND_bt_pp2
# Out:
#         Source.Name  match_id   season start_date  \
# 134883  1144490.csv   1144490     2019 2019-06-05
# 134884  1144490.csv   1144490     2019 2019-06-05
# 134885  1144490.csv   1144490     2019 2019-06-05
# 134886  1144490.csv   1144490     2019 2019-06-05
# 134887  1144490.csv   1144490     2019 2019-06-05
# ...             ...       ...      ...        ...
# 450259  1389389.csv   1389389  2023/24 2023-09-24
# 450260  1389389.csv   1389389  2023/24 2023-09-24
# 450261  1389389.csv   1389389  2023/24 2023-09-24
# 450262  1389389.csv   1389389  2023/24 2023-09-24
# 450263  1389389.csv   1389389  2023/24 2023-09-24
#
#                                  venue  innings  ball batting_team  \
# 134883                   The Rose Bowl        2  10.1        India
# 134884                   The Rose Bowl        2  10.2        India
# 134885                   The Rose Bowl        2  10.3        India
# 134886                   The Rose Bowl        2  10.4        India
# ...

# %%
ODI_19_IND_BAT_pp2=pd.pivot_table(ODI_19_IND_bt_pp2,index=["match_id","striker"],
                              values=["runs_off_bat","ball","player_dismissed"],
               aggfunc={"runs_off_bat":"sum","ball":"count","player_dismissed":"count"})
ODI_19_IND_BAT_pp2.rename(columns={"runs_off_bat":"Runs Scored","ball":"Balls Faced","player_dismissed":"Dismissals"},
                 inplace=True)
ODI_19_IND_BAT_pp2
# Out:
#                        Balls Faced  Dismissals  Runs Scored
# match_id striker
# 1144490  KL Rahul               42           1           26
#          MS Dhoni               28           0           17
#          RG Sharma              95           0           76
#          V Kohli                17           1           14
# 1144496  HH Pandya               8           0            7
# ...                            ...         ...          ...
# 1389388  Shubman Gill           40           1           42
# 1389389  Ishan Kishan           18           0           25
#          KL Rahul               27           0           43
#          SS Iyer                72           1           71
#          Shubman Gill           69           1           71
#
# [449 rows x 3 columns]

# %%
ODI_23_IND_bt_pp2=ODI_23_IND_bt[(ODI_23_IND_bt['Overs']>10) & (ODI_23_IND_bt['Overs']<=40)]
ODI_23_IND_bt_pp2
# Out:
#         Source.Name  match_id   season start_date  \
# 387063  1348643.csv   1348643  2022/23 2023-01-10
# 387064  1348643.csv   1348643  2022/23 2023-01-10
# 387065  1348643.csv   1348643  2022/23 2023-01-10
# 387066  1348643.csv   1348643  2022/23 2023-01-10
# 387067  1348643.csv   1348643  2022/23 2023-01-10
# ...             ...       ...      ...        ...
# 450259  1389389.csv   1389389  2023/24 2023-09-24
# 450260  1389389.csv   1389389  2023/24 2023-09-24
# 450261  1389389.csv   1389389  2023/24 2023-09-24
# 450262  1389389.csv   1389389  2023/24 2023-09-24
# 450263  1389389.csv   1389389  2023/24 2023-09-24
#
#                                       venue  innings  ball batting_team  \
# 387063  Barsapara Cricket Stadium, Guwahati        1  10.1        India
# 387064  Barsapara Cricket Stadium, Guwahati        1  10.2        India
# 387065  Barsapara Cricket Stadium, Guwahati        1  10.3        India
# ...

# %%
ODI_23_IND_BAT_pp2=pd.pivot_table(ODI_23_IND_bt_pp2,index=["match_id","striker"],
                              values=["runs_off_bat","ball","player_dismissed"],
               aggfunc={"runs_off_bat":"sum","ball":"count","player_dismissed":"count"})
ODI_23_IND_BAT_pp2.rename(columns={"runs_off_bat":"Runs Scored","ball":"Balls Faced","player_dismissed":"Dismissals"},
                 inplace=True)
ODI_23_IND_BAT_pp2
# Out:
#                        Balls Faced  Dismissals  Runs Scored
# match_id striker
# 1348643  KL Rahul               27           0           35
#          RG Sharma              35           1           39
#          SS Iyer                24           1           28
#          Shubman Gill           34           1           39
#          V Kohli                63           0           74
# ...                            ...         ...          ...
# 1389388  Shubman Gill           40           1           42
# 1389389  Ishan Kishan           18           0           25
#          KL Rahul               27           0           43
#          SS Iyer                72           1           71
#          Shubman Gill           69           1           71
#
# [107 rows x 3 columns]

# %%
ODI_19_IND_BAT_pp2=pd.pivot_table(ODI_19_IND_bt_pp2,index=["match_id","striker"],
                              values=["runs_off_bat","ball","player_dismissed"],
               aggfunc={"runs_off_bat":"sum","ball":"count","player_dismissed":"count"})
ODI_19_IND_BAT_pp2.rename(columns={"runs_off_bat":"Runs Scored","ball":"Balls Faced","player_dismissed":"Dismissals"},
                 inplace=True)
ODI_19_IND_BAT_P_pp2=pd.pivot_table(ODI_19_IND_BAT_pp2,index=['striker'],values=["Runs Scored","Balls Faced","Dismissals"],aggfunc="sum")
ODI_19_IND_BAT_P_pp2["Strike Rate"]=round(ODI_19_IND_BAT_P_pp2["Runs Scored"]/ODI_19_IND_BAT_P_pp2["Balls Faced"]*100,2)
ODI_19_IND_BAT_P_pp2["Batting Average"]=round(ODI_19_IND_BAT_P_pp2["Runs Scored"]/ODI_19_IND_BAT_P_pp2["Dismissals"],2)
ODI_19_IND_BAT_P_pp2
# Out:
#                    Balls Faced  Dismissals  Runs Scored  Strike Rate  \
# striker
# AR Patel                   154           4          129        83.77
# AT Rayudu                  263           4          205        77.95
# Avesh Khan                   6           1            3        50.00
# B Kumar                     65           1           26        40.00
# DJ Hooda                   134           2           85        63.43
# DL Chahar                   84           2           42        50.00
# HH Pandya                  749          14          657        87.72
# Ishan Kishan               627          17          673       107.34
# J Yadav                      1           0            0         0.00
# JJ Bumrah                   10           0            3        30.00
# K Gowtham                    3           1            2        66.67
# KD Karthik                  53           2           37        69.81
# ...

# %%
ODI_23_IND_BAT_pp2=pd.pivot_table(ODI_23_IND_bt_pp2,index=["match_id","striker"],
                              values=["runs_off_bat","ball","player_dismissed"],
               aggfunc={"runs_off_bat":"sum","ball":"count","player_dismissed":"count"})
ODI_23_IND_BAT_pp2.rename(columns={"runs_off_bat":"Runs Scored","ball":"Balls Faced","player_dismissed":"Dismissals"},
                 inplace=True)
ODI_23_IND_BAT_P_pp2=pd.pivot_table(ODI_23_IND_BAT_pp2,index=['striker'],values=["Runs Scored","Balls Faced","Dismissals"],aggfunc="sum")
ODI_23_IND_BAT_P_pp2["Strike Rate"]=round(ODI_23_IND_BAT_P_pp2["Runs Scored"]/ODI_23_IND_BAT_P_pp2["Balls Faced"]*100,2)
ODI_23_IND_BAT_P_pp2["Batting Average"]=round(ODI_23_IND_BAT_P_pp2["Runs Scored"]/ODI_23_IND_BAT_P_pp2["Dismissals"],2)
ODI_23_IND_BAT_P_pp2
# Out:
#                    Balls Faced  Dismissals  Runs Scored  Strike Rate  \
# striker
# AR Patel                    84           3           63        75.00
# HH Pandya                  318           5          239        75.16
# Ishan Kishan               330          10          297        90.00
# JJ Bumrah                    4           0            1        25.00
# KL Rahul                   456           3          368        80.70
# Kuldeep Yadav               42           1           11        26.19
# Mohammed Shami               1           1            0         0.00
# Mohammed Siraj               3           1            0         0.00
# Mukesh Kumar                 4           0            6       150.00
# RA Jadeja                  209           4          107        51.20
# RD Gaikwad                  54           2           47        87.04
# RG Sharma                  208           7          235       112.98
# ...

# %%
ODI_19_IND_BAT_P_pp2_runs=ODI_19_IND_BAT_P_pp2.sort_values(by='Runs Scored',ascending=False).head(5)
ODI_19_IND_BAT_P_pp2_runs
# Out:
#               Balls Faced  Dismissals  Runs Scored  Strike Rate  \
# striker
# V Kohli              2169          35         2052        94.61
# RG Sharma            1361          27         1378       101.25
# KL Rahul             1551          21         1303        84.01
# SS Iyer              1347          26         1228        91.17
# Shubman Gill          994          19         1016       102.21
#
#               Batting Average
# striker
# V Kohli                 58.63
# RG Sharma               51.04
# KL Rahul                62.05
# SS Iyer                 47.23
# Shubman Gill            53.47

# %%
ODI_23_IND_BAT_P_pp2_runs=ODI_23_IND_BAT_P_pp2.sort_values(by='Runs Scored',ascending=False).head(5)
ODI_23_IND_BAT_P_pp2_runs
# Out:
#               Balls Faced  Dismissals  Runs Scored  Strike Rate  \
# striker
# Shubman Gill          642          12          659       102.65
# KL Rahul              456           3          368        80.70
# V Kohli               337           6          333        98.81
# Ishan Kishan          330          10          297        90.00
# HH Pandya             318           5          239        75.16
#
#               Batting Average
# striker
# Shubman Gill            54.92
# KL Rahul               122.67
# V Kohli                 55.50
# Ishan Kishan            29.70
# HH Pandya               47.80

# %%
ODI_19_IND_BAT_P_pp2_avg=ODI_19_IND_BAT_P_pp2[ODI_19_IND_BAT_P_pp2["Balls Faced"]>=500].sort_values(by='Batting Average',ascending=False).head()
ODI_19_IND_BAT_P_pp2_avg
# Out:
#               Balls Faced  Dismissals  Runs Scored  Strike Rate  \
# striker
# KL Rahul             1551          21         1303        84.01
# V Kohli              2169          35         2052        94.61
# Shubman Gill          994          19         1016       102.21
# RG Sharma            1361          27         1378       101.25
# S Dhawan             1069          20          967        90.46
#
#               Batting Average
# striker
# KL Rahul                62.05
# V Kohli                 58.63
# Shubman Gill            53.47
# RG Sharma               51.04
# S Dhawan                48.35

# %%
ODI_23_IND_BAT_P_pp2_avg=ODI_23_IND_BAT_P_pp2[ODI_23_IND_BAT_P_pp2["Balls Faced"]>=150].sort_values(by='Batting Average',ascending=False).head()
ODI_23_IND_BAT_P_pp2_avg
# Out:
#               Balls Faced  Dismissals  Runs Scored  Strike Rate  \
# striker
# KL Rahul              456           3          368        80.70
# V Kohli               337           6          333        98.81
# Shubman Gill          642          12          659       102.65
# HH Pandya             318           5          239        75.16
# RG Sharma             208           7          235       112.98
#
#               Batting Average
# striker
# KL Rahul               122.67
# V Kohli                 55.50
# Shubman Gill            54.92
# HH Pandya               47.80
# RG Sharma               33.57

# %%
ODI_19_IND_BAT_P_pp2_SR=ODI_19_IND_BAT_P_pp2[ODI_19_IND_BAT_P_pp2["Balls Faced"]>=500].sort_values(by='Strike Rate',ascending=False).head(5)
ODI_19_IND_BAT_P_pp2_SR
# Out:
#               Balls Faced  Dismissals  Runs Scored  Strike Rate  \
# striker
# Ishan Kishan          627          17          673       107.34
# Shubman Gill          994          19         1016       102.21
# RG Sharma            1361          27         1378       101.25
# RR Pant               635          16          609        95.91
# V Kohli              2169          35         2052        94.61
#
#               Batting Average
# striker
# Ishan Kishan            39.59
# Shubman Gill            53.47
# RG Sharma               51.04
# RR Pant                 38.06
# V Kohli                 58.63

# %%
ODI_23_IND_BAT_P_pp2_SR=ODI_23_IND_BAT_P_pp2[ODI_23_IND_BAT_P_pp2["Balls Faced"]>=150].sort_values(by='Strike Rate',ascending=False).head(5)
ODI_23_IND_BAT_P_pp2_SR
# Out:
#               Balls Faced  Dismissals  Runs Scored  Strike Rate  \
# striker
# RG Sharma             208           7          235       112.98
# Shubman Gill          642          12          659       102.65
# V Kohli               337           6          333        98.81
# Ishan Kishan          330          10          297        90.00
# KL Rahul              456           3          368        80.70
#
#               Batting Average
# striker
# RG Sharma               33.57
# Shubman Gill            54.92
# V Kohli                 55.50
# Ishan Kishan            29.70
# KL Rahul               122.67

# %%
ODI_19_IND_BAT_pp2_123=pd.pivot_table(ODI_19_IND_bt_pp2[(ODI_19_IND_bt_pp2['runs_off_bat']==1)|(ODI_19_IND_bt_pp2['runs_off_bat']==2)|(ODI_19_IND_bt_pp2['runs_off_bat']==3)],
                                      index='striker',values='runs_off_bat',aggfunc={'runs_off_bat':'count'})
ODI_19_IND_BAT_pp2_123.rename(columns={'runs_off_bat':'Short Runs'},inplace=True)
ODI_19_IND_BAT_pp2_123['Short Runs per Ball']=round(ODI_19_IND_BAT_pp2_123['Short Runs']/ODI_19_IND_BAT_P_pp2['Balls Faced'],3)
ODI_19_IND_BAT_pp2_123=ODI_19_IND_BAT_pp2_123[ODI_19_IND_BAT_pp2_123['Short Runs']>=300].sort_values(by='Short Runs per Ball',ascending=False).head(5)
ODI_19_IND_BAT_pp2_123
# Out:
#               Short Runs  Short Runs per Ball
# striker
# V Kohli             1117                0.515
# Shubman Gill         480                0.483
# KL Rahul             697                0.449
# S Dhawan             472                0.442
# RG Sharma            591                0.434

# %%
ODI_23_IND_BAT_pp2_123=pd.pivot_table(ODI_23_IND_bt_pp2[(ODI_23_IND_bt_pp2['runs_off_bat']==1)|(ODI_23_IND_bt_pp2['runs_off_bat']==2)|(ODI_23_IND_bt_pp2['runs_off_bat']==3)],
                                      index='striker',values='runs_off_bat',aggfunc={'runs_off_bat':'count'})
ODI_23_IND_BAT_pp2_123.rename(columns={'runs_off_bat':'Short Runs'},inplace=True)
ODI_23_IND_BAT_pp2_123['Short Runs per Ball']=round(ODI_23_IND_BAT_pp2_123['Short Runs']/ODI_23_IND_BAT_P_pp2['Balls Faced'],3)
ODI_23_IND_BAT_pp2_123=ODI_23_IND_BAT_pp2_123[ODI_23_IND_BAT_pp2_123['Short Runs']>=100].sort_values(by='Short Runs per Ball',ascending=False).head(5)
ODI_23_IND_BAT_pp2_123
# Out:
#               Short Runs  Short Runs per Ball
# striker
# V Kohli              174                0.516
# Shubman Gill         314                0.489
# KL Rahul             199                0.436
# HH Pandya            125                0.393
# Ishan Kishan         121                0.367

# %%
ODI_19_IND_BAT_pp2_dot=pd.pivot_table(ODI_19_IND_bt_pp2[(ODI_19_IND_bt_pp2['runs_off_bat']==0)],index='striker',
                                      values='runs_off_bat',aggfunc={'runs_off_bat':'count'})
ODI_19_IND_BAT_pp2_dot.rename(columns={'runs_off_bat':'No Of Dot balls'},inplace=True)
ODI_19_IND_BAT_pp2_dot['Dots per Ball']=round(ODI_19_IND_BAT_pp2_dot['No Of Dot balls']/ODI_19_IND_BAT_P_pp2['Balls Faced'],3)
ODI_19_IND_BAT_pp2_dot=ODI_19_IND_BAT_pp2_dot[ODI_19_IND_BAT_pp2_dot['No Of Dot balls']>=300].sort_values(by='Dots per Ball',ascending=True).head(5)
ODI_19_IND_BAT_pp2_dot
# Out:
#               No Of Dot balls  Dots per Ball
# striker
# V Kohli                   859          0.396
# Shubman Gill              402          0.404
# RG Sharma                 614          0.451
# S Dhawan                  491          0.459
# KL Rahul                  735          0.474

# %%
ODI_23_IND_BAT_pp2_dot=pd.pivot_table(ODI_23_IND_bt_pp2[(ODI_23_IND_bt_pp2['runs_off_bat']==0)],index='striker',
                                      values='runs_off_bat',aggfunc={'runs_off_bat':'count'})
ODI_23_IND_BAT_pp2_dot.rename(columns={'runs_off_bat':'No Of Dot balls'},inplace=True)
ODI_23_IND_BAT_pp2_dot['Dots per Ball']=round(ODI_23_IND_BAT_pp2_dot['No Of Dot balls']/ODI_23_IND_BAT_P_pp2['Balls Faced'],3)
ODI_23_IND_BAT_pp2_dot=ODI_23_IND_BAT_pp2_dot[ODI_23_IND_BAT_pp2_dot['No Of Dot balls']>=100].sort_values(by='Dots per Ball',ascending=True).head(5)
ODI_23_IND_BAT_pp2_dot
# Out:
#               No Of Dot balls  Dots per Ball
# striker
# V Kohli                   130          0.386
# Shubman Gill              256          0.399
# RG Sharma                 100          0.481
# KL Rahul                  223          0.489
# Ishan Kishan              173          0.524

# %%
plt.subplot(5,2,1)
ODI_19_IND_BAT_P_pp2_runs['Runs Scored'].plot(kind='bar',figsize=(12,5),color='gray')
for i in range(len(list(ODI_19_IND_BAT_P_pp2_runs.index))):
    plt.text(i,ODI_19_IND_BAT_P_pp2_runs['Runs Scored'][i],ODI_19_IND_BAT_P_pp2_runs['Runs Scored'][i],ha='center')
plt.title('Top Runs Scorers [11-40 overs] of India(Since 2019)')
plt.xlabel('Batter')
plt.xticks(rotation=0)
plt.ylabel('Runs Scored')
plt.subplot(5,2,2)
ODI_23_IND_BAT_P_pp2_runs['Runs Scored'].plot(kind='bar',figsize=(12,5),color='gray')
for i in range(len(list(ODI_23_IND_BAT_P_pp2_runs.index))):
    plt.text(i,ODI_23_IND_BAT_P_pp2_runs['Runs Scored'][i],ODI_23_IND_BAT_P_pp2_runs['Runs Scored'][i],ha='center')
plt.title('Top Runs Scorers [11-40 overs] of India(In 2023)')
plt.xlabel('Batter')
plt.xticks(rotation=0)
plt.ylabel('Runs Scored')
plt.subplot(5,2,3)
ODI_19_IND_BAT_P_pp2_avg['Batting Average'].plot(kind='bar',figsize=(12,5),color='coral')
for i in range(len(list(ODI_19_IND_BAT_P_pp2_avg.index))):
    plt.text(i,ODI_19_IND_BAT_P_pp2_avg['Batting Average'][i],ODI_19_IND_BAT_P_pp2_avg['Batting Average'][i],ha='center')
plt.title('Top Batting Average [11-40 overs](played atleast 500 balls) of India(Since 2019)')
plt.xlabel('Batter')
plt.xticks(rotation=0)
plt.ylabel('Batting Average')
plt.subplot(5,2,4)
ODI_23_IND_BAT_P_pp2_avg['Batting Average'].plot(kind='bar',figsize=(12,5),color='coral')
for i in range(len(list(ODI_23_IND_BAT_P_pp2_avg.index))):
    plt.text(i,ODI_23_IND_BAT_P_pp2_avg['Batting Average'][i],ODI_23_IND_BAT_P_pp2_avg['Batting Average'][i],ha='center')
plt.title('Top Batting Average [11-40 overs](played atleast 150 balls) of India(In 2023)')
plt.xlabel('Batter')
plt.xticks(rotation=0)
plt.ylabel('Batiing Average')
plt.subplot(5,2,5)
ODI_19_IND_BAT_P_pp2_SR['Strike Rate'].plot(kind='bar',figsize=(12,5),color='purple')
for i in range(len(list(ODI_19_IND_BAT_P_pp2_SR.index))):
    plt.text(i,ODI_19_IND_BAT_P_pp2_SR['Strike Rate'][i],ODI_19_IND_BAT_P_pp2_SR['Strike Rate'][i],ha='center')
plt.title('Top Strike Rate [11-40 overs](played atleast 500 balls) of India(Since 2019)')
plt.xlabel('Batter')
plt.xticks(rotation=0)
plt.ylabel('Strike Rate')
plt.subplot(5,2,6)
ODI_23_IND_BAT_P_pp2_SR['Strike Rate'].plot(kind='bar',figsize=(12,5),color='purple')
for i in range(len(list(ODI_23_IND_BAT_P_pp2_SR.index))):
    plt.text(i,ODI_23_IND_BAT_P_pp2_SR['Strike Rate'][i],ODI_23_IND_BAT_P_pp2_SR['Strike Rate'][i],ha='center')
plt.title('Top Strike Rate [11-40 overs](played atleast 150 balls) of India(In 2023)')
plt.xlabel('Batter')
plt.xticks(rotation=0)
plt.ylabel('Strike Rate')    
plt.subplots_adjust(left=0.1,bottom=0.01, right=1.1, top=2, wspace=0.4, hspace=0.6)
plt.subplot(5,2,7)
ODI_19_IND_BAT_pp2_123['Short Runs per Ball'].plot(kind='bar',figsize=(12,5),color='green')
for i in range(len(list(ODI_19_IND_BAT_pp2_123.index))):
    plt.text(i,ODI_19_IND_BAT_pp2_123['Short Runs per Ball'][i],ODI_19_IND_BAT_pp2_123['Short Runs per Ball'][i],ha='center')
plt.title('Short Runs per Ball [11-40 overs](atleast 300 Short Runs) of India(Since 2019)')
plt.xlabel('Batter')
plt.xticks(rotation=0)
plt.ylabel('Short Runs per Ball')
plt.subplot(5,2,8)
ODI_23_IND_BAT_pp2_123['Short Runs per Ball'].plot(kind='bar',figsize=(12,5),color='green')
for i in range(len(list(ODI_23_IND_BAT_pp2_123.index))):
    plt.text(i,ODI_23_IND_BAT_pp2_123['Short Runs per Ball'][i],ODI_23_IND_BAT_pp2_123['Short Runs per Ball'][i],ha='center')
plt.title('Short Runs per Ball [11-40 overs](atleast 100 Short Runs) of India(In 2023)')
plt.xlabel('Batter')
plt.xticks(rotation=0)
plt.ylabel('Short Runs per Ball')
plt.subplot(5,2,9)
ODI_19_IND_BAT_pp2_dot['Dots per Ball'].plot(kind='bar',figsize=(12,5),color='brown')
for i in range(len(list(ODI_19_IND_BAT_pp2_dot.index))):
    plt.text(i,ODI_19_IND_BAT_pp2_dot['Dots per Ball'][i],ODI_19_IND_BAT_pp2_dot['Dots per Ball'][i],ha='center')
plt.title('Dots per Ball [11-40 overs](atleast 300 Dots) of India(Since 2019)')
plt.xlabel('Batter')
plt.xticks(rotation=0)
plt.ylabel('Dots per Ball')
plt.subplot(5,2,10)
ODI_23_IND_BAT_pp2_dot['Dots per Ball'].plot(kind='bar',figsize=(12,5),color='brown')
for i in range(len(list(ODI_23_IND_BAT_pp2_dot.index))):
    plt.text(i,ODI_23_IND_BAT_pp2_dot['Dots per Ball'][i],ODI_23_IND_BAT_pp2_dot['Dots per Ball'][i],ha='center')
plt.title('Dots per Ball [11-40 overs](atleast 100 Dots) of India(In 2023)')
plt.xlabel('Batter')
plt.xticks(rotation=0)
plt.ylabel('Dots per Ball')
plt.show()

# %% [markdown]
# **Caution:**
#
#     1. In 2023 Shikhar Dhawan hasn't get much chance to perform in ODI 2023. He is not in the scheme of BCCI for ODI world        Cup 2023(Though he has batting average of 48.35 in PP2 (Overs 11-40) since 2019).His age and recent performance may        reduce his chance of being included in the World cup 2023.
#     2. Rishabh Pant met an Car Accident in 2023. So he will not able to play for India in 2023 World Cup.

# %% [markdown]
# **Batting Stats(Info) in PP2 (Overs 11-40):**
#
#     1. Virat Kohli is the highest run scorers (2052 Runs) in middle overs(Overs 11-40) for India since 2019.
#     2. Subhman Gill is the highest run scorers (659 Runs) in middle overs(Overs 11-40) for India in 2023.
#     3. KL Rahul is the most consistant batter asper batting average(Since 2019-highest batting average: 62.05, In 2023-            highest batting average: 122.67 ) in middle overs(Overs 11-40) for India.
#     4. Ishan Kishan has the highest Strike Rate(107.34) in middle overs(Overs 11-40) for India since 2019.
#     5. Virat Kohli has most consistency for India in middle overs(Overs 11-40) as per Short Runs per Ball (Since 2019-            highest Short Runs per ball : 0.515, In 2023-highest Short Runs per Ball: 0.516 ) and dots per Ball (Since 2019-            least Dots  per ball : 0.396, In 2023-highest Dots per Ball: 0.386 ).

# %% [markdown]
# **Middle Orders:**
#
#     1. Virat Kohli
#     2. KL Rahul
#     3. Shreyas Iyer
#     4. Ishan Kishan
#        [Shreyas Iyer has scored 1228 Runs with a batiing average of 47.23 and Strike Rate of 91.17 for India in Middle            overs Since 2019, he recover from an injury before world cup 2023 whereas Ishan Kishan performs well in his short          career as a middle over batters for India. Now it depends on the situation and the current performance of them which        will define the chance of being included in the Playing 11. But both of them will be selected in the prabable 15            squads for the World Cup 2023.]
#     5. SuryaKumar Yadav [Backup: He scored 134 Runs in PP3 (Overs 41-50) with a Strike Rate of 147.25 and Batting Average          of 44.67 ]

# %% [markdown]
# ### All Rounders

# %%
ODI_19_IND_bt_pp3=ODI_19_IND_bt[(ODI_19_IND_bt['Overs']>40)]
ODI_19_IND_bt_pp3
# Out:
#         Source.Name  match_id   season start_date  \
# 135065  1144490.csv   1144490     2019 2019-06-05
# 135066  1144490.csv   1144490     2019 2019-06-05
# 135067  1144490.csv   1144490     2019 2019-06-05
# 135068  1144490.csv   1144490     2019 2019-06-05
# 135069  1144490.csv   1144490     2019 2019-06-05
# ...             ...       ...      ...        ...
# 450322  1389389.csv   1389389  2023/24 2023-09-24
# 450323  1389389.csv   1389389  2023/24 2023-09-24
# 450324  1389389.csv   1389389  2023/24 2023-09-24
# 450325  1389389.csv   1389389  2023/24 2023-09-24
# 450326  1389389.csv   1389389  2023/24 2023-09-24
#
#                                  venue  innings  ball batting_team  \
# 135065                   The Rose Bowl        2  40.1        India
# 135066                   The Rose Bowl        2  40.2        India
# 135067                   The Rose Bowl        2  40.3        India
# 135068                   The Rose Bowl        2  40.4        India
# ...

# %%
ODI_19_IND_BAT_pp3=pd.pivot_table(ODI_19_IND_bt_pp3,index=["match_id","striker"],
                              values=["runs_off_bat","ball","player_dismissed"],
               aggfunc={"runs_off_bat":"sum","ball":"count","player_dismissed":"count"})
ODI_19_IND_BAT_pp3.rename(columns={"runs_off_bat":"Runs Scored","ball":"Balls Faced","player_dismissed":"Dismissals"},
                 inplace=True)
ODI_19_IND_BAT_pp3
# Out:
#                        Balls Faced  Dismissals  Runs Scored
# match_id striker
# 1144490  HH Pandya               8           0           15
#          MS Dhoni               19           1           17
#          RG Sharma              19           0           25
# 1144496  HH Pandya              21           1           41
#          KL Rahul                3           0           11
# ...                            ...         ...          ...
# 1389388  SA Yadav               20           1           25
# 1389389  Ishan Kishan            2           1            6
#          KL Rahul               13           1            9
#          RA Jadeja               9           0           13
#          SA Yadav               39           0           72
#
# [277 rows x 3 columns]

# %%
ODI_23_IND_bt_pp3=ODI_23_IND_bt[(ODI_23_IND_bt['Overs']>40)]
ODI_23_IND_bt_pp3
# Out:
#         Source.Name  match_id   season start_date  \
# 387246  1348643.csv   1348643  2022/23 2023-01-10
# 387247  1348643.csv   1348643  2022/23 2023-01-10
# 387248  1348643.csv   1348643  2022/23 2023-01-10
# 387249  1348643.csv   1348643  2022/23 2023-01-10
# 387250  1348643.csv   1348643  2022/23 2023-01-10
# ...             ...       ...      ...        ...
# 450322  1389389.csv   1389389  2023/24 2023-09-24
# 450323  1389389.csv   1389389  2023/24 2023-09-24
# 450324  1389389.csv   1389389  2023/24 2023-09-24
# 450325  1389389.csv   1389389  2023/24 2023-09-24
# 450326  1389389.csv   1389389  2023/24 2023-09-24
#
#                                       venue  innings  ball batting_team  \
# 387246  Barsapara Cricket Stadium, Guwahati        1  40.1        India
# 387247  Barsapara Cricket Stadium, Guwahati        1  40.2        India
# 387248  Barsapara Cricket Stadium, Guwahati        1  40.3        India
# ...

# %%
ODI_23_IND_BAT_pp3=pd.pivot_table(ODI_23_IND_bt_pp3,index=["match_id","striker"],
                              values=["runs_off_bat","ball","player_dismissed"],
               aggfunc={"runs_off_bat":"sum","ball":"count","player_dismissed":"count"})
ODI_23_IND_BAT_pp3.rename(columns={"runs_off_bat":"Runs Scored","ball":"Balls Faced","player_dismissed":"Dismissals"},
                 inplace=True)
ODI_23_IND_BAT_pp3
# Out:
#                             Balls Faced  Dismissals  Runs Scored
# match_id striker
# 1348643  AR Patel                    10           1            9
#          HH Pandya                   13           1           14
#          KL Rahul                     2           1            4
#          Mohammed Shami               4           0            4
#          Mohammed Siraj               8           0            7
#          V Kohli                     25           1           39
# 1348644  KL Rahul                    12           0           15
#          Kuldeep Yadav               10           0           10
# 1348645  AR Patel                     2           0            2
#          KL Rahul                     7           1            7
#          SA Yadav                     5           1            4
#          SS Iyer                     14           1           15
#          V Kohli                     35           0           84
# ...

# %%
ODI_19_IND_BAT_pp3=pd.pivot_table(ODI_19_IND_bt_pp3,index=["match_id","striker"],
                              values=["runs_off_bat","ball","player_dismissed"],
               aggfunc={"runs_off_bat":"sum","ball":"count","player_dismissed":"count"})
ODI_19_IND_BAT_pp3.rename(columns={"runs_off_bat":"Runs Scored","ball":"Balls Faced","player_dismissed":"Dismissals"},
                 inplace=True)
ODI_19_IND_BAT_P_pp3=pd.pivot_table(ODI_19_IND_BAT_pp3,index=['striker'],values=["Runs Scored","Balls Faced","Dismissals"],aggfunc="sum")
ODI_19_IND_BAT_P_pp3["Strike Rate"]=round(ODI_19_IND_BAT_P_pp3["Runs Scored"]/ODI_19_IND_BAT_P_pp3["Balls Faced"]*100,2)
ODI_19_IND_BAT_P_pp3["Batting Average"]=round(ODI_19_IND_BAT_P_pp3["Runs Scored"]/ODI_19_IND_BAT_P_pp3["Dismissals"],2)
ODI_19_IND_BAT_P_pp3
# Out:
#                    Balls Faced  Dismissals  Runs Scored  Strike Rate  \
# striker
# AR Patel                   145           6          171       117.93
# AT Rayudu                   40           2           38        95.00
# Arshdeep Singh               9           1            9       100.00
# Avesh Khan                  13           1           10        76.92
# B Kumar                     87           8           86        98.85
# C Sakariya                   1           0            0         0.00
# DJ Hooda                    60           4           68       113.33
# DL Chahar                  120           3          149       124.17
# HH Pandya                  286          13          430       150.35
# Ishan Kishan                 7           1           10       142.86
# J Yadav                      5           1            2        40.00
# JJ Bumrah                   78           5           54        69.23
# ...

# %%
ODI_19_IND_BAT_P_AR=ODI_19_IND_BAT_P_pp3.rename(columns={"Strike Rate":"Batting Strike Rate"})
ODI_19_IND_BALL_P_AR=ODI_19_IND_BALL_P.rename(columns={"Dismissals":"Wickets Taken"})
ODI_19_IND_P_AR=pd.concat([ODI_19_IND_BAT_P_AR,ODI_19_IND_BALL_P_AR],axis=1,join="inner")
ODI_19_IND_P_AR=ODI_19_IND_P_AR[(ODI_19_IND_P_AR["Wickets Taken"]>=20)&
                                                (ODI_19_IND_P_AR["Runs Scored"]>=100)]
ODI_19_IND_P_AR
# Out:
#            Balls Faced  Dismissals  Runs Scored  Batting Strike Rate  \
# HH Pandya          286          13          430               150.35
# RA Jadeja          314          13          335               106.69
# SN Thakur          187          12          214               114.44
#
#            Batting Average  Balls Delivered  Wickets Taken  Runs Conceeded  \
# HH Pandya            33.08             1382             40            1143
# RA Jadeja            25.77             1897             39            1548
# SN Thakur            17.83             1694             59            1619
#
#            Economy  Bowling Average  Bowling Strike Rate
# HH Pandya     4.96            28.58                34.55
# RA Jadeja     4.90            39.69                48.64
# SN Thakur     5.73            27.44                28.71

# %%
ODI_23_IND_BAT_pp3=pd.pivot_table(ODI_23_IND_bt_pp3,index=["match_id","striker"],
                              values=["runs_off_bat","ball","player_dismissed"],
               aggfunc={"runs_off_bat":"sum","ball":"count","player_dismissed":"count"})
ODI_23_IND_BAT_pp3.rename(columns={"runs_off_bat":"Runs Scored","ball":"Balls Faced","player_dismissed":"Dismissals"},
                 inplace=True)
ODI_23_IND_BAT_P_pp3=pd.pivot_table(ODI_23_IND_BAT_pp3,index=['striker'],values=["Runs Scored","Balls Faced","Dismissals"],aggfunc="sum")
ODI_23_IND_BAT_P_pp3["Strike Rate"]=round(ODI_23_IND_BAT_P_pp3["Runs Scored"]/ODI_23_IND_BAT_P_pp3["Balls Faced"]*100,2)
ODI_23_IND_BAT_P_pp3["Batting Average"]=round(ODI_23_IND_BAT_P_pp3["Runs Scored"]/ODI_23_IND_BAT_P_pp3["Dismissals"],2)
ODI_23_IND_BAT_P_pp3
# Out:
#                    Balls Faced  Dismissals  Runs Scored  Strike Rate  \
# striker
# AR Patel                    70           3           69        98.57
# HH Pandya                   85           4          132       155.29
# Ishan Kishan                 2           1            6       300.00
# JJ Bumrah                   22           2           20        90.91
# KL Rahul                    85           3          103       121.18
# Kuldeep Yadav               52           4           29        55.77
# M Prasidh Krishna            2           0            0         0.00
# Mohammed Shami              22           2           26       118.18
# Mohammed Siraj              34           0           16        47.06
# Mukesh Kumar                 3           1            0         0.00
# RA Jadeja                   59           2           45        76.27
# SA Yadav                    91           3          134       147.25
# ...

# %%
ODI_23_IND_BAT_P_AR=ODI_23_IND_BAT_P_pp3.rename(columns={"Strike Rate":"Batting Strike Rate"})
ODI_23_IND_BALL_P_AR=ODI_23_IND_BALL_P.rename(columns={"Dismissals":"Wickets Taken"})
ODI_23_IND_P_AR=pd.concat([ODI_23_IND_BAT_P_AR,ODI_23_IND_BALL_P_AR],axis=1,join="inner")
ODI_23_IND_P_AR=ODI_23_IND_P_AR[(ODI_23_IND_P_AR["Wickets Taken"]>=5)&
                                                (ODI_23_IND_P_AR["Runs Scored"]>=30)]
ODI_23_IND_P_AR
# Out:
#            Balls Faced  Dismissals  Runs Scored  Batting Strike Rate  \
# AR Patel            70           3           69                98.57
# HH Pandya           85           4          132               155.29
# RA Jadeja           59           2           45                76.27
# SN Thakur           37           3           42               113.51
#
#            Batting Average  Balls Delivered  Wickets Taken  Runs Conceeded  \
# AR Patel              23.0              254              5             230
# HH Pandya             33.0              484             16             388
# RA Jadeja             22.5              525             15             407
# SN Thakur             14.0              443             21             430
#
#            Economy  Bowling Average  Bowling Strike Rate
# AR Patel      5.43            46.00                50.80
# HH Pandya     4.81            24.25                30.25
# RA Jadeja     4.65            27.13                35.00
# ...

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 1.5))
ODI_19_IND_P_AR.loc[:, ['Runs Scored', 'Wickets Taken']].plot(kind='bar',color=('purple','brown'),ax=axes[0])
for i in range(len(list(ODI_19_IND_P_AR.index))):
    for j in range(len(list(ODI_19_IND_P_AR.loc[:, ['Runs Scored', 'Wickets Taken']].columns))):
        axes[0].text(i, ODI_19_IND_P_AR.loc[:, ['Runs Scored', 'Wickets Taken']].iloc[i, j],
                 ODI_19_IND_P_AR.loc[:, ['Runs Scored', 'Wickets Taken']].iloc[i, j], ha='center',
                 bbox=dict(facecolor='cyan', alpha=0.75))
axes[0].set_title('All Rounders of India (Since 2019)')
axes[0].set_xlabel('All Rounders')
axes[0].set_xticks(range(len(ODI_19_IND_P_AR)))
axes[0].set_xticklabels(ODI_19_IND_P_AR.index, rotation=0)
plt.subplots_adjust(left=0.1, bottom=0.01, right=1.1, top=2.5, wspace=0.4, hspace=0.6)
ODI_23_IND_P_AR.loc[:, ['Runs Scored', 'Wickets Taken']].plot(kind='bar',color=('purple','brown'),ax=axes[1])
for i in range(len(list(ODI_23_IND_P_AR.index))):
    for j in range(len(list(ODI_23_IND_P_AR.loc[:, ['Runs Scored', 'Wickets Taken']].columns))):
        axes[1].text(i, ODI_23_IND_P_AR.loc[:, ['Runs Scored', 'Wickets Taken']].iloc[i, j],
                 ODI_23_IND_P_AR.loc[:, ['Runs Scored', 'Wickets Taken']].iloc[i, j], ha='center',
                 bbox=dict(facecolor='cyan', alpha=0.75))
axes[1].set_title('All Rounders of India (In 2023)')
axes[1].set_xlabel('All Rounders')
axes[1].set_xticks(range(len(ODI_23_IND_P_AR)))
axes[1].set_xticklabels(ODI_23_IND_P_AR.index, rotation=0)
plt.subplots_adjust(left=0.1, bottom=0.01, right=1.1, top=2.5, wspace=0.4, hspace=0.6)
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 1.5))
ODI_19_IND_P_AR.loc[:,['Batting Average','Bowling Average','Economy']].plot(kind='bar',color=('blue','orange','green'), ax=axes[0])
for i in range(len(list(ODI_19_IND_P_AR.index))):
    for j in range(len(list(ODI_19_IND_P_AR.loc[:,['Batting Average','Bowling Average','Economy']].columns))):
        axes[0].text(i,ODI_19_IND_P_AR.loc[:,['Batting Average','Bowling Average','Economy']].iloc[i,j],
                 ODI_19_IND_P_AR.loc[:,['Batting Average','Bowling Average','Economy']].iloc[i,j],ha='center',
                 bbox=dict(facecolor='red',alpha=0.75))
axes[0].set_title('All Rounders of India(Since 2019)')
axes[0].set_xticks(range(len(ODI_19_IND_P_AR)))
axes[0].set_xticklabels(ODI_19_IND_P_AR.index, rotation=0)
plt.subplots_adjust(left=0.1, bottom=0.01, right=1.1, top=2.5, wspace=0.4, hspace=0.6)
ODI_23_IND_P_AR.loc[:,['Batting Average','Bowling Average','Economy']].plot(kind='bar',color=('blue','orange','green'), ax=axes[1])
for i in range(len(list(ODI_23_IND_P_AR.index))):
    for j in range(len(list(ODI_23_IND_P_AR.loc[:,['Batting Average','Bowling Average','Economy']].columns))):
        axes[1].text(i,ODI_23_IND_P_AR.loc[:,['Batting Average','Bowling Average','Economy']].iloc[i,j],
                 ODI_23_IND_P_AR.loc[:,['Batting Average','Bowling Average','Economy']].iloc[i,j],ha='center',
                 bbox=dict(facecolor='red',alpha=0.75))
axes[1].set_title('All Rounders of India(In 2023)')
axes[1].set_xlabel('All Rounders')
axes[1].set_xticks(range(len(ODI_23_IND_P_AR)))
axes[1].set_xticklabels(ODI_23_IND_P_AR.index, rotation=0)
plt.subplots_adjust(left=0.1, bottom=0.01, right=1.1, top=2.5, wspace=0.4, hspace=0.6)
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 1.5))
ODI_19_IND_P_AR.loc[:,['Batting Strike Rate','Bowling Strike Rate']].plot(kind='bar',color=('coral','indigo'), ax=axes[0])
for i in range(len(list(ODI_19_IND_P_AR.index))):
    for j in range(len(list(ODI_19_IND_P_AR.loc[:,['Batting Strike Rate','Bowling Strike Rate']].columns))):
        axes[0].text(i,ODI_19_IND_P_AR.loc[:,['Batting Strike Rate','Bowling Strike Rate']].iloc[i,j],
                 ODI_19_IND_P_AR.loc[:,['Batting Strike Rate','Bowling Strike Rate']].iloc[i,j],ha='center',
                 bbox=dict(facecolor='grey',alpha=0.75))
axes[0].set_title('All Rounders of India(Since 2019)')
axes[0].set_xlabel('All Rounders')
axes[0].set_xticks(range(len(ODI_19_IND_P_AR)))
axes[0].set_xticklabels(ODI_19_IND_P_AR.index, rotation=0)
plt.subplots_adjust(left=0.1, bottom=0.01, right=1.1, top=2.5, wspace=0.4, hspace=0.6)
ODI_23_IND_P_AR.loc[:,['Batting Strike Rate','Bowling Strike Rate']].plot(kind='bar',color=('coral','indigo'), ax=axes[1])
for i in range(len(list(ODI_23_IND_P_AR.index))):
    for j in range(len(list(ODI_23_IND_P_AR.loc[:,['Batting Strike Rate','Bowling Strike Rate']].columns))):
        axes[1].text(i,ODI_23_IND_P_AR.loc[:,['Batting Strike Rate','Bowling Strike Rate']].iloc[i,j],
                 ODI_23_IND_P_AR.loc[:,['Batting Strike Rate','Bowling Strike Rate']].iloc[i,j],ha='center',
                 bbox=dict(facecolor='grey',alpha=0.75))
axes[1].set_title('All Rounders of India(In 2023)')
axes[1].set_xlabel('All Rounders')
axes[1].set_xticks(range(len(ODI_23_IND_P_AR)))
axes[1].set_xticklabels(ODI_23_IND_P_AR.index, rotation=0)
plt.subplots_adjust(left=0.1, bottom=0.01, right=1.1, top=2.5, wspace=0.4, hspace=0.6)
plt.show()

# %% [markdown]
# **All Rounders info:**
#
#     1. Hardik Pandya has scored 430 runs(Highest among Indian All Rounders) with a Batting average of 33.08 and Batting            Strike Rate of 150.35(Highest Among All Rounders) in PP3(41-50 Overs) since 2019 for India. Along this he has              taken 40 wickets with an Economy of 4.96 and Bowling Average of 28.58.
#     2. Ravindra Jadeja has scored 335 runs with a Batting average of 25.77 and Batting Strike Rate of 106.69(Highest              Among All Rounders) in PP3(41-50 Overs) since 2019 for India. Along this he has taken 39 wickets with an Economy of        4.9 and Bowling Average of 39.69.
#     3. Shardul Thakur has taken 59 wickets(Highest among Indian All ROunders) since 2019 for India.
#     4. Hardik Pandya has scored 132 runs(Highest among Indian All Rounders) with a Batting average of 33 and Batting              Strike Rate of 155.35(Highest Among All Rounders) in PP3(41-50 Overs) in 2023 for India. Along this he has taken            16 wickets with an Economy of 4.81 and Bowling Average of 24.85(least among All Rouunders).
#     5. Ravindra Jadeja has taken 15 wickets with an Economy of 4.65(least among All Rounders) and Bowling Average of              27.13 in 2023 for India.
#     6. Shardul Thakur has taken 21 wickets(Highest among Indian All ROunders) with a Bowling Average of 20.48(least                among All Rounders) in 2023 for India.

# %% [markdown]
# **All Rounders:**
#
#     1. Hardik Pandya
#     2. Ravidra Jadeja
#     3. Shardul Thakur (Though Ravidra Jadeja will be preferred more then Shardul Thakur as he is more explosive batter and        a better economical bowler. Shardul has more than 5.5 economy in his whole carrer which very costly for the team in        some cases.)
#     4. Axar Patel[Backup:Left Arm Off Spinners and explosive left handed finishers suitable in Indian subcontinental              Grounds in World Cup 2023]

# %% [markdown]
# ### Powerplay Bowlers

# %%
ODI_19_IND_bl_pp1=ODI_19_IND_bl[ODI_19_IND_bl['Overs']<=10]
ODI_19_IND_bl_pp1
# Out:
#         Source.Name  match_id   season start_date  \
# 134516  1144490.csv   1144490     2019 2019-06-05
# 134517  1144490.csv   1144490     2019 2019-06-05
# 134518  1144490.csv   1144490     2019 2019-06-05
# 134519  1144490.csv   1144490     2019 2019-06-05
# 134520  1144490.csv   1144490     2019 2019-06-05
# ...             ...       ...      ...        ...
# 450385  1389389.csv   1389389  2023/24 2023-09-24
# 450386  1389389.csv   1389389  2023/24 2023-09-24
# 450387  1389389.csv   1389389  2023/24 2023-09-24
# 450388  1389389.csv   1389389  2023/24 2023-09-24
# 450389  1389389.csv   1389389  2023/24 2023-09-24
#
#                                  venue  innings  ball  batting_team  \
# 134516                   The Rose Bowl        1   0.1  South Africa
# 134517                   The Rose Bowl        1   0.2  South Africa
# 134518                   The Rose Bowl        1   0.3  South Africa
# 134519                   The Rose Bowl        1   0.4  South Africa
# ...

# %%
ODI_19_IND_BALL_pp1=pd.pivot_table(ODI_19_IND_bl_pp1,index=["match_id","bowler"],
                              values=["runs_off_bat","ball","player_dismissed"],
               aggfunc={"runs_off_bat":"sum","ball":"count","player_dismissed":"count"})
ODI_19_IND_BALL_pp1.rename(columns={"runs_off_bat":"Runs Conceeded","ball":"Balls Delivered","player_dismissed":"Dismissals"},
                 inplace=True)
ODI_19_IND_BALL_pp1=pd.pivot_table(ODI_19_IND_BALL_pp1,index=['bowler'],
                                 values=["Runs Conceeded","Balls Delivered","Dismissals"],aggfunc="sum")
ODI_19_IND_BALL_pp1["Economy"]=round(ODI_19_IND_BALL_pp1["Runs Conceeded"]/ODI_19_IND_BALL_pp1["Balls Delivered"]*6,2)
ODI_19_IND_BALL_pp1["Bowling Average"]=round(ODI_19_IND_BALL_pp1["Runs Conceeded"]/ODI_19_IND_BALL_pp1["Dismissals"],2)
ODI_19_IND_BALL_pp1["Bowling Strike Rate"]=round(ODI_19_IND_BALL_pp1["Balls Delivered"]/ODI_19_IND_BALL_pp1["Dismissals"],2)
ODI_19_IND_BALL_pp1
# Out:
#                    Balls Delivered  Dismissals  Runs Conceeded  Economy  \
# bowler
# AR Patel                        48           1              49     6.12
# Arshdeep Singh                  44           0              37     5.05
# Avesh Khan                      98           0              80     4.90
# B Kumar                        728          12             492     4.05
# C Sakariya                      12           0               9     4.50
# DJ Hooda                        12           1               6     3.00
# DL Chahar                      291           9             214     4.41
# HH Pandya                      239           5             180     4.52
# JJ Bumrah                      790          16             462     3.51
# K Gowtham                       19           1              13     4.11
# KH Pandya                        6           0              16    16.00
# KK Ahmed                        81           0             107     7.93
# ...

# %%
ODI_23_IND_bl_pp1=ODI_23_IND_bl[ODI_23_IND_bl['Overs']<=10]
ODI_23_IND_bl_pp1
# Out:
#         Source.Name  match_id   season start_date  \
# 387308  1348643.csv   1348643  2022/23 2023-01-10
# 387309  1348643.csv   1348643  2022/23 2023-01-10
# 387310  1348643.csv   1348643  2022/23 2023-01-10
# 387311  1348643.csv   1348643  2022/23 2023-01-10
# 387312  1348643.csv   1348643  2022/23 2023-01-10
# ...             ...       ...      ...        ...
# 450385  1389389.csv   1389389  2023/24 2023-09-24
# 450386  1389389.csv   1389389  2023/24 2023-09-24
# 450387  1389389.csv   1389389  2023/24 2023-09-24
# 450388  1389389.csv   1389389  2023/24 2023-09-24
# 450389  1389389.csv   1389389  2023/24 2023-09-24
#
#                                       venue  innings  ball batting_team  \
# 387308  Barsapara Cricket Stadium, Guwahati        2   0.1    Sri Lanka
# 387309  Barsapara Cricket Stadium, Guwahati        2   0.2    Sri Lanka
# 387310  Barsapara Cricket Stadium, Guwahati        2   0.3    Sri Lanka
# ...

# %%
ODI_23_IND_BALL_pp1=pd.pivot_table(ODI_23_IND_bl_pp1,index=["match_id","bowler"],
                              values=["runs_off_bat","ball","player_dismissed"],
               aggfunc={"runs_off_bat":"sum","ball":"count","player_dismissed":"count"})
ODI_23_IND_BALL_pp1.rename(columns={"runs_off_bat":"Runs Conceeded","ball":"Balls Delivered","player_dismissed":"Dismissals"},
                 inplace=True)
ODI_23_IND_BALL_pp1=pd.pivot_table(ODI_23_IND_BALL_pp1,index=['bowler'],
                                 values=["Runs Conceeded","Balls Delivered","Dismissals"],aggfunc="sum")
ODI_23_IND_BALL_pp1["Economy"]=round(ODI_23_IND_BALL_pp1["Runs Conceeded"]/ODI_23_IND_BALL_pp1["Balls Delivered"]*6,2)
ODI_23_IND_BALL_pp1["Bowling Average"]=round(ODI_23_IND_BALL_pp1["Runs Conceeded"]/ODI_23_IND_BALL_pp1["Dismissals"],2)
ODI_23_IND_BALL_pp1["Bowling Strike Rate"]=round(ODI_23_IND_BALL_pp1["Balls Delivered"]/ODI_23_IND_BALL_pp1["Dismissals"],2)
ODI_23_IND_BALL_pp1
# Out:
#                    Balls Delivered  Dismissals  Runs Conceeded  Economy  \
# bowler
# AR Patel                        30           0              30     6.00
# HH Pandya                      143           3             114     4.78
# JJ Bumrah                      119           4              64     3.23
# Kuldeep Yadav                    6           0              12    12.00
# M Prasidh Krishna               32           2              31     5.81
# Mohammed Shami                 289           5             180     3.74
# Mohammed Siraj                 331          16             235     4.26
# Mukesh Kumar                    84           4              48     3.43
# R Ashwin                        12           0               9     4.50
# SN Thakur                      107           6             120     6.73
# Umran Malik                     19           0              29     9.16
# Washington Sundar               12           0              10     5.00
#
# ...

# %%
ODI_19_IND_BALL_pp1_wicket=ODI_19_IND_BALL_pp1.sort_values(by='Dismissals',ascending=False).head(5)
ODI_19_IND_BALL_pp1_wicket
# Out:
#                 Balls Delivered  Dismissals  Runs Conceeded  Economy  \
# bowler
# Mohammed Siraj              756          32             491     3.90
# Mohammed Shami              975          20             685     4.22
# JJ Bumrah                   790          16             462     3.51
# B Kumar                     728          12             492     4.05
# DL Chahar                   291           9             214     4.41
#
#                 Bowling Average  Bowling Strike Rate
# bowler
# Mohammed Siraj            15.34                23.62
# Mohammed Shami            34.25                48.75
# JJ Bumrah                 28.88                49.38
# B Kumar                   41.00                60.67
# DL Chahar                 23.78                32.33

# %%
ODI_23_IND_BALL_pp1_wicket=ODI_23_IND_BALL_pp1.sort_values(by='Dismissals',ascending=False).head(5)
ODI_23_IND_BALL_pp1_wicket
# Out:
#                 Balls Delivered  Dismissals  Runs Conceeded  Economy  \
# bowler
# Mohammed Siraj              331          16             235     4.26
# SN Thakur                   107           6             120     6.73
# Mohammed Shami              289           5             180     3.74
# JJ Bumrah                   119           4              64     3.23
# Mukesh Kumar                 84           4              48     3.43
#
#                 Bowling Average  Bowling Strike Rate
# bowler
# Mohammed Siraj            14.69                20.69
# SN Thakur                 20.00                17.83
# Mohammed Shami            36.00                57.80
# JJ Bumrah                 16.00                29.75
# Mukesh Kumar              12.00                21.00

# %%
ODI_19_IND_BALL_pp1_eco=ODI_19_IND_BALL_pp1[ODI_19_IND_BALL_pp1["Balls Delivered"]>=240].sort_values(by='Economy',ascending=True).head(5)
ODI_19_IND_BALL_pp1_eco
# Out:
#                 Balls Delivered  Dismissals  Runs Conceeded  Economy  \
# bowler
# JJ Bumrah                   790          16             462     3.51
# Mohammed Siraj              756          32             491     3.90
# B Kumar                     728          12             492     4.05
# Mohammed Shami              975          20             685     4.22
# DL Chahar                   291           9             214     4.41
#
#                 Bowling Average  Bowling Strike Rate
# bowler
# JJ Bumrah                 28.88                49.38
# Mohammed Siraj            15.34                23.62
# B Kumar                   41.00                60.67
# Mohammed Shami            34.25                48.75
# DL Chahar                 23.78                32.33

# %%
ODI_23_IND_BALL_pp1_eco=ODI_23_IND_BALL_pp1[ODI_23_IND_BALL_pp1["Balls Delivered"]>=85].sort_values(by='Economy',ascending=True).head(5)
ODI_23_IND_BALL_pp1_eco
# Out:
#                 Balls Delivered  Dismissals  Runs Conceeded  Economy  \
# bowler
# JJ Bumrah                   119           4              64     3.23
# Mohammed Shami              289           5             180     3.74
# Mohammed Siraj              331          16             235     4.26
# HH Pandya                   143           3             114     4.78
# SN Thakur                   107           6             120     6.73
#
#                 Bowling Average  Bowling Strike Rate
# bowler
# JJ Bumrah                 16.00                29.75
# Mohammed Shami            36.00                57.80
# Mohammed Siraj            14.69                20.69
# HH Pandya                 38.00                47.67
# SN Thakur                 20.00                17.83

# %%
ODI_19_IND_BALL_pp1_bavg=ODI_19_IND_BALL_pp1[ODI_19_IND_BALL_pp1["Balls Delivered"]>=240].sort_values(by='Bowling Average',ascending=True).head(5)
ODI_19_IND_BALL_pp1_bavg
# Out:
#                 Balls Delivered  Dismissals  Runs Conceeded  Economy  \
# bowler
# Mohammed Siraj              756          32             491     3.90
# DL Chahar                   291           9             214     4.41
# JJ Bumrah                   790          16             462     3.51
# Mohammed Shami              975          20             685     4.22
# B Kumar                     728          12             492     4.05
#
#                 Bowling Average  Bowling Strike Rate
# bowler
# Mohammed Siraj            15.34                23.62
# DL Chahar                 23.78                32.33
# JJ Bumrah                 28.88                49.38
# Mohammed Shami            34.25                48.75
# B Kumar                   41.00                60.67

# %%
ODI_23_IND_BALL_pp1_bavg=ODI_23_IND_BALL_pp1[ODI_23_IND_BALL_pp1["Balls Delivered"]>=85].sort_values(by='Bowling Average',ascending=True).head(5)
ODI_23_IND_BALL_pp1_bavg
# Out:
#                 Balls Delivered  Dismissals  Runs Conceeded  Economy  \
# bowler
# Mohammed Siraj              331          16             235     4.26
# JJ Bumrah                   119           4              64     3.23
# SN Thakur                   107           6             120     6.73
# Mohammed Shami              289           5             180     3.74
# HH Pandya                   143           3             114     4.78
#
#                 Bowling Average  Bowling Strike Rate
# bowler
# Mohammed Siraj            14.69                20.69
# JJ Bumrah                 16.00                29.75
# SN Thakur                 20.00                17.83
# Mohammed Shami            36.00                57.80
# HH Pandya                 38.00                47.67

# %%
ODI_19_IND_BALL_pp1_bSR=ODI_19_IND_BALL_pp1[ODI_19_IND_BALL_pp1["Balls Delivered"]>=240].sort_values(by='Bowling Strike Rate',ascending=True).head(5)
ODI_19_IND_BALL_pp1_bSR
# Out:
#                 Balls Delivered  Dismissals  Runs Conceeded  Economy  \
# bowler
# Mohammed Siraj              756          32             491     3.90
# DL Chahar                   291           9             214     4.41
# Mohammed Shami              975          20             685     4.22
# JJ Bumrah                   790          16             462     3.51
# SN Thakur                   358           7             348     5.83
#
#                 Bowling Average  Bowling Strike Rate
# bowler
# Mohammed Siraj            15.34                23.62
# DL Chahar                 23.78                32.33
# Mohammed Shami            34.25                48.75
# JJ Bumrah                 28.88                49.38
# SN Thakur                 49.71                51.14

# %%
ODI_23_IND_BALL_pp1_bSR=ODI_23_IND_BALL_pp1[ODI_23_IND_BALL_pp1["Balls Delivered"]>=85].sort_values(by='Bowling Strike Rate',ascending=True).head(5)
ODI_23_IND_BALL_pp1_bSR
# Out:
#                 Balls Delivered  Dismissals  Runs Conceeded  Economy  \
# bowler
# SN Thakur                   107           6             120     6.73
# Mohammed Siraj              331          16             235     4.26
# JJ Bumrah                   119           4              64     3.23
# HH Pandya                   143           3             114     4.78
# Mohammed Shami              289           5             180     3.74
#
#                 Bowling Average  Bowling Strike Rate
# bowler
# SN Thakur                 20.00                17.83
# Mohammed Siraj            14.69                20.69
# JJ Bumrah                 16.00                29.75
# HH Pandya                 38.00                47.67
# Mohammed Shami            36.00                57.80

# %%
ODI_19_IND_BALL_pp1_P=pd.pivot_table(ODI_19_IND_bl_pp1,index=["match_id","bowler"],
                              values=["runs_off_bat","ball","player_dismissed"],
               aggfunc={"runs_off_bat":"sum","ball":"count","player_dismissed":"count"})
ODI_19_IND_BALL_pp1_P.rename(columns={"runs_off_bat":"Runs Conceeded","ball":"Balls Delivered","player_dismissed":"Dismissals"},
                 inplace=True)
ODI_19_IND_BALL_pp1_P
# Out:
#                             Balls Delivered  Dismissals  Runs Conceeded
# match_id bowler
# 1144490  B Kumar                         30           0              20
#          JJ Bumrah                       30           2              13
# 1144496  B Kumar                         31           0              11
#          HH Pandya                       13           0              23
#          JJ Bumrah                       18           0              12
# ...                                     ...         ...             ...
# 1389388  SN Thakur                        6           0               9
# 1389389  M Prasidh Krishna               26           2              29
#          Mohammed Shami                  24           0              16
#          R Ashwin                         6           0               7
#          SN Thakur                        7           0               6
#
# [276 rows x 3 columns]

# %%
ODI_19_IND_BALL_pp1_1=pd.pivot_table(ODI_19_IND_BALL_pp1_P[ODI_19_IND_BALL_pp1_P['Dismissals']>1],index=['bowler'],values=['Dismissals'],
               aggfunc={'Dismissals':'count'})
ODI_19_IND_BALL_pp1_1.rename(columns={'Dismissals':'Dismissals(more than 1)'},inplace=True)
ODI_19_IND_BALL_pp1_1=ODI_19_IND_BALL_pp1_1.sort_values(by='Dismissals(more than 1)',ascending=False).head(5)
ODI_19_IND_BALL_pp1_1
# Out:
#                 Dismissals(more than 1)
# bowler
# Mohammed Siraj                        7
# Mohammed Shami                        5
# JJ Bumrah                             4
# B Kumar                               3
# DL Chahar                             3

# %%
ODI_23_IND_BALL_pp1_P=pd.pivot_table(ODI_23_IND_bl_pp1,index=["match_id","bowler"],
                              values=["runs_off_bat","ball","player_dismissed"],
               aggfunc={"runs_off_bat":"sum","ball":"count","player_dismissed":"count"})
ODI_23_IND_BALL_pp1_P.rename(columns={"runs_off_bat":"Runs Conceeded","ball":"Balls Delivered","player_dismissed":"Dismissals"},
                 inplace=True)
ODI_23_IND_BALL_pp1_P
# Out:
#                             Balls Delivered  Dismissals  Runs Conceeded
# match_id bowler
# 1348643  HH Pandya                        6           0               1
#          Mohammed Shami                  25           0              21
#          Mohammed Siraj                  30           2              15
# 1348644  HH Pandya                        6           0               5
#          Mohammed Shami                  25           0              20
# ...                                     ...         ...             ...
# 1389388  SN Thakur                        6           0               9
# 1389389  M Prasidh Krishna               26           2              29
#          Mohammed Shami                  24           0              16
#          R Ashwin                         6           0               7
#          SN Thakur                        7           0               6
#
# [62 rows x 3 columns]

# %%
ODI_23_IND_BALL_pp1_1=pd.pivot_table(ODI_23_IND_BALL_pp1_P[ODI_23_IND_BALL_pp1_P['Dismissals']>1],index=['bowler'],values=['Dismissals'],
               aggfunc={'Dismissals':'count'})
ODI_23_IND_BALL_pp1_1.rename(columns={'Dismissals':'Dismissals(more than 1)'},inplace=True)
ODI_23_IND_BALL_pp1_1=ODI_23_IND_BALL_pp1_1.sort_values(by='Dismissals(more than 1)',ascending=False).head(5)
ODI_23_IND_BALL_pp1_1
# Out:
#                    Dismissals(more than 1)
# bowler
# Mohammed Siraj                           3
# SN Thakur                                2
# JJ Bumrah                                1
# M Prasidh Krishna                        1
# Mohammed Shami                           1

# %%
ODI_19_IND_bl_pp1_dot=pd.pivot_table(ODI_19_IND_bl_pp1[ODI_19_IND_bl_pp1['runs_off_bat']==0],index='bowler',values='runs_off_bat',aggfunc={'runs_off_bat':'count'})
ODI_19_IND_bl_pp1_dot.rename(columns={'runs_off_bat':'Dot Balls'},inplace=True)
ODI_19_IND_bl_pp1_dot['Dot Ball(%)']=round((ODI_19_IND_bl_pp1_dot['Dot Balls']/ODI_19_IND_BALL_pp1['Balls Delivered'])*100,2)
ODI_19_IND_bl_pp1_dot=ODI_19_IND_bl_pp1_dot[ODI_19_IND_bl_pp1_dot['Dot Balls']>=175].sort_values(by='Dot Ball(%)',ascending=False).head(5)
ODI_19_IND_bl_pp1_dot
# Out:
#                 Dot Balls  Dot Ball(%)
# bowler
# Mohammed Siraj        558        73.81
# JJ Bumrah             583        73.80
# Mohammed Shami        697        71.49
# B Kumar               500        68.68
# DL Chahar             199        68.38

# %%
ODI_23_IND_bl_pp1_dot=pd.pivot_table(ODI_23_IND_bl_pp1[ODI_23_IND_bl_pp1['runs_off_bat']==0],index='bowler',values='runs_off_bat',aggfunc={'runs_off_bat':'count'})
ODI_23_IND_bl_pp1_dot.rename(columns={'runs_off_bat':'Dot Balls'},inplace=True)
ODI_23_IND_bl_pp1_dot['Dot Ball(%)']=round((ODI_23_IND_bl_pp1_dot['Dot Balls']/ODI_23_IND_BALL_pp1['Balls Delivered'])*100,2)
ODI_23_IND_bl_pp1_dot=ODI_23_IND_bl_pp1_dot[ODI_23_IND_bl_pp1_dot['Dot Balls']>=60].sort_values(by='Dot Ball(%)',ascending=False).head(5)
ODI_23_IND_bl_pp1_dot
# Out:
#                 Dot Balls  Dot Ball(%)
# bowler
# JJ Bumrah              93        78.15
# Mohammed Shami        221        76.47
# Mukesh Kumar           64        76.19
# Mohammed Siraj        243        73.41
# HH Pandya             102        71.33

# %%
plt.subplot(6,2,1)
ODI_19_IND_BALL_pp1_wicket['Dismissals'].plot(kind='bar',figsize=(12,5),color='orange')
for i in range(len(list(ODI_19_IND_BALL_pp1_wicket.index))):
    plt.text(i,ODI_19_IND_BALL_pp1_wicket['Dismissals'][i],ODI_19_IND_BALL_pp1_wicket['Dismissals'][i],ha='center')
plt.title('Top Wicket Takers [1-10 overs] of India(Since 2019)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Wickets Taken')
plt.subplot(6,2,2)
ODI_23_IND_BALL_pp1_wicket['Dismissals'].plot(kind='bar',figsize=(12,5),color='orange')
for i in range(len(list(ODI_23_IND_BALL_pp1_wicket.index))):
    plt.text(i,ODI_23_IND_BALL_pp1_wicket['Dismissals'][i],ODI_23_IND_BALL_pp1_wicket['Dismissals'][i],ha='center')
plt.title('Top Wicket Takers [1-10 overs] of India(In 2023)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Wickets Taken')
plt.subplot(6,2,3)
ODI_19_IND_BALL_pp1_eco['Economy'].plot(kind='bar',figsize=(12,5),color='green')
for i in range(len(list(ODI_19_IND_BALL_pp1_eco.index))):
    plt.text(i,ODI_19_IND_BALL_pp1_eco['Economy'][i],ODI_19_IND_BALL_pp1_eco['Economy'][i],ha='center')
plt.title('Least Economical bowlers [1-10 overs] (atleast 240 balls delivered) of India(Since 2019)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Economy')
plt.subplot(6,2,4)
ODI_23_IND_BALL_pp1_eco['Economy'].plot(kind='bar',figsize=(12,5),color='green')
for i in range(len(list(ODI_23_IND_BALL_pp1_eco.index))):
    plt.text(i,ODI_23_IND_BALL_pp1_eco['Economy'][i],ODI_23_IND_BALL_pp1_eco['Economy'][i],ha='center')
plt.title('Least Economical bowlers [1-10 overs] (atleast 85 balls delivered) of India(In 2023)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Economy')
plt.subplot(6,2,5)
ODI_19_IND_BALL_pp1_bavg['Bowling Average'].plot(kind='bar',figsize=(12,5),color='violet')
for i in range(len(list(ODI_19_IND_BALL_pp1_bavg.index))):
    plt.text(i,ODI_19_IND_BALL_pp1_bavg['Bowling Average'][i],ODI_19_IND_BALL_pp1_bavg['Bowling Average'][i],ha='center')
plt.title('Least Bowling Average [1-10 overs] (atleast 240 balls delivered) of India(Since 2019)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Bowling Average')
plt.subplot(6,2,6)
ODI_23_IND_BALL_pp1_bavg['Bowling Average'].plot(kind='bar',figsize=(12,5),color='violet')
for i in range(len(list(ODI_23_IND_BALL_pp1_bavg.index))):
    plt.text(i,ODI_23_IND_BALL_pp1_bavg['Bowling Average'][i],ODI_23_IND_BALL_pp1_bavg['Bowling Average'][i],ha='center')
plt.title('Least Bowling Average [1-10 overs] (atleast 85 balls delivered) of India(In 2023)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Bowling Average')
plt.subplot(6,2,7)
ODI_19_IND_BALL_pp1_bSR['Bowling Strike Rate'].plot(kind='bar',figsize=(12,5),color='brown')
for i in range(len(list(ODI_19_IND_BALL_pp1_bSR.index))):
    plt.text(i,ODI_19_IND_BALL_pp1_bSR['Bowling Strike Rate'][i],ODI_19_IND_BALL_pp1_bSR['Bowling Strike Rate'][i],ha='center')
plt.title('Least Bowling Strike Rate [1-10 overs] (atleast 240 balls delivered) of India(Since 2019)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Bowling Strike Rate')
plt.subplot(6,2,8)
ODI_23_IND_BALL_pp1_bSR['Bowling Strike Rate'].plot(kind='bar',figsize=(12,5),color='brown')
for i in range(len(list(ODI_23_IND_BALL_pp1_bSR.index))):
    plt.text(i,ODI_23_IND_BALL_pp1_bSR['Bowling Strike Rate'][i],ODI_23_IND_BALL_pp1_bSR['Bowling Strike Rate'][i],ha='center')
plt.title('Least Bowling Strike Rate [1-10 overs] (atleast 85 balls delivered) of India(In 2023)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Bowling Strike Rate')
plt.subplot(6,2,9)
ODI_19_IND_BALL_pp1_1['Dismissals(more than 1)'].plot(kind='bar',figsize=(12,5),color='gray')
for i in range(len(list(ODI_19_IND_BALL_pp1_1.index))):
    plt.text(i,ODI_19_IND_BALL_pp1_1['Dismissals(more than 1)'][i],ODI_19_IND_BALL_pp1_1['Dismissals(more than 1)'][i],ha='center')
plt.title('Top Multiple Wicket Takers [1-10 overs] (more than 1) for India(Since 2019)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Dismissals(more than 1)')
plt.subplot(6,2,10)
ODI_23_IND_BALL_pp1_1['Dismissals(more than 1)'].plot(kind='bar',figsize=(12,5),color='gray')
for i in range(len(list(ODI_23_IND_BALL_pp1_1.index))):
    plt.text(i,ODI_23_IND_BALL_pp1_1['Dismissals(more than 1)'][i],ODI_23_IND_BALL_pp1_1['Dismissals(more than 1)'][i],ha='center')
plt.title('Top Multiple Wicket Takers [1-10 overs] (more than 1) for India(In 2023)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Dismissals(more than 1)')
plt.subplots_adjust(left=0.1,bottom=0.01, right=1.5, top=4.5, wspace=0.4, hspace=0.8)
plt.subplot(6,2,11)
ODI_19_IND_bl_pp1_dot['Dot Ball(%)'].plot(kind='bar',figsize=(12,5),color='yellow')
for i in range(len(list(ODI_19_IND_bl_pp1_dot.index))):
    plt.text(i,ODI_19_IND_bl_pp1_dot['Dot Ball(%)'][i],ODI_19_IND_bl_pp1_dot['Dot Ball(%)'][i],ha='center')
plt.title('Top Dot Ball(%) [1-10 overs] (atleast 175 dot balls delivered) for India(Since 2019)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Dot Ball(%)')
plt.subplot(6,2,12)
ODI_23_IND_bl_pp1_dot['Dot Ball(%)'].plot(kind='bar',figsize=(12,5),color='yellow')
for i in range(len(list(ODI_23_IND_bl_pp1_dot.index))):
    plt.text(i,ODI_23_IND_bl_pp1_dot['Dot Ball(%)'][i],ODI_23_IND_bl_pp1_dot['Dot Ball(%)'][i],ha='center')
plt.title('Top Dot Ball(%) [1-10 overs] (atleast 60 dot balls delivered) for  India(In 2023)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Dot Ball(%)')
plt.show()

# %% [markdown]
# **Caution:**
#
#     1. Jasprit Bumrah was out of ground for couple of months due to injury.
#     2. Bhubaneshwar Kumar,Deepak Chahar is not in a scheme for 2023 world cup (BCCI doesn't give much chance to them to            prove himself).
#     3. Mohd. Siraj is the star performer  for India in 2023.He has bowled an exceptional spell against SriLanka in 2023 ODI        Asia Cup Final.

# %% [markdown]
# **Bowling Stats(Info) in PP1 (Overs 1-10):**
#
#     1. Mohammad Siraj is the highet wicket takers in pp1 [1-10 overs] since 2019 (32 wickets with 7 times multiple wickets)        with least bowling average(15.34), highest dot ball(%) (73.81) and also in present year (2023) (16 wickets with 3          time multiple wickets) least bowling average(14.69) for India.
#     2. Jasprit Bumrah is the best econoic bowler in pp1 [1-10 overs] since 2019( Economy:3.51) and also in present year            (2023)(Economy: 3.23 with most dot ball(%): 78.15) for India.Rather he bocome more economical in 2023.
#     3. Mohmd. Shami is the 2nd highest wicket takers in pp1 [1-10 overs] since 2019 (20 wickets with 5 times multiple              wickets). He has 2nd most dot ball (%)(76.47) in 2023 for India in pp1.

# %% [markdown]
# **Powerplay Bowlers:**
#
#     1. Mohmd. Siraj
#     2. Jasprit Bumrah
#     3. Mohmd. Shami

# %% [markdown]
# ### Middle Overs

# %%
ODI_19_IND_bl_pp2=ODI_19_IND_bl[(ODI_19_IND_bl['Overs']>10)&(ODI_19_IND_bl['Overs']<=40)]
ODI_19_IND_bl_pp2
# Out:
#         Source.Name  match_id   season start_date  \
# 134576  1144490.csv   1144490     2019 2019-06-05
# 134577  1144490.csv   1144490     2019 2019-06-05
# 134578  1144490.csv   1144490     2019 2019-06-05
# 134579  1144490.csv   1144490     2019 2019-06-05
# 134580  1144490.csv   1144490     2019 2019-06-05
# ...             ...       ...      ...        ...
# 450495  1389389.csv   1389389  2023/24 2023-09-24
# 450496  1389389.csv   1389389  2023/24 2023-09-24
# 450497  1389389.csv   1389389  2023/24 2023-09-24
# 450498  1389389.csv   1389389  2023/24 2023-09-24
# 450499  1389389.csv   1389389  2023/24 2023-09-24
#
#                                  venue  innings  ball  batting_team  \
# 134576                   The Rose Bowl        1  10.1  South Africa
# 134577                   The Rose Bowl        1  10.2  South Africa
# 134578                   The Rose Bowl        1  10.3  South Africa
# 134579                   The Rose Bowl        1  10.4  South Africa
# ...

# %%
ODI_23_IND_bl_pp2=ODI_23_IND_bl[(ODI_23_IND_bl['Overs']>10)&(ODI_23_IND_bl['Overs']<=40)]
ODI_23_IND_bl_pp2
# Out:
#         Source.Name  match_id   season start_date  \
# 387369  1348643.csv   1348643  2022/23 2023-01-10
# 387370  1348643.csv   1348643  2022/23 2023-01-10
# 387371  1348643.csv   1348643  2022/23 2023-01-10
# 387372  1348643.csv   1348643  2022/23 2023-01-10
# 387373  1348643.csv   1348643  2022/23 2023-01-10
# ...             ...       ...      ...        ...
# 450495  1389389.csv   1389389  2023/24 2023-09-24
# 450496  1389389.csv   1389389  2023/24 2023-09-24
# 450497  1389389.csv   1389389  2023/24 2023-09-24
# 450498  1389389.csv   1389389  2023/24 2023-09-24
# 450499  1389389.csv   1389389  2023/24 2023-09-24
#
#                                       venue  innings  ball batting_team  \
# 387369  Barsapara Cricket Stadium, Guwahati        2  10.1    Sri Lanka
# 387370  Barsapara Cricket Stadium, Guwahati        2  10.2    Sri Lanka
# 387371  Barsapara Cricket Stadium, Guwahati        2  10.3    Sri Lanka
# ...

# %%
ODI_19_IND_BALL_pp2=pd.pivot_table(ODI_19_IND_bl_pp2,index=["match_id","bowler"],
                              values=["runs_off_bat","ball","player_dismissed"],
               aggfunc={"runs_off_bat":"sum","ball":"count","player_dismissed":"count"})
ODI_19_IND_BALL_pp2.rename(columns={"runs_off_bat":"Runs Conceeded","ball":"Balls Delivered","player_dismissed":"Dismissals"},
                 inplace=True)
ODI_19_IND_BALL_pp2=pd.pivot_table(ODI_19_IND_BALL_pp2,index=['bowler'],
                                 values=["Runs Conceeded","Balls Delivered","Dismissals"],aggfunc="sum")
ODI_19_IND_BALL_pp2["Economy"]=round(ODI_19_IND_BALL_pp2["Runs Conceeded"]/ODI_19_IND_BALL_pp2["Balls Delivered"]*6,2)
ODI_19_IND_BALL_pp2["Bowling Average"]=round(ODI_19_IND_BALL_pp2["Runs Conceeded"]/ODI_19_IND_BALL_pp2["Dismissals"],2)
ODI_19_IND_BALL_pp2["Bowling Strike Rate"]=round(ODI_19_IND_BALL_pp2["Balls Delivered"]/ODI_19_IND_BALL_pp2["Dismissals"],2)
ODI_19_IND_BALL_pp2
# Out:
#                    Balls Delivered  Dismissals  Runs Conceeded  Economy  \
# bowler
# AR Patel                       489          12             369     4.53
# AT Rayudu                       12           0              13     6.50
# Arshdeep Singh                  31           0              32     6.19
# Avesh Khan                      94           1              75     4.79
# B Kumar                        304          12             263     5.19
# C Sakariya                      39           2              22     3.38
# DJ Hooda                       142           2             107     4.52
# DL Chahar                      150           7             134     5.36
# HH Pandya                      957          26             766     4.80
# J Yadav                         62           0              47     4.55
# JD Unadkat                      30           1              16     3.20
# JJ Bumrah                      536          13             433     4.85
# ...

# %%
ODI_23_IND_BALL_pp2=pd.pivot_table(ODI_23_IND_bl_pp2,index=["match_id","bowler"],
                              values=["runs_off_bat","ball","player_dismissed"],
               aggfunc={"runs_off_bat":"sum","ball":"count","player_dismissed":"count"})
ODI_23_IND_BALL_pp2.rename(columns={"runs_off_bat":"Runs Conceeded","ball":"Balls Delivered","player_dismissed":"Dismissals"},
                 inplace=True)
ODI_23_IND_BALL_pp2=pd.pivot_table(ODI_23_IND_BALL_pp2,index=['bowler'],
                                 values=["Runs Conceeded","Balls Delivered","Dismissals"],aggfunc="sum")
ODI_23_IND_BALL_pp2["Economy"]=round(ODI_23_IND_BALL_pp2["Runs Conceeded"]/ODI_23_IND_BALL_pp2["Balls Delivered"]*6,2)
ODI_23_IND_BALL_pp2["Bowling Average"]=round(ODI_23_IND_BALL_pp2["Runs Conceeded"]/ODI_23_IND_BALL_pp2["Dismissals"],2)
ODI_23_IND_BALL_pp2["Bowling Strike Rate"]=round(ODI_23_IND_BALL_pp2["Balls Delivered"]/ODI_23_IND_BALL_pp2["Dismissals"],2)
ODI_23_IND_BALL_pp2
# Out:
#                    Balls Delivered  Dismissals  Runs Conceeded  Economy  \
# bowler
# AR Patel                       188           4             160     5.11
# HH Pandya                      284          10             224     4.73
# JD Unadkat                      30           1              16     3.20
# JJ Bumrah                       30           0              25     5.00
# Kuldeep Yadav                  601          29             418     4.17
# M Prasidh Krishna               43           0              43     6.00
# Mohammed Shami                 153          10             127     4.98
# Mohammed Siraj                 114           9              82     4.32
# Mukesh Kumar                    14           0              13     5.57
# R Ashwin                        90           4              79     5.27
# RA Jadeja                      501          15             375     4.49
# SN Thakur                      302          13             252     5.01
# ...

# %%
ODI_19_IND_BALL_pp2_wicket=ODI_19_IND_BALL_pp2.sort_values(by='Dismissals',ascending=False).head(5)
ODI_19_IND_BALL_pp2_wicket
# Out:
#                 Balls Delivered  Dismissals  Runs Conceeded  Economy  \
# bowler
# Kuldeep Yadav              2611          77            2188     5.03
# YS Chahal                  1629          45            1439     5.30
# SN Thakur                  1104          43             950     5.16
# RA Jadeja                  1807          38            1453     4.82
# Mohammed Shami              729          33             625     5.14
#
#                 Bowling Average  Bowling Strike Rate
# bowler
# Kuldeep Yadav             28.42                33.91
# YS Chahal                 31.98                36.20
# SN Thakur                 22.09                25.67
# RA Jadeja                 38.24                47.55
# Mohammed Shami            18.94                22.09

# %%
ODI_23_IND_BALL_pp2_wicket=ODI_23_IND_BALL_pp2.sort_values(by='Dismissals',ascending=False).head(5)
ODI_23_IND_BALL_pp2_wicket
# Out:
#                 Balls Delivered  Dismissals  Runs Conceeded  Economy  \
# bowler
# Kuldeep Yadav               601          29             418     4.17
# RA Jadeja                   501          15             375     4.49
# SN Thakur                   302          13             252     5.01
# Mohammed Shami              153          10             127     4.98
# HH Pandya                   284          10             224     4.73
#
#                 Bowling Average  Bowling Strike Rate
# bowler
# Kuldeep Yadav             14.41                20.72
# RA Jadeja                 25.00                33.40
# SN Thakur                 19.38                23.23
# Mohammed Shami            12.70                15.30
# HH Pandya                 22.40                28.40

# %%
ODI_19_IND_BALL_pp2_eco=ODI_19_IND_BALL_pp2[ODI_19_IND_BALL_pp2["Balls Delivered"]>=700].sort_values(by='Economy',ascending=True).head(5)
ODI_19_IND_BALL_pp2_eco
# Out:
#                 Balls Delivered  Dismissals  Runs Conceeded  Economy  \
# bowler
# HH Pandya                   957          26             766     4.80
# RA Jadeja                  1807          38            1453     4.82
# Kuldeep Yadav              2611          77            2188     5.03
# Mohammed Shami              729          33             625     5.14
# SN Thakur                  1104          43             950     5.16
#
#                 Bowling Average  Bowling Strike Rate
# bowler
# HH Pandya                 29.46                36.81
# RA Jadeja                 38.24                47.55
# Kuldeep Yadav             28.42                33.91
# Mohammed Shami            18.94                22.09
# SN Thakur                 22.09                25.67

# %%
ODI_23_IND_BALL_pp2_eco=ODI_23_IND_BALL_pp2[ODI_23_IND_BALL_pp2["Balls Delivered"]>=150].sort_values(by='Economy',ascending=True).head(5)
ODI_23_IND_BALL_pp2_eco
# Out:
#                 Balls Delivered  Dismissals  Runs Conceeded  Economy  \
# bowler
# Kuldeep Yadav               601          29             418     4.17
# RA Jadeja                   501          15             375     4.49
# HH Pandya                   284          10             224     4.73
# Mohammed Shami              153          10             127     4.98
# SN Thakur                   302          13             252     5.01
#
#                 Bowling Average  Bowling Strike Rate
# bowler
# Kuldeep Yadav             14.41                20.72
# RA Jadeja                 25.00                33.40
# HH Pandya                 22.40                28.40
# Mohammed Shami            12.70                15.30
# SN Thakur                 19.38                23.23

# %%
ODI_19_IND_BALL_pp2_bavg=ODI_19_IND_BALL_pp2[ODI_19_IND_BALL_pp2["Balls Delivered"]>=700].sort_values(by='Bowling Average',ascending=True).head(5)
ODI_19_IND_BALL_pp2_bavg
# Out:
#                 Balls Delivered  Dismissals  Runs Conceeded  Economy  \
# bowler
# Mohammed Shami              729          33             625     5.14
# SN Thakur                  1104          43             950     5.16
# Kuldeep Yadav              2611          77            2188     5.03
# HH Pandya                   957          26             766     4.80
# YS Chahal                  1629          45            1439     5.30
#
#                 Bowling Average  Bowling Strike Rate
# bowler
# Mohammed Shami            18.94                22.09
# SN Thakur                 22.09                25.67
# Kuldeep Yadav             28.42                33.91
# HH Pandya                 29.46                36.81
# YS Chahal                 31.98                36.20

# %%
ODI_23_IND_BALL_pp2_bavg=ODI_23_IND_BALL_pp2[ODI_23_IND_BALL_pp2["Balls Delivered"]>=150].sort_values(by='Bowling Average',ascending=True).head(5)
ODI_23_IND_BALL_pp2_bavg
# Out:
#                 Balls Delivered  Dismissals  Runs Conceeded  Economy  \
# bowler
# Mohammed Shami              153          10             127     4.98
# Kuldeep Yadav               601          29             418     4.17
# SN Thakur                   302          13             252     5.01
# HH Pandya                   284          10             224     4.73
# RA Jadeja                   501          15             375     4.49
#
#                 Bowling Average  Bowling Strike Rate
# bowler
# Mohammed Shami            12.70                15.30
# Kuldeep Yadav             14.41                20.72
# SN Thakur                 19.38                23.23
# HH Pandya                 22.40                28.40
# RA Jadeja                 25.00                33.40

# %%
ODI_19_IND_BALL_pp2_bSR=ODI_19_IND_BALL_pp2[ODI_19_IND_BALL_pp2["Balls Delivered"]>=700].sort_values(by='Bowling Strike Rate',ascending=True).head(5)
ODI_19_IND_BALL_pp2_bSR
# Out:
#                 Balls Delivered  Dismissals  Runs Conceeded  Economy  \
# bowler
# Mohammed Shami              729          33             625     5.14
# SN Thakur                  1104          43             950     5.16
# Kuldeep Yadav              2611          77            2188     5.03
# YS Chahal                  1629          45            1439     5.30
# HH Pandya                   957          26             766     4.80
#
#                 Bowling Average  Bowling Strike Rate
# bowler
# Mohammed Shami            18.94                22.09
# SN Thakur                 22.09                25.67
# Kuldeep Yadav             28.42                33.91
# YS Chahal                 31.98                36.20
# HH Pandya                 29.46                36.81

# %%
ODI_23_IND_BALL_pp2_bSR=ODI_23_IND_BALL_pp2[ODI_23_IND_BALL_pp2["Balls Delivered"]>=150].sort_values(by='Bowling Strike Rate',ascending=True).head(5)
ODI_23_IND_BALL_pp2_bSR
# Out:
#                 Balls Delivered  Dismissals  Runs Conceeded  Economy  \
# bowler
# Mohammed Shami              153          10             127     4.98
# Kuldeep Yadav               601          29             418     4.17
# SN Thakur                   302          13             252     5.01
# HH Pandya                   284          10             224     4.73
# RA Jadeja                   501          15             375     4.49
#
#                 Bowling Average  Bowling Strike Rate
# bowler
# Mohammed Shami            12.70                15.30
# Kuldeep Yadav             14.41                20.72
# SN Thakur                 19.38                23.23
# HH Pandya                 22.40                28.40
# RA Jadeja                 25.00                33.40

# %%
ODI_19_IND_BALL_pp2_P=pd.pivot_table(ODI_19_IND_bl_pp2,index=["match_id","bowler"],
                              values=["runs_off_bat","ball","player_dismissed"],
               aggfunc={"runs_off_bat":"sum","ball":"count","player_dismissed":"count"})
ODI_19_IND_BALL_pp2_P.rename(columns={"runs_off_bat":"Runs Conceeded","ball":"Balls Delivered","player_dismissed":"Dismissals"},
                 inplace=True)
ODI_19_IND_BALL_pp2_P
# Out:
#                             Balls Delivered  Dismissals  Runs Conceeded
# match_id bowler
# 1144490  B Kumar                         12           0               5
#          HH Pandya                       30           0              22
#          JJ Bumrah                       12           0               6
#          KM Jadhav                       24           0              16
#          Kuldeep Yadav                   54           1              43
# ...                                     ...         ...             ...
# 1389389  M Prasidh Krishna               12           0              25
#          Mohammed Shami                  12           1              23
#          R Ashwin                        36           3              34
#          RA Jadeja                       32           3              42
#          SN Thakur                       18           1              28
#
# [450 rows x 3 columns]

# %%
ODI_19_IND_BALL_pp2_1=pd.pivot_table(ODI_19_IND_BALL_pp2_P[ODI_19_IND_BALL_pp2_P['Dismissals']>1],index=['bowler'],values=['Dismissals'],
               aggfunc={'Dismissals':'count'})
ODI_19_IND_BALL_pp2_1.rename(columns={'Dismissals':'Dismissals(more than 1)'},inplace=True)
ODI_19_IND_BALL_pp2_1=ODI_19_IND_BALL_pp2_1.sort_values(by='Dismissals(more than 1)',ascending=False).head(5)
ODI_19_IND_BALL_pp2_1
# Out:
#                 Dismissals(more than 1)
# bowler
# Kuldeep Yadav                        22
# YS Chahal                            12
# SN Thakur                            12
# RA Jadeja                            11
# Mohammed Shami                        8

# %%
ODI_23_IND_BALL_pp2_P=pd.pivot_table(ODI_23_IND_bl_pp2,index=["match_id","bowler"],
                              values=["runs_off_bat","ball","player_dismissed"],
               aggfunc={"runs_off_bat":"sum","ball":"count","player_dismissed":"count"})
ODI_23_IND_BALL_pp2_P.rename(columns={"runs_off_bat":"Runs Conceeded","ball":"Balls Delivered","player_dismissed":"Dismissals"},
                 inplace=True)
ODI_23_IND_BALL_pp2_P
# Out:
#                             Balls Delivered  Dismissals  Runs Conceeded
# match_id bowler
# 1348643  AR Patel                        30           0              32
#          HH Pandya                       32           1              30
#          Mohammed Shami                  13           1               9
#          Mohammed Siraj                  12           0              15
#          Umran Malik                     39           3              29
# ...                                     ...         ...             ...
# 1389389  M Prasidh Krishna               12           0              25
#          Mohammed Shami                  12           1              23
#          R Ashwin                        36           3              34
#          RA Jadeja                       32           3              42
#          SN Thakur                       18           1              28
#
# [95 rows x 3 columns]

# %%
ODI_23_IND_BALL_pp2_1=pd.pivot_table(ODI_23_IND_BALL_pp2_P[ODI_23_IND_BALL_pp2_P['Dismissals']>1],index=['bowler'],values=['Dismissals'],
               aggfunc={'Dismissals':'count'})
ODI_23_IND_BALL_pp2_1.rename(columns={'Dismissals':'Dismissals(more than 1)'},inplace=True)
ODI_23_IND_BALL_pp2_1=ODI_23_IND_BALL_pp2_1.sort_values(by='Dismissals(more than 1)',ascending=False).head(5)
ODI_23_IND_BALL_pp2_1
# Out:
#                 Dismissals(more than 1)
# bowler
# Kuldeep Yadav                         9
# RA Jadeja                             5
# Mohammed Siraj                        3
# HH Pandya                             2
# Mohammed Shami                        2

# %%
ODI_19_IND_bl_pp2_dot=pd.pivot_table(ODI_19_IND_bl_pp2[ODI_19_IND_bl_pp2['runs_off_bat']==0],index='bowler',values='runs_off_bat',aggfunc={'runs_off_bat':'count'})
ODI_19_IND_bl_pp2_dot.rename(columns={'runs_off_bat':'Dot Balls'},inplace=True)
ODI_19_IND_bl_pp2_dot['Dot Ball(%)']=round((ODI_19_IND_bl_pp2_dot['Dot Balls']/ODI_19_IND_BALL_pp2['Balls Delivered'])*100,2)
ODI_19_IND_bl_pp2_dot=ODI_19_IND_bl_pp2_dot[ODI_19_IND_bl_pp2_dot['Dot Balls']>=325].sort_values(by='Dot Ball(%)',ascending=False).head(5)
ODI_19_IND_bl_pp2_dot
# Out:
#                 Dot Balls  Dot Ball(%)
# bowler
# SN Thakur             608        55.07
# HH Pandya             512        53.50
# Mohammed Shami        389        53.36
# Kuldeep Yadav        1299        49.75
# YS Chahal             806        49.48

# %%
ODI_23_IND_bl_pp2_dot=pd.pivot_table(ODI_23_IND_bl_pp2[ODI_23_IND_bl_pp2['runs_off_bat']==0],index='bowler',values='runs_off_bat',aggfunc={'runs_off_bat':'count'})
ODI_23_IND_bl_pp2_dot.rename(columns={'runs_off_bat':'Dot Balls'},inplace=True)
ODI_23_IND_bl_pp2_dot['Dot Ball(%)']=round((ODI_23_IND_bl_pp2_dot['Dot Balls']/ODI_23_IND_BALL_pp2['Balls Delivered'])*100,2)
ODI_23_IND_bl_pp2_dot=ODI_23_IND_bl_pp2_dot[ODI_23_IND_bl_pp2_dot['Dot Balls']>=90].sort_values(by='Dot Ball(%)',ascending=False).head(5)
ODI_23_IND_bl_pp2_dot
# Out:
#                 Dot Balls  Dot Ball(%)
# bowler
# Kuldeep Yadav         362        60.23
# HH Pandya             169        59.51
# SN Thakur             179        59.27
# Mohammed Shami         90        58.82
# AR Patel              100        53.19

# %%
plt.subplot(6,2,1)
ODI_19_IND_BALL_pp2_wicket['Dismissals'].plot(kind='bar',figsize=(12,5),color='orange')
for i in range(len(list(ODI_19_IND_BALL_pp2_wicket.index))):
    plt.text(i,ODI_19_IND_BALL_pp2_wicket['Dismissals'][i],ODI_19_IND_BALL_pp2_wicket['Dismissals'][i],ha='center')
plt.title('Top Wicket Takers [11-40 overs] of India(Since 2019)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Wickets Taken')
plt.subplot(6,2,2)
ODI_23_IND_BALL_pp2_wicket['Dismissals'].plot(kind='bar',figsize=(12,5),color='orange')
for i in range(len(list(ODI_23_IND_BALL_pp2_wicket.index))):
    plt.text(i,ODI_23_IND_BALL_pp2_wicket['Dismissals'][i],ODI_23_IND_BALL_pp2_wicket['Dismissals'][i],ha='center')
plt.title('Top Wicket Takers [11-40 overs] of India(In 2023)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Wickets Taken')
plt.subplot(6,2,3)
ODI_19_IND_BALL_pp2_eco['Economy'].plot(kind='bar',figsize=(12,5),color='green')
for i in range(len(list(ODI_19_IND_BALL_pp2_eco.index))):
    plt.text(i,ODI_19_IND_BALL_pp2_eco['Economy'][i],ODI_19_IND_BALL_pp2_eco['Economy'][i],ha='center')
plt.title('Least Economical bowlers [11-40 overs] (atleast 700 balls delivered) of India(Since 2019)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Economy')
plt.subplot(6,2,4)
ODI_23_IND_BALL_pp2_eco['Economy'].plot(kind='bar',figsize=(12,5),color='green')
for i in range(len(list(ODI_23_IND_BALL_pp2_eco.index))):
    plt.text(i,ODI_23_IND_BALL_pp2_eco['Economy'][i],ODI_23_IND_BALL_pp2_eco['Economy'][i],ha='center')
plt.title('Least Economical bowlers [11-40 overs] (atleast 150 balls delivered) of India(In 2023)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Economy')
plt.subplot(6,2,5)
ODI_19_IND_BALL_pp2_bavg['Bowling Average'].plot(kind='bar',figsize=(12,5),color='violet')
for i in range(len(list(ODI_19_IND_BALL_pp2_bavg.index))):
    plt.text(i,ODI_19_IND_BALL_pp2_bavg['Bowling Average'][i],ODI_19_IND_BALL_pp2_bavg['Bowling Average'][i],ha='center')
plt.title('Least Bowling Average [11-40 overs] (atleast 700 balls delivered) of India(Since 2019)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Bowling Average')
plt.subplot(6,2,6)
ODI_23_IND_BALL_pp2_bavg['Bowling Average'].plot(kind='bar',figsize=(12,5),color='violet')
for i in range(len(list(ODI_23_IND_BALL_pp2_bavg.index))):
    plt.text(i,ODI_23_IND_BALL_pp2_bavg['Bowling Average'][i],ODI_23_IND_BALL_pp2_bavg['Bowling Average'][i],ha='center')
plt.title('Least Bowling Average [11-40 overs] (atleast 150 balls delivered) of India(In 2023)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Bowling Average')
plt.subplot(6,2,7)
ODI_19_IND_BALL_pp2_bSR['Bowling Strike Rate'].plot(kind='bar',figsize=(12,5),color='brown')
for i in range(len(list(ODI_19_IND_BALL_pp2_bSR.index))):
    plt.text(i,ODI_19_IND_BALL_pp2_bSR['Bowling Strike Rate'][i],ODI_19_IND_BALL_pp2_bSR['Bowling Strike Rate'][i],ha='center')
plt.title('Least Bowling Strike Rate [11-40 overs] (atleast 700 balls delivered) of India(Since 2019)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Bowling Strike Rate')
plt.subplot(6,2,8)
ODI_23_IND_BALL_pp2_bSR['Bowling Strike Rate'].plot(kind='bar',figsize=(12,5),color='brown')
for i in range(len(list(ODI_23_IND_BALL_pp2_bSR.index))):
    plt.text(i,ODI_23_IND_BALL_pp2_bSR['Bowling Strike Rate'][i],ODI_23_IND_BALL_pp2_bSR['Bowling Strike Rate'][i],ha='center')
plt.title('Least Bowling Strike Rate [11-40 overs] (atleast 150 balls delivered) of India(In 2023)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Bowling Strike Rate')
plt.subplot(6,2,9)
ODI_19_IND_BALL_pp2_1['Dismissals(more than 1)'].plot(kind='bar',figsize=(12,5),color='gray')
for i in range(len(list(ODI_19_IND_BALL_pp2_1.index))):
    plt.text(i,ODI_19_IND_BALL_pp2_1['Dismissals(more than 1)'][i],ODI_19_IND_BALL_pp2_1['Dismissals(more than 1)'][i],ha='center')
plt.title('Top Multiple Wicket Takers [11-40 overs] (more than 1) for India(Since 2019)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Dismissals(more than 1)')
plt.subplot(6,2,10)
ODI_23_IND_BALL_pp2_1['Dismissals(more than 1)'].plot(kind='bar',figsize=(12,5),color='gray')
for i in range(len(list(ODI_23_IND_BALL_pp2_1.index))):
    plt.text(i,ODI_23_IND_BALL_pp2_1['Dismissals(more than 1)'][i],ODI_23_IND_BALL_pp2_1['Dismissals(more than 1)'][i],ha='center')
plt.title('Top Multiple Wicket Takers [11-40 overs] (more than 1) for India(In 2023)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Dismissals(more than 1)')
plt.subplots_adjust(left=0.1,bottom=0.01, right=1.5, top=4.5, wspace=0.4, hspace=0.8)
plt.subplot(6,2,11)
ODI_19_IND_bl_pp2_dot['Dot Ball(%)'].plot(kind='bar',figsize=(12,5),color='yellow')
for i in range(len(list(ODI_19_IND_bl_pp2_dot.index))):
    plt.text(i,ODI_19_IND_bl_pp2_dot['Dot Ball(%)'][i],ODI_19_IND_bl_pp2_dot['Dot Ball(%)'][i],ha='center')
plt.title('Top Dot Ball(%) [11-40 overs] (atleast 325 dot balls delivered) for India(Since 2019)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Dot Ball(%)')
plt.subplot(6,2,12)
ODI_23_IND_bl_pp2_dot['Dot Ball(%)'].plot(kind='bar',figsize=(12,5),color='yellow')
for i in range(len(list(ODI_23_IND_bl_pp2_dot.index))):
    plt.text(i,ODI_23_IND_bl_pp2_dot['Dot Ball(%)'][i],ODI_23_IND_bl_pp2_dot['Dot Ball(%)'][i],ha='center')
plt.title('Top Dot Ball(%) [11-40 overs] (atleast 90 dot balls delivered) for India(In 2023)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Dot Ball(%)')
plt.show()

# %% [markdown]
# **Caution:**
#
#     1. Yuzi Chahal is not in a scheme for 2023 world cup (BCCI doesn't give much chance to him to prove himself).
#     2. Shardul Thakur is an wicket taker but his economy is not good.

# %% [markdown]
# **Bowling Stats(Info) in PP2 (Overs 11-40):**
#
#     1. Kuldeep Yadav is the highet wicket takers in pp2 [11-40 overs] since 2019 (77 wickets with 22 times multiple              wickets)and also in present year (2023) (29 wickets with 9 time multiple wickets) least economy(4.17),highest dot          ball(%)(60.23) for India.
#     2. Hardik Pandya is the most econoic bowler in pp2 [11-40 overs] since 2019(Economy:4.8) for India.
#     3. Mohmd. Shami has least bowling average(18.94) in pp2 [11-40 overs] since 2019 and also in present year (2023)              (12.7).
#     4. Ravindra Jadeja is the 2nd least econoic bowler in pp2 [11-40 overs] since 2019( Economy:4.82) and also in present          year (2023)(Economy: 4.49) for India.
#     5. Shardul Tahkur has highest dot ball(%) (55.07) and 2nd highest bowling average(22.09) in pp2 [11-40 overs] for              India.

# %% [markdown]
# **Middle Overs:**
#
#     1. Kuldeep Yadav
#     2. Mohmd. Shami
#     3. Ravindra Jadeja
#     4. Shardul Thakur
#     5. Hardik Pandya
#     6. Yuzi Chahal [Bakup:He is the 2nd leading wicket takers (45 wickets) for India Since 2019. Moreover Kuldeep and              Chahal together make mervellous performance in middle over for India in 2018-20 (If India Consider his experience          rather than his per formance)]

# %% [markdown]
# ### Death Overs

# %%
ODI_19_IND_bl_pp3=ODI_19_IND_bl[ODI_19_IND_bl['Overs']>40]
ODI_19_IND_bl_pp3
# Out:
#         Source.Name  match_id   season start_date  \
# 134759  1144490.csv   1144490     2019 2019-06-05
# 134760  1144490.csv   1144490     2019 2019-06-05
# 134761  1144490.csv   1144490     2019 2019-06-05
# 134762  1144490.csv   1144490     2019 2019-06-05
# 134763  1144490.csv   1144490     2019 2019-06-05
# ...             ...       ...      ...        ...
# 449717  1389388.csv   1389388  2023/24 2023-09-22
# 449718  1389388.csv   1389388  2023/24 2023-09-22
# 449719  1389388.csv   1389388  2023/24 2023-09-22
# 449720  1389388.csv   1389388  2023/24 2023-09-22
# 449721  1389388.csv   1389388  2023/24 2023-09-22
#
#                                                     venue  innings  ball  \
# 134759                                      The Rose Bowl        1  40.1
# 134760                                      The Rose Bowl        1  40.2
# 134761                                      The Rose Bowl        1  40.3
# ...

# %%
ODI_23_IND_bl_pp3=ODI_23_IND_bl[ODI_23_IND_bl['Overs']>40]
ODI_23_IND_bl_pp3
# Out:
#         Source.Name  match_id   season start_date  \
# 387555  1348643.csv   1348643  2022/23 2023-01-10
# 387556  1348643.csv   1348643  2022/23 2023-01-10
# 387557  1348643.csv   1348643  2022/23 2023-01-10
# 387558  1348643.csv   1348643  2022/23 2023-01-10
# 387559  1348643.csv   1348643  2022/23 2023-01-10
# ...             ...       ...      ...        ...
# 449717  1389388.csv   1389388  2023/24 2023-09-22
# 449718  1389388.csv   1389388  2023/24 2023-09-22
# 449719  1389388.csv   1389388  2023/24 2023-09-22
# 449720  1389388.csv   1389388  2023/24 2023-09-22
# 449721  1389388.csv   1389388  2023/24 2023-09-22
#
#                                                     venue  innings  ball  \
# 387555                Barsapara Cricket Stadium, Guwahati        2  40.1
# 387556                Barsapara Cricket Stadium, Guwahati        2  40.2
# 387557                Barsapara Cricket Stadium, Guwahati        2  40.3
# ...

# %%
ODI_19_IND_BALL_pp3=pd.pivot_table(ODI_19_IND_bl_pp3,index=["match_id","bowler"],
                              values=["runs_off_bat","ball","player_dismissed"],
               aggfunc={"runs_off_bat":"sum","ball":"count","player_dismissed":"count"})
ODI_19_IND_BALL_pp3.rename(columns={"runs_off_bat":"Runs Conceeded","ball":"Balls Delivered","player_dismissed":"Dismissals"},
                 inplace=True)
ODI_19_IND_BALL_pp3=pd.pivot_table(ODI_19_IND_BALL_pp3,index=['bowler'],
                                 values=["Runs Conceeded","Balls Delivered","Dismissals"],aggfunc="sum")
ODI_19_IND_BALL_pp3["Economy"]=round(ODI_19_IND_BALL_pp3["Runs Conceeded"]/ODI_19_IND_BALL_pp3["Balls Delivered"]*6,2)
ODI_19_IND_BALL_pp3["Bowling Average"]=round(ODI_19_IND_BALL_pp3["Runs Conceeded"]/ODI_19_IND_BALL_pp3["Dismissals"],2)
ODI_19_IND_BALL_pp3["Bowling Strike Rate"]=round(ODI_19_IND_BALL_pp3["Balls Delivered"]/ODI_19_IND_BALL_pp3["Dismissals"],2)
ODI_19_IND_BALL_pp3
# Out:
#                    Balls Delivered  Dismissals  Runs Conceeded  Economy  \
# bowler
# AR Patel                        69           2              68     5.91
# Arshdeep Singh                   7           0              17    14.57
# Avesh Khan                      29           2              51    10.55
# B Kumar                        304          22             366     7.22
# DL Chahar                       65           0              84     7.75
# HH Pandya                      186           9             197     6.35
# JJ Bumrah                      476          22             455     5.74
# KH Pandya                       12           0              13     6.50
# KM Jadhav                        6           0               6     6.00
# KR Sen                           7           0              13    11.14
# Kuldeep Yadav                  198           9             234     7.09
# M Prasidh Krishna              122           8              98     4.82
# ...

# %%
ODI_23_IND_BALL_pp3=pd.pivot_table(ODI_23_IND_bl_pp3,index=["match_id","bowler"],
                              values=["runs_off_bat","ball","player_dismissed"],
               aggfunc={"runs_off_bat":"sum","ball":"count","player_dismissed":"count"})
ODI_23_IND_BALL_pp3.rename(columns={"runs_off_bat":"Runs Conceeded","ball":"Balls Delivered","player_dismissed":"Dismissals"},
                 inplace=True)
ODI_23_IND_BALL_pp3=pd.pivot_table(ODI_23_IND_BALL_pp3,index=['bowler'],
                                 values=["Runs Conceeded","Balls Delivered","Dismissals"],aggfunc="sum")
ODI_23_IND_BALL_pp3["Economy"]=round(ODI_23_IND_BALL_pp3["Runs Conceeded"]/ODI_23_IND_BALL_pp3["Balls Delivered"]*6,2)
ODI_23_IND_BALL_pp3["Bowling Average"]=round(ODI_23_IND_BALL_pp3["Runs Conceeded"]/ODI_23_IND_BALL_pp3["Dismissals"],2)
ODI_23_IND_BALL_pp3["Bowling Strike Rate"]=round(ODI_23_IND_BALL_pp3["Balls Delivered"]/ODI_23_IND_BALL_pp3["Dismissals"],2)
ODI_23_IND_BALL_pp3
# Out:
#                    Balls Delivered  Dismissals  Runs Conceeded  Economy  \
# bowler
# AR Patel                        36           1              40     6.67
# HH Pandya                       57           3              50     5.26
# JJ Bumrah                       18           1              16     5.33
# Kuldeep Yadav                   33           2              41     7.45
# M Prasidh Krishna               19           1              21     6.63
# Mohammed Shami                  78           6             123     9.46
# Mohammed Siraj                  53           5              42     4.75
# RA Jadeja                       24           0              32     8.00
# SN Thakur                       34           2              58    10.24
# Umran Malik                     13           0              24    11.08
# YS Chahal                        2           1               0     0.00
#
#                    Bowling Average  Bowling Strike Rate
# bowler
# ...

# %%
ODI_19_IND_BALL_pp3_wicket=ODI_19_IND_BALL_pp3.sort_values(by='Dismissals',ascending=False).head(5)
ODI_19_IND_BALL_pp3_wicket
# Out:
#                 Balls Delivered  Dismissals  Runs Conceeded  Economy  \
# bowler
# Mohammed Shami              406          29             533     7.88
# B Kumar                     304          22             366     7.22
# JJ Bumrah                   476          22             455     5.74
# YS Chahal                   280          19             315     6.75
# SN Thakur                   232           9             321     8.30
#
#                 Bowling Average  Bowling Strike Rate
# bowler
# Mohammed Shami            18.38                14.00
# B Kumar                   16.64                13.82
# JJ Bumrah                 20.68                21.64
# YS Chahal                 16.58                14.74
# SN Thakur                 35.67                25.78

# %%
ODI_23_IND_BALL_pp3_wicket=ODI_23_IND_BALL_pp3.sort_values(by='Dismissals',ascending=False).head(5)
ODI_23_IND_BALL_pp3_wicket
# Out:
#                 Balls Delivered  Dismissals  Runs Conceeded  Economy  \
# bowler
# Mohammed Shami               78           6             123     9.46
# Mohammed Siraj               53           5              42     4.75
# HH Pandya                    57           3              50     5.26
# Kuldeep Yadav                33           2              41     7.45
# SN Thakur                    34           2              58    10.24
#
#                 Bowling Average  Bowling Strike Rate
# bowler
# Mohammed Shami            20.50                 13.0
# Mohammed Siraj             8.40                 10.6
# HH Pandya                 16.67                 19.0
# Kuldeep Yadav             20.50                 16.5
# SN Thakur                 29.00                 17.0

# %%
ODI_19_IND_BALL_pp3_eco=ODI_19_IND_BALL_pp3[ODI_19_IND_BALL_pp3["Balls Delivered"]>=125].sort_values(by='Economy',ascending=True).head(5)
ODI_19_IND_BALL_pp3_eco
# Out:
#                 Balls Delivered  Dismissals  Runs Conceeded  Economy  \
# bowler
# Mohammed Siraj              178           6             163     5.49
# JJ Bumrah                   476          22             455     5.74
# HH Pandya                   186           9             197     6.35
# YS Chahal                   280          19             315     6.75
# Kuldeep Yadav               198           9             234     7.09
#
#                 Bowling Average  Bowling Strike Rate
# bowler
# Mohammed Siraj            27.17                29.67
# JJ Bumrah                 20.68                21.64
# HH Pandya                 21.89                20.67
# YS Chahal                 16.58                14.74
# Kuldeep Yadav             26.00                22.00

# %%
ODI_23_IND_BALL_pp3_eco=ODI_23_IND_BALL_pp3[ODI_23_IND_BALL_pp3["Balls Delivered"]>=25].sort_values(by='Economy',ascending=True).head(5)
ODI_23_IND_BALL_pp3_eco
# Out:
#                 Balls Delivered  Dismissals  Runs Conceeded  Economy  \
# bowler
# Mohammed Siraj               53           5              42     4.75
# HH Pandya                    57           3              50     5.26
# AR Patel                     36           1              40     6.67
# Kuldeep Yadav                33           2              41     7.45
# Mohammed Shami               78           6             123     9.46
#
#                 Bowling Average  Bowling Strike Rate
# bowler
# Mohammed Siraj             8.40                 10.6
# HH Pandya                 16.67                 19.0
# AR Patel                  40.00                 36.0
# Kuldeep Yadav             20.50                 16.5
# Mohammed Shami            20.50                 13.0

# %%
ODI_19_IND_BALL_pp3_bavg=ODI_19_IND_BALL_pp3[ODI_19_IND_BALL_pp3["Balls Delivered"]>=125].sort_values(by='Bowling Average',ascending=True).head(5)
ODI_19_IND_BALL_pp3_bavg
# Out:
#                 Balls Delivered  Dismissals  Runs Conceeded  Economy  \
# bowler
# YS Chahal                   280          19             315     6.75
# B Kumar                     304          22             366     7.22
# Mohammed Shami              406          29             533     7.88
# JJ Bumrah                   476          22             455     5.74
# HH Pandya                   186           9             197     6.35
#
#                 Bowling Average  Bowling Strike Rate
# bowler
# YS Chahal                 16.58                14.74
# B Kumar                   16.64                13.82
# Mohammed Shami            18.38                14.00
# JJ Bumrah                 20.68                21.64
# HH Pandya                 21.89                20.67

# %%
ODI_23_IND_BALL_pp3_bavg=ODI_23_IND_BALL_pp3[ODI_23_IND_BALL_pp3["Balls Delivered"]>=25].sort_values(by='Bowling Average',ascending=True).head(5)
ODI_23_IND_BALL_pp3_bavg
# Out:
#                 Balls Delivered  Dismissals  Runs Conceeded  Economy  \
# bowler
# Mohammed Siraj               53           5              42     4.75
# HH Pandya                    57           3              50     5.26
# Kuldeep Yadav                33           2              41     7.45
# Mohammed Shami               78           6             123     9.46
# SN Thakur                    34           2              58    10.24
#
#                 Bowling Average  Bowling Strike Rate
# bowler
# Mohammed Siraj             8.40                 10.6
# HH Pandya                 16.67                 19.0
# Kuldeep Yadav             20.50                 16.5
# Mohammed Shami            20.50                 13.0
# SN Thakur                 29.00                 17.0

# %%
ODI_19_IND_BALL_pp3_bSR=ODI_19_IND_BALL_pp3[ODI_19_IND_BALL_pp3["Balls Delivered"]>=125].sort_values(by='Bowling Strike Rate',ascending=True).head(5)
ODI_19_IND_BALL_pp3_bSR
# Out:
#                 Balls Delivered  Dismissals  Runs Conceeded  Economy  \
# bowler
# B Kumar                     304          22             366     7.22
# Mohammed Shami              406          29             533     7.88
# YS Chahal                   280          19             315     6.75
# HH Pandya                   186           9             197     6.35
# JJ Bumrah                   476          22             455     5.74
#
#                 Bowling Average  Bowling Strike Rate
# bowler
# B Kumar                   16.64                13.82
# Mohammed Shami            18.38                14.00
# YS Chahal                 16.58                14.74
# HH Pandya                 21.89                20.67
# JJ Bumrah                 20.68                21.64

# %%
ODI_23_IND_BALL_pp3_bSR=ODI_23_IND_BALL_pp3[ODI_23_IND_BALL_pp3["Balls Delivered"]>=25].sort_values(by='Bowling Strike Rate',ascending=True).head(5)
ODI_23_IND_BALL_pp3_bSR
# Out:
#                 Balls Delivered  Dismissals  Runs Conceeded  Economy  \
# bowler
# Mohammed Siraj               53           5              42     4.75
# Mohammed Shami               78           6             123     9.46
# Kuldeep Yadav                33           2              41     7.45
# SN Thakur                    34           2              58    10.24
# HH Pandya                    57           3              50     5.26
#
#                 Bowling Average  Bowling Strike Rate
# bowler
# Mohammed Siraj             8.40                 10.6
# Mohammed Shami            20.50                 13.0
# Kuldeep Yadav             20.50                 16.5
# SN Thakur                 29.00                 17.0
# HH Pandya                 16.67                 19.0

# %%
ODI_19_IND_BALL_pp3_P=pd.pivot_table(ODI_19_IND_bl_pp3,index=["match_id","bowler"],
                              values=["runs_off_bat","ball","player_dismissed"],
               aggfunc={"runs_off_bat":"sum","ball":"count","player_dismissed":"count"})
ODI_19_IND_BALL_pp3_P.rename(columns={"runs_off_bat":"Runs Conceeded","ball":"Balls Delivered","player_dismissed":"Dismissals"},
                 inplace=True)
ODI_19_IND_BALL_pp3_P
# Out:
#                          Balls Delivered  Dismissals  Runs Conceeded
# match_id bowler
# 1144490  B Kumar                      20           2              17
#          HH Pandya                     6           0               9
#          JJ Bumrah                    18           0              16
#          Kuldeep Yadav                 7           0               2
#          YS Chahal                    12           0              17
# ...                                  ...         ...             ...
# 1388412  SN Thakur                    13           0              15
# 1389388  JJ Bumrah                    18           1              16
#          Mohammed Shami               12           3              20
#          RA Jadeja                    12           0              14
#          SN Thakur                    18           1              37
#
# [220 rows x 3 columns]

# %%
ODI_19_IND_BALL_pp3_1=pd.pivot_table(ODI_19_IND_BALL_pp3_P[ODI_19_IND_BALL_pp3_P['Dismissals']>1],index=['bowler'],values=['Dismissals'],
               aggfunc={'Dismissals':'count'})
ODI_19_IND_BALL_pp3_1.rename(columns={'Dismissals':'Dismissals(more than 1)'},inplace=True)
ODI_19_IND_BALL_pp3_1=ODI_19_IND_BALL_pp3_1.sort_values(by='Dismissals(more than 1)',ascending=False).head(5)
ODI_19_IND_BALL_pp3_1
# Out:
#                 Dismissals(more than 1)
# bowler
# Mohammed Shami                       10
# B Kumar                               7
# JJ Bumrah                             5
# Kuldeep Yadav                         2
# Mohammed Siraj                        2

# %%
ODI_23_IND_BALL_pp3_P=pd.pivot_table(ODI_23_IND_bl_pp3,index=["match_id","bowler"],
                              values=["runs_off_bat","ball","player_dismissed"],
               aggfunc={"runs_off_bat":"sum","ball":"count","player_dismissed":"count"})
ODI_23_IND_BALL_pp3_P.rename(columns={"runs_off_bat":"Runs Conceeded","ball":"Balls Delivered","player_dismissed":"Dismissals"},
                 inplace=True)
ODI_19_IND_BALL_pp3_P
# Out:
#                          Balls Delivered  Dismissals  Runs Conceeded
# match_id bowler
# 1144490  B Kumar                      20           2              17
#          HH Pandya                     6           0               9
#          JJ Bumrah                    18           0              16
#          Kuldeep Yadav                 7           0               2
#          YS Chahal                    12           0              17
# ...                                  ...         ...             ...
# 1388412  SN Thakur                    13           0              15
# 1389388  JJ Bumrah                    18           1              16
#          Mohammed Shami               12           3              20
#          RA Jadeja                    12           0              14
#          SN Thakur                    18           1              37
#
# [220 rows x 3 columns]

# %%
ODI_23_IND_BALL_pp3_1=pd.pivot_table(ODI_23_IND_BALL_pp3_P[ODI_23_IND_BALL_pp3_P['Dismissals']>1],index=['bowler'],values=['Dismissals'],
               aggfunc={'Dismissals':'count'})
ODI_23_IND_BALL_pp3_1.rename(columns={'Dismissals':'Dismissals(more than 1)'},inplace=True)
ODI_23_IND_BALL_pp3_1=ODI_23_IND_BALL_pp3_1.sort_values(by='Dismissals(more than 1)',ascending=False).head(5)
ODI_23_IND_BALL_pp3_1
# Out:
#                 Dismissals(more than 1)
# bowler
# Mohammed Shami                        2
# Mohammed Siraj                        2
# Kuldeep Yadav                         1

# %%
ODI_19_IND_bl_pp3_dot=pd.pivot_table(ODI_19_IND_bl_pp3[ODI_19_IND_bl_pp3['runs_off_bat']==0],index='bowler',values='runs_off_bat',aggfunc={'runs_off_bat':'count'})
ODI_19_IND_bl_pp3_dot.rename(columns={'runs_off_bat':'Dot Balls'},inplace=True)
ODI_19_IND_bl_pp3_dot['Dot Ball(%)']=round((ODI_19_IND_bl_pp3_dot['Dot Balls']/ODI_19_IND_BALL_pp3['Balls Delivered'])*100,2)
ODI_19_IND_bl_pp3_dot=ODI_19_IND_bl_pp3_dot[ODI_19_IND_bl_pp3_dot['Dot Balls']>=50].sort_values(by='Dot Ball(%)',ascending=False).head(5)
ODI_19_IND_bl_pp3_dot
# Out:
#                    Dot Balls  Dot Ball(%)
# bowler
# M Prasidh Krishna         70        57.38
# Mohammed Siraj            89        50.00
# YS Chahal                122        43.57
# JJ Bumrah                205        43.07
# HH Pandya                 78        41.94

# %%
ODI_23_IND_bl_pp3_dot=pd.pivot_table(ODI_23_IND_bl_pp3[ODI_23_IND_bl_pp3['runs_off_bat']==0],index='bowler',values='runs_off_bat',aggfunc={'runs_off_bat':'count'})
ODI_23_IND_bl_pp3_dot.rename(columns={'runs_off_bat':'Dot Balls'},inplace=True)
ODI_23_IND_bl_pp3_dot['Dot Ball(%)']=round((ODI_23_IND_bl_pp3_dot['Dot Balls']/ODI_23_IND_BALL_pp3['Balls Delivered'])*100,2)
ODI_23_IND_bl_pp3_dot=ODI_23_IND_bl_pp3_dot[ODI_23_IND_bl_pp3_dot['Dot Balls']>=15].sort_values(by='Dot Ball(%)',ascending=False).head(5)
ODI_23_IND_bl_pp3_dot
# Out:
#                 Dot Balls  Dot Ball(%)
# bowler
# Mohammed Siraj         30        56.60
# AR Patel               19        52.78
# HH Pandya              30        52.63
# Mohammed Shami         28        35.90

# %%
ODI_19_IND_bl_pp3_lb=pd.pivot_table(ODI_19_IND_bl_pp3[(ODI_19_IND_bl_pp3['runs_off_bat']==4)|(ODI_19_IND_bl_pp3['runs_off_bat']==6)],
                                    index='bowler',values='runs_off_bat',aggfunc={'runs_off_bat':'count'})
ODI_19_IND_bl_pp3_lb.rename(columns={'runs_off_bat':'Boundary Conceeded'},inplace=True)
ODI_19_IND_bl_pp3_lb['Boundary Conceeded(%)']=round((ODI_19_IND_bl_pp3_lb['Boundary Conceeded']/ODI_19_IND_BALL_pp3['Balls Delivered'])*100,2)
ODI_19_IND_bl_pp3_lb=ODI_19_IND_bl_pp3_lb[ODI_19_IND_bl_pp3_lb['Boundary Conceeded']>=20].sort_values(by='Boundary Conceeded(%)',ascending=True).head(5)
ODI_19_IND_bl_pp3_lb
# Out:
#                Boundary Conceeded  Boundary Conceeded(%)
# bowler
# JJ Bumrah                      43                   9.03
# HH Pandya                      20                  10.75
# YS Chahal                      32                  11.43
# B Kumar                        35                  11.51
# Kuldeep Yadav                  25                  12.63

# %%
ODI_23_IND_bl_pp3_lb=pd.pivot_table(ODI_23_IND_bl_pp3[(ODI_23_IND_bl_pp3['runs_off_bat']==4)|(ODI_23_IND_bl_pp3['runs_off_bat']==6)],
                                    index='bowler',values='runs_off_bat',aggfunc={'runs_off_bat':'count'})
ODI_23_IND_bl_pp3_lb.rename(columns={'runs_off_bat':'Boundary Conceeded'},inplace=True)
ODI_23_IND_bl_pp3_lb['Boundary Conceeded(%)']=round((ODI_23_IND_bl_pp3_lb['Boundary Conceeded']/ODI_23_IND_BALL_pp3['Balls Delivered'])*100,2)
ODI_23_IND_bl_pp3_lb=ODI_23_IND_bl_pp3_lb.sort_values(by='Boundary Conceeded(%)',ascending=True).head(5)
ODI_23_IND_bl_pp3_lb
# Out:
#                    Boundary Conceeded  Boundary Conceeded(%)
# bowler
# HH Pandya                           4                   7.02
# Mohammed Siraj                      4                   7.55
# M Prasidh Krishna                   2                  10.53
# JJ Bumrah                           2                  11.11
# Kuldeep Yadav                       4                  12.12

# %%
plt.subplot(7,2,1)
ODI_19_IND_BALL_pp3_wicket['Dismissals'].plot(kind='bar',figsize=(12,5),color='orange')
for i in range(len(list(ODI_19_IND_BALL_pp3_wicket.index))):
    plt.text(i,ODI_19_IND_BALL_pp3_wicket['Dismissals'][i],ODI_19_IND_BALL_pp3_wicket['Dismissals'][i],ha='center')
plt.title('Top Wicket Takers [41-50 overs] of India(Since 2019)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Wickets Taken')
plt.subplot(7,2,2)
ODI_23_IND_BALL_pp3_wicket['Dismissals'].plot(kind='bar',figsize=(12,5),color='orange')
for i in range(len(list(ODI_23_IND_BALL_pp3_wicket.index))):
    plt.text(i,ODI_23_IND_BALL_pp3_wicket['Dismissals'][i],ODI_23_IND_BALL_pp3_wicket['Dismissals'][i],ha='center')
plt.title('Top Wicket Takers [41-50 overs] of India(In 2023)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Wickets Taken')
plt.subplot(7,2,3)
ODI_19_IND_BALL_pp3_eco['Economy'].plot(kind='bar',figsize=(12,5),color='green')
for i in range(len(list(ODI_19_IND_BALL_pp3_eco.index))):
    plt.text(i,ODI_19_IND_BALL_pp3_eco['Economy'][i],ODI_19_IND_BALL_pp3_eco['Economy'][i],ha='center')
plt.title('Least Economical bowlers [41-50 overs] (atleast 125 balls delivered) of India(Since 2019)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Economy')
plt.subplot(7,2,4)
ODI_23_IND_BALL_pp3_eco['Economy'].plot(kind='bar',figsize=(12,5),color='green')
for i in range(len(list(ODI_23_IND_BALL_pp3_eco.index))):
    plt.text(i,ODI_23_IND_BALL_pp3_eco['Economy'][i],ODI_23_IND_BALL_pp3_eco['Economy'][i],ha='center')
plt.title('Least Economical bowlers [41-50 overs] (atleast 25 balls delivered) of India(In 2023)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Economy')
plt.subplot(7,2,5)
ODI_19_IND_BALL_pp3_bavg['Bowling Average'].plot(kind='bar',figsize=(12,5),color='violet')
for i in range(len(list(ODI_19_IND_BALL_pp3_bavg.index))):
    plt.text(i,ODI_19_IND_BALL_pp3_bavg['Bowling Average'][i],ODI_19_IND_BALL_pp3_bavg['Bowling Average'][i],ha='center')
plt.title('Least Bowling Average [41-50 overs] (atleast 125 balls delivered) of India(Since 2019)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Bowling Average')
plt.subplot(7,2,6)
ODI_23_IND_BALL_pp3_bavg['Bowling Average'].plot(kind='bar',figsize=(12,5),color='violet')
for i in range(len(list(ODI_23_IND_BALL_pp3_bavg.index))):
    plt.text(i,ODI_23_IND_BALL_pp3_bavg['Bowling Average'][i],ODI_23_IND_BALL_pp3_bavg['Bowling Average'][i],ha='center')
plt.title('Least Bowling Average [41-50 overs] (atleast 25 balls delivered) of India(In 2023)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Bowling Average')
plt.subplot(7,2,7)
ODI_19_IND_BALL_pp3_bSR['Bowling Strike Rate'].plot(kind='bar',figsize=(12,5),color='brown')
for i in range(len(list(ODI_19_IND_BALL_pp3_bSR.index))):
    plt.text(i,ODI_19_IND_BALL_pp3_bSR['Bowling Strike Rate'][i],ODI_19_IND_BALL_pp3_bSR['Bowling Strike Rate'][i],ha='center')
plt.title('Least Bowling Strike Rate [41-50 overs] (atleast 125 balls delivered) of India(Since 2019)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Bowling Strike Rate')
plt.subplot(7,2,8)
ODI_23_IND_BALL_pp3_bSR['Bowling Strike Rate'].plot(kind='bar',figsize=(12,5),color='brown')
for i in range(len(list(ODI_23_IND_BALL_pp3_bSR.index))):
    plt.text(i,ODI_23_IND_BALL_pp3_bSR['Bowling Strike Rate'][i],ODI_23_IND_BALL_pp3_bSR['Bowling Strike Rate'][i],ha='center')
plt.title('Least Bowling Strike Rate [41-50 overs] (atleast 25 balls delivered) of India(In 2023)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Bowling Strike Rate')
plt.subplot(7,2,9)
ODI_19_IND_BALL_pp3_1['Dismissals(more than 1)'].plot(kind='bar',figsize=(12,5),color='gray')
for i in range(len(list(ODI_19_IND_BALL_pp3_1.index))):
    plt.text(i,ODI_19_IND_BALL_pp3_1['Dismissals(more than 1)'][i],ODI_19_IND_BALL_pp3_1['Dismissals(more than 1)'][i],ha='center')
plt.title('Top Multiple Wicket Takers [41-50 overs] (more than 1)of India(Since 2019)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Dismissals(more than 1)')
plt.subplot(7,2,10)
ODI_23_IND_BALL_pp3_1['Dismissals(more than 1)'].plot(kind='bar',figsize=(12,5),color='gray')
for i in range(len(list(ODI_23_IND_BALL_pp3_1.index))):
    plt.text(i,ODI_23_IND_BALL_pp3_1['Dismissals(more than 1)'][i],ODI_23_IND_BALL_pp3_1['Dismissals(more than 1)'][i],ha='center')
plt.title('Top Multiple Wicket Takers [41-50 overs] (more than 1)of India(In 2023)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Dismissals(more than 1)')
plt.subplots_adjust(left=0.1,bottom=0.01, right=1.5, top=4.5, wspace=0.4, hspace=0.8)
plt.subplot(7,2,11)
ODI_19_IND_bl_pp3_dot['Dot Ball(%)'].plot(kind='bar',figsize=(12,5),color='yellow')
for i in range(len(list(ODI_19_IND_bl_pp3_dot.index))):
    plt.text(i,ODI_19_IND_bl_pp3_dot['Dot Ball(%)'][i],ODI_19_IND_bl_pp3_dot['Dot Ball(%)'][i],ha='center')
plt.title('Top Dot Ball(%) [41-50 overs] (atleast 50 dot balls delivered) for India(Since 2019)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Dot Ball(%)')
plt.subplot(7,2,12)
ODI_23_IND_bl_pp3_dot['Dot Ball(%)'].plot(kind='bar',figsize=(12,5),color='yellow')
for i in range(len(list(ODI_23_IND_bl_pp3_dot.index))):
    plt.text(i,ODI_23_IND_bl_pp3_dot['Dot Ball(%)'][i],ODI_23_IND_bl_pp3_dot['Dot Ball(%)'][i],ha='center')
plt.title('Top Dot Ball(%) [41-50 overs] (atleast 15 dot balls delivered) for India(In 2023)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Dot Ball(%)')
plt.subplot(7,2,13)
ODI_19_IND_bl_pp3_lb['Boundary Conceeded(%)'].plot(kind='bar',figsize=(12,5),color='indigo')
for i in range(len(list(ODI_19_IND_bl_pp3_lb.index))):
    plt.text(i,ODI_19_IND_bl_pp3_lb['Boundary Conceeded(%)'][i],ODI_19_IND_bl_pp3_lb['Boundary Conceeded(%)'][i],ha='center')
plt.title('Least Boundary Conceeded(%) [11-40 overs] for India(Since 2019)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Boundary Conceeded(%)')
plt.subplot(7,2,14)
ODI_23_IND_bl_pp3_lb['Boundary Conceeded(%)'].plot(kind='bar',figsize=(12,5),color='indigo')
for i in range(len(list(ODI_23_IND_bl_pp3_lb.index))):
    plt.text(i,ODI_23_IND_bl_pp3_lb['Boundary Conceeded(%)'][i],ODI_23_IND_bl_pp3_lb['Boundary Conceeded(%)'][i],ha='center')
plt.title('Least Boundary Conceeded(%) [11-40 overs] for India(In 2023)')
plt.xlabel('Bowler')
plt.xticks(rotation=0)
plt.ylabel('Boundary Conceeded(%)')
plt.show()

# %% [markdown]
# **Caution:**
#
#     1. Bhubaneshwar Kumar,Yuzi Chahal, Prasidh Krishna is not in a scheme for 2023 world cup (BCCI doesn't give much chance        to them to prove ). Also Prasidh Krishna was out of Indian teams for more than half years.
#     2. Shardul Thakur is an wicket taker but his economy is not good.

# %% [markdown]
# **Bowling Stats(Info) in PP3 (Overs 41-50):**
#
#     1. Mohmd. Shami is the highet wicket takers in pp3 [41-50 overs] since 2019 (29 wickets with 10 times multiple                wickets)and also in present year (2023) (6 wickets with 2 time multiple wickets)for India.
#     2. Mohd. Siraj is the best econoic bowler in pp3 [41-50 overs] since 2019( Economy:5.49) and also in present                  year (2023)(Economy: 4.75) with least bowling average(8.4), highest dot ball(%)(56.5) for India. Rather his                performance increases in 2023 at a high rate.
#     3. Jasprit Bumrah has least boundary(%) in pp3 [41-50 overs] since 2019 (9.03).
#     4. Hardik Pandya has least boundary(%) in pp3 [41-50 overs] since 2023 (7.02).

# %% [markdown]
# **Death Overs:**
#
#     1. Mohd. Siraj
#     2. Mohmd. Shami
#     3. Jasprit Bumrah
#     4. Hardik Pandya
#     5. Prasidh Krishna [Backup: Top dot ball(%) since 2019 in pp3 for India]

# %% [markdown]
# **Probable 11:**
#
#     1. Rohit Sharma (C)
#     2. Subhman Gill [Backup: Ishan Kishan]
#     3. Virat Kohli
#     4. Shreyas Iyer/ Ishan Kishan [Backup: SuryaKumar Yadav]
#     5. KL Rahul [Backup: Ishan Kishan]
#     6. Hardik Pandya (VC) [Backup: SuryaKumar Yadav]
#     7. Ravindra Jadeja [Backup: Axar Patel]
#     8. Momd. Shami [Backup: Shardul Thakur]
#     9. Kuldeep Yadav [Backup: Yuzi Chahal (*If required)]
#     10. Jasprit Bumrah [Backup: Prasidh Krishna (*If required)]
#     11. Momd. Siraj [Backup: Prasidh Krishna (*If required)]
